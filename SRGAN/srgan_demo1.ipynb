# %% [markdown]
# # SRGAN

# %% [markdown]
# ## 预处理阶段

# %%
import argparse
import os
import numpy as np
import math
import itertools
import sys
import time
import glob
from PIL import Image

import torchvision.transforms as transforms
from torchvision.utils import save_image, make_grid
from torchvision import datasets
from torchvision.models import vgg19
from torchvision.models import VGG19_Weights

from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torch.autograd import Variable

import torch.nn as nn
import torch.nn.functional as F
import torch

# %%
# 计划使用GPU运行
# 检查是否有可用的GPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
# 超参数设置
epoch = 0           # 起始轮次
n_epochs = 200      # 训练集总训练轮次
batch_size = 4
lr = 0.0002           # 学习率
b1 = 0.5 
b2 = 0.999
decay_epoch = 100    # 从第几轮开始，lr开始衰减
hr_height = 256      # 高分辨图像高
hr_width = 256       # 高分辨图像宽
channels = 3        # 图片通道数
sample_interval = 100    # 生成图片间隔
checkpoint_interval = -1  # 模型检查点之间的间隔
sample_dir = 'demo1'    # 生成图片保存路径

hr_shape = (hr_height, hr_width)

# %%
# 建立文件夹用于存放训练过程的图像，如果文件夹不存在，就创建一个
if not os.path.exists(sample_dir):
    os.makedirs(sample_dir)

# %% [markdown]
# ## 数据集

# %%
# 数据集预训练得到的平均值和标准差
mean = np.array([0.485, 0.456, 0.406])
std = np.array([0.229, 0.224, 0.225])

class ImageDataset(Dataset):
    def __init__(self, root, hr_shape):
        hr_height, hr_width = hr_shape
        # 低分辨图像和高分辨图像的transforms
        self.lr_transform = transforms.Compose(
            [
                transforms.Resize((hr_height // 4, hr_width // 4), Image.BICUBIC),
                transforms.ToTensor(),
                transforms.Normalize(mean, std),
            ]
        )
        self.hr_transform = transforms.Compose(
            [
                transforms.Resize((hr_height, hr_width), Image.BICUBIC),
                transforms.ToTensor(),
                transforms.Normalize(mean, std),
            ]
        )
        
        self.files = sorted(glob.glob(root + "/*.*"))
        
    def __getitem__(self, index):
        img = Image.open(self.files[index % len(self.files)])
        img_lr = self.lr_transform(img)
        img_hr = self.hr_transform(img)
        return {"lr": img_lr, "hr": img_hr}
    
    def __len__(self):
        return len(self.files)

# %%
# 数据集加载器
data_loader = DataLoader(
    # ImageDataset(root='/home/cxmd/文档/data_for_AI_train/img_align_celeba', hr_shape=hr_shape),
    ImageDataset(root='/home/cxmd/文档/data_for_AI_train/Particles/hr', hr_shape=hr_shape),
    batch_size=batch_size,
    shuffle=True,
)

# %% [markdown]
# ## 网络构建

# %% [markdown]
# ![](https://raw.githubusercontent.com/XM-Chen/figuremap/main/my_notes/202311200921526.png)

# %%
class FeatureExtractor(nn.Module):
    def __init__(self):
        super(FeatureExtractor, self).__init__()
        # 创建一个预训练的VGG-19模型
        vgg19_model = vgg19(weights=VGG19_Weights.IMAGENET1K_V1)
        # 使用VGG-19模型的前18层作为特征提取器
        self.feature_extractor = nn.Sequential(*list(vgg19_model.features.children())[:18])

    def forward(self, img):
        # 提取图像的特征并返回
        return self.feature_extractor(img)


class ResidualBlock(nn.Module):
    def __init__(self, in_features):
        super(ResidualBlock, self).__init__()
        # 定义一个卷积块，包含两个卷积层，每个卷积层后面都跟着一个批量归一化层和一个PReLU激活函数
        self.conv_block = nn.Sequential(
            nn.Conv2d(in_features, in_features, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(in_features, 0.8),
            nn.PReLU(),
            nn.Conv2d(in_features, in_features, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(in_features, 0.8),
        )

    def forward(self, x):
        # 将输入通过卷积块处理得到的结果与原始输入相加，实现残差连接
        return x + self.conv_block(x)

# %%
# 构建生成器
class GeneratorResNet(nn.Module):
    def __init__(self, in_channels=3, out_channels=3, n_residual_blocks=16):   # 原文建议使用16个残差块
        super(GeneratorResNet, self).__init__()
        
        # 第一层
        self.conv1 = nn.Sequential(
            nn.Conv2d(in_channels=in_channels, out_channels=64, kernel_size=9, stride=1, padding=4),
            nn.PReLU(),
        )
        
        # 残差块
        res_blocks = []
        for _ in range(n_residual_blocks):
            res_blocks.append(ResidualBlock(64))
        self.res_block = nn.Sequential(
            *res_blocks
        )
        
        # 残差块后的第二个卷积层
        self.conv2 = nn.Sequential(
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64, 0.8),
        )
        
        # 上采样层
        upsampling = []
        for out_features in range(2):
            upsampling += [
                nn.Conv2d(64, 256, 3, 1, 1),
                nn.BatchNorm2d(256),
                nn.PixelShuffle(upscale_factor=2),
                nn.PReLU()
            ]
        self.upsampling = nn.Sequential(
            *upsampling
        )
        
        # 最后输出层
        self.conv3 = nn.Sequential(
            nn.Conv2d(64, out_channels=out_channels, kernel_size=9, stride=1, padding=4),
            nn.Tanh(),
        )
        
    def forward(self, x):
        out1 = self.conv1(x)
        out = self.res_block(out1)
        out2 = self.conv2(out)
        out = torch.add(out1, out2)
        out = self.upsampling(out)
        out = self.conv3(out)
        return out

# %%
# 构建判别器
class Discriminator(nn.Module):
    def __init__(self, input_shape):
        super(Discriminator, self).__init__()
        
        self.input_shape = input_shape
        in_channels, in_height, in_width = self.input_shape
        patch_h, patch_w = int(in_height / 2 ** 4), int(in_width / 2 ** 4)
        self.output_shape = (1, patch_h, patch_w)
        
        def discriminator_block(in_filters, out_filters, first_block=False):
            layers = []
            layers.append(nn.Conv2d(in_filters, out_filters, kernel_size=3, stride=1, padding=1))
            if not first_block:
                layers.append(nn.BatchNorm2d(out_filters))
            layers.append(nn.LeakyReLU(0.2, inplace=True))
            layers.append(nn.Conv2d(out_filters, out_filters, kernel_size=3, stride=2, padding=1))
            layers.append(nn.BatchNorm2d(out_filters))
            layers.append(nn.LeakyReLU(0.2, inplace=True))
            return layers
        
        layers = []
        in_filters = in_channels
        for i, out_filters in enumerate([64, 128, 256, 512]):
            layers.extend(discriminator_block(in_filters, out_filters, first_block=(i == 0)))
            in_filters = out_filters
        
        # layers.append(nn.AdaptiveAvgPool2d(1))
        # layers.append(nn.Flatten())
        # layers.append(nn.Linear(512, 1024))
        # layers.append(nn.LeakyReLU(0.2))
        # layers.append(nn.Linear(1024, 1))
        # layers.append(nn.Sigmoid())
        layers.append(nn.Conv2d(out_filters, 1, kernel_size=3, stride=1, padding=1))
        
        self.model = nn.Sequential(*layers)
        
    def forward(self, img):
        return self.model(img)

# %%
# 初始化生成器和判别器
generator = GeneratorResNet().to(device)
discriminator = Discriminator(input_shape=(channels, *hr_shape)).to(device)
feature_extractor = FeatureExtractor().to(device)

# 将feature_extractor设为评估模式，不需要训练
feature_extractor.eval()
# Out:
# FeatureExtractor(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU(inplace=True)
#   )
# )

# %%
# 设置损失函数和优化器
criterion_GAN = torch.nn.MSELoss()
criterion_content = torch.nn.L1Loss()

optimizer_G = torch.optim.Adam(generator.parameters(), lr=lr, betas=(b1, b2))
optimizer_D = torch.optim.Adam(discriminator.parameters(), lr=lr, betas=(b1, b2))

# %%
# 检测是否有预训练模型
# 如果开始训练的轮数不等于0，那么加载预训练的模型
if epoch != 0:
    # 从文件中加载生成器模型的参数，并将这些参数加载到生成器模型中
    generator.load_state_dict(torch.load(f"demo1/generator_{epoch}.pth"))
    # 从文件中加载判别器模型的参数，并将这些参数加载到判别器模型中
    discriminator.load_state_dict(torch.load(f"saved_models/discriminator_{epoch}.pth"))

# %% [markdown]
# ## 训练

# %%
# 记录开始训练的时间
start_time = time.time()

for ind_epoch in range(epoch, n_epochs):
    for i, imgs in enumerate(data_loader):
        
        # 固定输入大小
        imgs_lr = imgs['lr'].to(device)
        imgs_hr = imgs['hr'].to(device)
        
        valid = torch.ones((imgs_lr.size(0), *discriminator.output_shape), device=device, requires_grad=False)
        fake = torch.zeros((imgs_lr.size(0), *discriminator.output_shape), device=device, requires_grad=False)
        
        # ----------------
        #  训练生成器
        # ----------------
        
        optimizer_G.zero_grad()
        
        # 由低分辨图像输入产生高分辨图像
        gen_hr = generator(imgs_lr)
        
        # 判别器损失
        loss_GAN = criterion_GAN(discriminator(gen_hr), valid)
        
        # 内容损失
        gen_features = feature_extractor(gen_hr)
        real_features = feature_extractor(imgs_hr)
        loss_content = criterion_content(gen_features, real_features.detach())
        
        # 总损失
        loss_G = loss_content + 1e-3 * loss_GAN
        
        loss_G.backward()
        optimizer_G.step()
        
        # ----------------
        #  训练判别器
        # ----------------
        
        optimizer_D.zero_grad()
        
        # 真假图片损失
        loss_real = criterion_GAN(discriminator(imgs_hr), valid)
        loss_fake = criterion_GAN(discriminator(gen_hr.detach()), fake)
        
        # 总损失
        loss_D = (loss_real + loss_fake) / 2
        
        loss_D.backward()
        optimizer_D.step()
        
        # ----------------
        #  输出
        # ----------------
        if (i + 1) % 100 == 0:      # 每一百批次输入一次训练程度
            # 计算过去的时间
            elapsed_time = time.time() - start_time
            print('Elapsed time: {:.4f} seconds, Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss: {:.4f}'.format(elapsed_time, ind_epoch + 1, n_epochs, i + 1, len(data_loader), loss_D.item(), loss_G.item()))
# Out:
# Elapsed time: 27.4935 seconds, Epoch [1/200], Step [100/853], d_loss: 0.0070, g_loss: 0.6543
# Elapsed time: 53.7790 seconds, Epoch [1/200], Step [200/853], d_loss: 0.0058, g_loss: 0.5323
# Elapsed time: 80.3820 seconds, Epoch [1/200], Step [300/853], d_loss: 0.0014, g_loss: 0.5476
# Elapsed time: 106.7564 seconds, Epoch [1/200], Step [400/853], d_loss: 0.0225, g_loss: 0.5261
# Elapsed time: 133.0567 seconds, Epoch [1/200], Step [500/853], d_loss: 0.0072, g_loss: 0.5852
# Elapsed time: 159.6567 seconds, Epoch [1/200], Step [600/853], d_loss: 0.0101, g_loss: 0.4247
# Elapsed time: 186.1487 seconds, Epoch [1/200], Step [700/853], d_loss: 0.0012, g_loss: 0.4128
# Elapsed time: 212.4837 seconds, Epoch [1/200], Step [800/853], d_loss: 0.0016, g_loss: 0.8750
# Elapsed time: 253.0195 seconds, Epoch [2/200], Step [100/853], d_loss: 0.0012, g_loss: 0.5471
# Elapsed time: 279.3575 seconds, Epoch [2/200], Step [200/853], d_loss: 0.0010, g_loss: 0.5554
# Elapsed time: 305.5912 seconds, Epoch [2/200], Step [300/853], d_loss: 0.0009, g_loss: 0.6557
# Elapsed time: 331.9402 seconds, Epoch [2/200], Step [400/853], d_loss: 0.0010, g_loss: 0.4190
# Elapsed time: 358.4456 seconds, Epoch [2/200], Step [500/853], d_loss: 0.0013, g_loss: 0.4387
# Elapsed time: 384.9946 seconds, Epoch [2/200], Step [600/853], d_loss: 0.0006, g_loss: 0.5454
# Elapsed time: 411.4350 seconds, Epoch [2/200], Step [700/853], d_loss: 0.0007, g_loss: 0.5239
# Elapsed time: 437.8032 seconds, Epoch [2/200], Step [800/853], d_loss: 0.0012, g_loss: 0.5764
# Elapsed time: 478.5999 seconds, Epoch [3/200], Step [100/853], d_loss: 0.0019, g_loss: 0.6003
# Elapsed time: 505.1694 seconds, Epoch [3/200], Step [200/853], d_loss: 0.0004, g_loss: 0.4878
# Elapsed time: 531.7423 seconds, Epoch [3/200], Step [300/853], d_loss: 0.0018, g_loss: 0.6748
# Elapsed time: 557.5551 seconds, Epoch [3/200], Step [400/853], d_loss: 0.0004, g_loss: 0.5219
# Elapsed time: 582.6341 seconds, Epoch [3/200], Step [500/853], d_loss: 0.0024, g_loss: 0.6410
# Elapsed time: 609.1381 seconds, Epoch [3/200], Step [600/853], d_loss: 0.0007, g_loss: 0.4772
# Elapsed time: 635.7150 seconds, Epoch [3/200], Step [700/853], d_loss: 0.0013, g_loss: 0.4480
# Elapsed time: 662.8000 seconds, Epoch [3/200], Step [800/853], d_loss: 0.0014, g_loss: 0.7457
# Elapsed time: 703.3097 seconds, Epoch [4/200], Step [100/853], d_loss: 0.0006, g_loss: 0.6411
# Elapsed time: 729.7416 seconds, Epoch [4/200], Step [200/853], d_loss: 0.0004, g_loss: 0.4290
# Elapsed time: 756.1393 seconds, Epoch [4/200], Step [300/853], d_loss: 0.0013, g_loss: 0.4031
# Elapsed time: 782.8299 seconds, Epoch [4/200], Step [400/853], d_loss: 0.0004, g_loss: 0.4468
# Elapsed time: 809.4233 seconds, Epoch [4/200], Step [500/853], d_loss: 0.0009, g_loss: 0.5276
# Elapsed time: 835.9687 seconds, Epoch [4/200], Step [600/853], d_loss: 0.0008, g_loss: 0.4475
# Elapsed time: 862.3772 seconds, Epoch [4/200], Step [700/853], d_loss: 0.0027, g_loss: 0.5793
# Elapsed time: 889.0858 seconds, Epoch [4/200], Step [800/853], d_loss: 0.0023, g_loss: 0.5099
# Elapsed time: 930.2323 seconds, Epoch [5/200], Step [100/853], d_loss: 0.0007, g_loss: 0.3326
# Elapsed time: 956.9011 seconds, Epoch [5/200], Step [200/853], d_loss: 0.0010, g_loss: 0.5723
# Elapsed time: 983.0330 seconds, Epoch [5/200], Step [300/853], d_loss: 0.0009, g_loss: 0.4915
# Elapsed time: 1009.1575 seconds, Epoch [5/200], Step [400/853], d_loss: 0.0042, g_loss: 0.3327
# Elapsed time: 1035.2883 seconds, Epoch [5/200], Step [500/853], d_loss: 0.2098, g_loss: 0.3558
# Elapsed time: 1062.0251 seconds, Epoch [5/200], Step [600/853], d_loss: 0.0216, g_loss: 0.4085
# Elapsed time: 1088.7941 seconds, Epoch [5/200], Step [700/853], d_loss: 0.0061, g_loss: 0.3843
# Elapsed time: 1115.3174 seconds, Epoch [5/200], Step [800/853], d_loss: 0.0062, g_loss: 0.5691
# Elapsed time: 1155.2304 seconds, Epoch [6/200], Step [100/853], d_loss: 0.0059, g_loss: 0.3511
# Elapsed time: 1181.5551 seconds, Epoch [6/200], Step [200/853], d_loss: 0.0050, g_loss: 0.4697
# Elapsed time: 1207.2878 seconds, Epoch [6/200], Step [300/853], d_loss: 0.0005, g_loss: 0.4209
# Elapsed time: 1232.9860 seconds, Epoch [6/200], Step [400/853], d_loss: 0.0016, g_loss: 0.5114
# Elapsed time: 1258.5535 seconds, Epoch [6/200], Step [500/853], d_loss: 0.0018, g_loss: 0.6691
# Elapsed time: 1283.5897 seconds, Epoch [6/200], Step [600/853], d_loss: 0.0008, g_loss: 0.4535
# Elapsed time: 1308.7381 seconds, Epoch [6/200], Step [700/853], d_loss: 0.0006, g_loss: 0.5048
# Elapsed time: 1333.9463 seconds, Epoch [6/200], Step [800/853], d_loss: 0.0015, g_loss: 0.3559
# Elapsed time: 1372.5765 seconds, Epoch [7/200], Step [100/853], d_loss: 0.0010, g_loss: 0.4239
# Elapsed time: 1397.6265 seconds, Epoch [7/200], Step [200/853], d_loss: 0.0009, g_loss: 0.6321
# Elapsed time: 1422.7093 seconds, Epoch [7/200], Step [300/853], d_loss: 0.0005, g_loss: 0.2657
# Elapsed time: 1448.4247 seconds, Epoch [7/200], Step [400/853], d_loss: 0.0009, g_loss: 0.4137
# Elapsed time: 1473.8489 seconds, Epoch [7/200], Step [500/853], d_loss: 0.0008, g_loss: 0.3084
# Elapsed time: 1499.0728 seconds, Epoch [7/200], Step [600/853], d_loss: 0.0035, g_loss: 0.3605
# Elapsed time: 1524.2420 seconds, Epoch [7/200], Step [700/853], d_loss: 0.0041, g_loss: 0.3045
# Elapsed time: 1549.3857 seconds, Epoch [7/200], Step [800/853], d_loss: 0.0017, g_loss: 0.8391
# Elapsed time: 1588.1866 seconds, Epoch [8/200], Step [100/853], d_loss: 0.0079, g_loss: 0.4394
# Elapsed time: 1614.1821 seconds, Epoch [8/200], Step [200/853], d_loss: 0.0011, g_loss: 0.4822
# Elapsed time: 1640.1691 seconds, Epoch [8/200], Step [300/853], d_loss: 0.0012, g_loss: 0.2926
# Elapsed time: 1665.5134 seconds, Epoch [8/200], Step [400/853], d_loss: 0.0032, g_loss: 0.3287
# Elapsed time: 1690.6655 seconds, Epoch [8/200], Step [500/853], d_loss: 0.0006, g_loss: 0.2759
# Elapsed time: 1715.7489 seconds, Epoch [8/200], Step [600/853], d_loss: 0.0041, g_loss: 0.4798
# Elapsed time: 1741.6395 seconds, Epoch [8/200], Step [700/853], d_loss: 0.0023, g_loss: 0.5959
# Elapsed time: 1767.3242 seconds, Epoch [8/200], Step [800/853], d_loss: 0.0014, g_loss: 0.2829
# Elapsed time: 1805.7304 seconds, Epoch [9/200], Step [100/853], d_loss: 0.0004, g_loss: 0.4593
# Elapsed time: 1830.9651 seconds, Epoch [9/200], Step [200/853], d_loss: 0.0007, g_loss: 0.2690
# Elapsed time: 1856.3616 seconds, Epoch [9/200], Step [300/853], d_loss: 0.0011, g_loss: 0.3380
# Elapsed time: 1882.2256 seconds, Epoch [9/200], Step [400/853], d_loss: 0.0006, g_loss: 0.3869
# Elapsed time: 1908.0911 seconds, Epoch [9/200], Step [500/853], d_loss: 0.0076, g_loss: 0.2926
# Elapsed time: 1933.9734 seconds, Epoch [9/200], Step [600/853], d_loss: 0.0005, g_loss: 0.5482
# Elapsed time: 1959.7818 seconds, Epoch [9/200], Step [700/853], d_loss: 0.0006, g_loss: 0.4255
# Elapsed time: 1985.9587 seconds, Epoch [9/200], Step [800/853], d_loss: 0.0005, g_loss: 0.6450
# Elapsed time: 2025.7308 seconds, Epoch [10/200], Step [100/853], d_loss: 0.0027, g_loss: 0.4920
# Elapsed time: 2051.8332 seconds, Epoch [10/200], Step [200/853], d_loss: 0.0012, g_loss: 0.4082
# Elapsed time: 2077.7149 seconds, Epoch [10/200], Step [300/853], d_loss: 0.0006, g_loss: 0.5004
# Elapsed time: 2103.7075 seconds, Epoch [10/200], Step [400/853], d_loss: 0.0021, g_loss: 0.3413
# Elapsed time: 2129.4757 seconds, Epoch [10/200], Step [500/853], d_loss: 0.0038, g_loss: 0.3287
# Elapsed time: 2156.0231 seconds, Epoch [10/200], Step [600/853], d_loss: 0.1276, g_loss: 0.3483
# Elapsed time: 2181.9258 seconds, Epoch [10/200], Step [700/853], d_loss: 0.0052, g_loss: 0.3191
# Elapsed time: 2207.9912 seconds, Epoch [10/200], Step [800/853], d_loss: 0.0023, g_loss: 0.3610
# Elapsed time: 2247.6929 seconds, Epoch [11/200], Step [100/853], d_loss: 0.0018, g_loss: 0.3017
# Elapsed time: 2273.6981 seconds, Epoch [11/200], Step [200/853], d_loss: 0.0022, g_loss: 0.4898
# Elapsed time: 2299.6903 seconds, Epoch [11/200], Step [300/853], d_loss: 0.0047, g_loss: 0.5349
# Elapsed time: 2325.8157 seconds, Epoch [11/200], Step [400/853], d_loss: 0.0028, g_loss: 0.3363
# Elapsed time: 2351.8524 seconds, Epoch [11/200], Step [500/853], d_loss: 0.0043, g_loss: 0.2864
# Elapsed time: 2377.8067 seconds, Epoch [11/200], Step [600/853], d_loss: 0.0031, g_loss: 0.3735
# Elapsed time: 2403.7948 seconds, Epoch [11/200], Step [700/853], d_loss: 0.0008, g_loss: 0.4562
# Elapsed time: 2429.7862 seconds, Epoch [11/200], Step [800/853], d_loss: 0.0006, g_loss: 0.3895
# Elapsed time: 2469.6836 seconds, Epoch [12/200], Step [100/853], d_loss: 0.0009, g_loss: 0.2486
# Elapsed time: 2495.7306 seconds, Epoch [12/200], Step [200/853], d_loss: 0.0066, g_loss: 0.5763
# Elapsed time: 2521.7199 seconds, Epoch [12/200], Step [300/853], d_loss: 0.0004, g_loss: 0.2684
# Elapsed time: 2547.8621 seconds, Epoch [12/200], Step [400/853], d_loss: 0.0009, g_loss: 0.4769
# Elapsed time: 2573.9437 seconds, Epoch [12/200], Step [500/853], d_loss: 0.0007, g_loss: 0.3828
# Elapsed time: 2600.0479 seconds, Epoch [12/200], Step [600/853], d_loss: 0.0020, g_loss: 0.2878
# Elapsed time: 2626.0990 seconds, Epoch [12/200], Step [700/853], d_loss: 0.0028, g_loss: 0.5935
# Elapsed time: 2652.0798 seconds, Epoch [12/200], Step [800/853], d_loss: 0.0018, g_loss: 0.5210
# Elapsed time: 2692.2612 seconds, Epoch [13/200], Step [100/853], d_loss: 0.0009, g_loss: 0.3152
# Elapsed time: 2718.5885 seconds, Epoch [13/200], Step [200/853], d_loss: 0.0032, g_loss: 0.3731
# Elapsed time: 2744.6134 seconds, Epoch [13/200], Step [300/853], d_loss: 0.0009, g_loss: 0.3452
# Elapsed time: 2770.6831 seconds, Epoch [13/200], Step [400/853], d_loss: 0.0006, g_loss: 0.2458
# Elapsed time: 2796.8900 seconds, Epoch [13/200], Step [500/853], d_loss: 0.0004, g_loss: 0.3034
# Elapsed time: 2822.9558 seconds, Epoch [13/200], Step [600/853], d_loss: 0.0017, g_loss: 0.3323
# Elapsed time: 2849.0244 seconds, Epoch [13/200], Step [700/853], d_loss: 0.0005, g_loss: 0.2542
# Elapsed time: 2875.2087 seconds, Epoch [13/200], Step [800/853], d_loss: 0.0006, g_loss: 0.3293
# Elapsed time: 2915.0572 seconds, Epoch [14/200], Step [100/853], d_loss: 0.0032, g_loss: 0.3215
# Elapsed time: 2941.0669 seconds, Epoch [14/200], Step [200/853], d_loss: 0.0035, g_loss: 0.4424
# Elapsed time: 2967.1096 seconds, Epoch [14/200], Step [300/853], d_loss: 0.0013, g_loss: 0.3382
# Elapsed time: 2993.3181 seconds, Epoch [14/200], Step [400/853], d_loss: 0.0010, g_loss: 0.3303
# Elapsed time: 3019.4190 seconds, Epoch [14/200], Step [500/853], d_loss: 0.0003, g_loss: 0.6087
# Elapsed time: 3045.6001 seconds, Epoch [14/200], Step [600/853], d_loss: 0.0015, g_loss: 0.4930
# Elapsed time: 3071.5414 seconds, Epoch [14/200], Step [700/853], d_loss: 0.0007, g_loss: 0.5555
# Elapsed time: 3097.5825 seconds, Epoch [14/200], Step [800/853], d_loss: 0.0014, g_loss: 0.2746
# Elapsed time: 3137.4351 seconds, Epoch [15/200], Step [100/853], d_loss: 0.0006, g_loss: 0.4723
# Elapsed time: 3163.6227 seconds, Epoch [15/200], Step [200/853], d_loss: 0.0011, g_loss: 0.4659
# Elapsed time: 3189.5509 seconds, Epoch [15/200], Step [300/853], d_loss: 0.0005, g_loss: 0.5467
# Elapsed time: 3215.5503 seconds, Epoch [15/200], Step [400/853], d_loss: 0.0008, g_loss: 0.3656
# Elapsed time: 3241.6510 seconds, Epoch [15/200], Step [500/853], d_loss: 0.0007, g_loss: 0.4198
# Elapsed time: 3267.6742 seconds, Epoch [15/200], Step [600/853], d_loss: 0.0023, g_loss: 0.4428
# Elapsed time: 3293.7524 seconds, Epoch [15/200], Step [700/853], d_loss: 0.0006, g_loss: 0.7288
# Elapsed time: 3319.5468 seconds, Epoch [15/200], Step [800/853], d_loss: 0.0010, g_loss: 0.4598
# Elapsed time: 3359.0780 seconds, Epoch [16/200], Step [100/853], d_loss: 0.0004, g_loss: 0.3276
# Elapsed time: 3384.9476 seconds, Epoch [16/200], Step [200/853], d_loss: 0.0021, g_loss: 0.3644
# Elapsed time: 3411.0156 seconds, Epoch [16/200], Step [300/853], d_loss: 0.0013, g_loss: 0.6932
# Elapsed time: 3437.2419 seconds, Epoch [16/200], Step [400/853], d_loss: 0.0013, g_loss: 0.3716
# Elapsed time: 3463.2753 seconds, Epoch [16/200], Step [500/853], d_loss: 0.0006, g_loss: 0.3426
# Elapsed time: 3489.3119 seconds, Epoch [16/200], Step [600/853], d_loss: 0.0008, g_loss: 0.5830
# Elapsed time: 3515.4909 seconds, Epoch [16/200], Step [700/853], d_loss: 0.0002, g_loss: 0.3848
# Elapsed time: 3541.5376 seconds, Epoch [16/200], Step [800/853], d_loss: 0.0004, g_loss: 0.3638
# Elapsed time: 3581.5319 seconds, Epoch [17/200], Step [100/853], d_loss: 0.0012, g_loss: 0.3320
# Elapsed time: 3607.8334 seconds, Epoch [17/200], Step [200/853], d_loss: 0.0008, g_loss: 0.3799
# Elapsed time: 3633.8836 seconds, Epoch [17/200], Step [300/853], d_loss: 0.0005, g_loss: 0.3845
# Elapsed time: 3660.0295 seconds, Epoch [17/200], Step [400/853], d_loss: 0.0005, g_loss: 0.3727
# Elapsed time: 3686.2008 seconds, Epoch [17/200], Step [500/853], d_loss: 0.0009, g_loss: 0.4954
# Elapsed time: 3712.2411 seconds, Epoch [17/200], Step [600/853], d_loss: 0.0071, g_loss: 0.3366
# Elapsed time: 3738.1195 seconds, Epoch [17/200], Step [700/853], d_loss: 0.0007, g_loss: 0.5339
# Elapsed time: 3764.2157 seconds, Epoch [17/200], Step [800/853], d_loss: 0.0006, g_loss: 0.4136
# Elapsed time: 3804.0238 seconds, Epoch [18/200], Step [100/853], d_loss: 0.0005, g_loss: 0.3627
# Elapsed time: 3830.1306 seconds, Epoch [18/200], Step [200/853], d_loss: 0.0017, g_loss: 0.4926
# Elapsed time: 3856.2124 seconds, Epoch [18/200], Step [300/853], d_loss: 0.0045, g_loss: 0.4867
# Elapsed time: 3882.3212 seconds, Epoch [18/200], Step [400/853], d_loss: 0.0003, g_loss: 0.3257
# Elapsed time: 3908.3603 seconds, Epoch [18/200], Step [500/853], d_loss: 0.0003, g_loss: 0.3890
# Elapsed time: 3934.3902 seconds, Epoch [18/200], Step [600/853], d_loss: 0.0019, g_loss: 0.3508
# Elapsed time: 3960.3043 seconds, Epoch [18/200], Step [700/853], d_loss: 0.0011, g_loss: 0.5722
# Elapsed time: 3986.4068 seconds, Epoch [18/200], Step [800/853], d_loss: 0.0002, g_loss: 0.2592
# Elapsed time: 4025.8902 seconds, Epoch [19/200], Step [100/853], d_loss: 0.0048, g_loss: 0.4194
# Elapsed time: 4051.8269 seconds, Epoch [19/200], Step [200/853], d_loss: 0.0003, g_loss: 0.5034
# Elapsed time: 4077.9030 seconds, Epoch [19/200], Step [300/853], d_loss: 0.0006, g_loss: 0.1890
# Elapsed time: 4104.0975 seconds, Epoch [19/200], Step [400/853], d_loss: 0.0020, g_loss: 0.4249
# Elapsed time: 4130.1035 seconds, Epoch [19/200], Step [500/853], d_loss: 0.0005, g_loss: 0.5705
# Elapsed time: 4156.0614 seconds, Epoch [19/200], Step [600/853], d_loss: 0.0006, g_loss: 0.2433
# Elapsed time: 4181.9585 seconds, Epoch [19/200], Step [700/853], d_loss: 0.0011, g_loss: 0.3107
# Elapsed time: 4207.7601 seconds, Epoch [19/200], Step [800/853], d_loss: 0.0007, g_loss: 0.5865
# Elapsed time: 4247.4506 seconds, Epoch [20/200], Step [100/853], d_loss: 0.0020, g_loss: 0.3381
# Elapsed time: 4273.7405 seconds, Epoch [20/200], Step [200/853], d_loss: 0.0003, g_loss: 0.2367
# Elapsed time: 4299.6524 seconds, Epoch [20/200], Step [300/853], d_loss: 0.0187, g_loss: 0.4090
# Elapsed time: 4325.8944 seconds, Epoch [20/200], Step [400/853], d_loss: 0.0035, g_loss: 0.4290
# Elapsed time: 4351.9753 seconds, Epoch [20/200], Step [500/853], d_loss: 0.0004, g_loss: 0.3207
# Elapsed time: 4377.9237 seconds, Epoch [20/200], Step [600/853], d_loss: 0.0006, g_loss: 0.4827
# Elapsed time: 4404.1396 seconds, Epoch [20/200], Step [700/853], d_loss: 0.0003, g_loss: 0.3315
# Elapsed time: 4430.1214 seconds, Epoch [20/200], Step [800/853], d_loss: 0.0002, g_loss: 0.3186
# Elapsed time: 4469.8726 seconds, Epoch [21/200], Step [100/853], d_loss: 0.0007, g_loss: 0.5294
# Elapsed time: 4496.0217 seconds, Epoch [21/200], Step [200/853], d_loss: 0.0005, g_loss: 0.5415
# Elapsed time: 4522.1153 seconds, Epoch [21/200], Step [300/853], d_loss: 0.0005, g_loss: 0.5642
# Elapsed time: 4548.5588 seconds, Epoch [21/200], Step [400/853], d_loss: 0.0002, g_loss: 0.3985
# Elapsed time: 4574.5046 seconds, Epoch [21/200], Step [500/853], d_loss: 0.0001, g_loss: 0.4441
# Elapsed time: 4600.4134 seconds, Epoch [21/200], Step [600/853], d_loss: 0.0001, g_loss: 0.2525
# Elapsed time: 4626.3952 seconds, Epoch [21/200], Step [700/853], d_loss: 0.0002, g_loss: 0.5063
# Elapsed time: 4652.5141 seconds, Epoch [21/200], Step [800/853], d_loss: 0.0003, g_loss: 0.3723
# Elapsed time: 4692.3806 seconds, Epoch [22/200], Step [100/853], d_loss: 0.0007, g_loss: 0.3286
# Elapsed time: 4718.4992 seconds, Epoch [22/200], Step [200/853], d_loss: 0.0041, g_loss: 0.2793
# Elapsed time: 4744.4789 seconds, Epoch [22/200], Step [300/853], d_loss: 0.0019, g_loss: 0.2433
# Elapsed time: 4770.6828 seconds, Epoch [22/200], Step [400/853], d_loss: 0.0001, g_loss: 0.2796
# Elapsed time: 4796.6802 seconds, Epoch [22/200], Step [500/853], d_loss: 0.0009, g_loss: 0.3713
# Elapsed time: 4822.4843 seconds, Epoch [22/200], Step [600/853], d_loss: 0.0003, g_loss: 0.5266
# Elapsed time: 4848.5153 seconds, Epoch [22/200], Step [700/853], d_loss: 0.0005, g_loss: 0.5045
# Elapsed time: 4874.4182 seconds, Epoch [22/200], Step [800/853], d_loss: 0.0004, g_loss: 0.4084
# Elapsed time: 4914.0885 seconds, Epoch [23/200], Step [100/853], d_loss: 0.0002, g_loss: 0.3317
# Elapsed time: 4940.1190 seconds, Epoch [23/200], Step [200/853], d_loss: 0.0016, g_loss: 0.3017
# Elapsed time: 4966.0434 seconds, Epoch [23/200], Step [300/853], d_loss: 0.0003, g_loss: 0.3158
# Elapsed time: 4992.0139 seconds, Epoch [23/200], Step [400/853], d_loss: 0.0004, g_loss: 0.3246
# Elapsed time: 5017.8790 seconds, Epoch [23/200], Step [500/853], d_loss: 0.0004, g_loss: 0.3278
# Elapsed time: 5044.0011 seconds, Epoch [23/200], Step [600/853], d_loss: 0.0004, g_loss: 0.2994
# Elapsed time: 5070.0635 seconds, Epoch [23/200], Step [700/853], d_loss: 0.0006, g_loss: 0.3870
# Elapsed time: 5095.9911 seconds, Epoch [23/200], Step [800/853], d_loss: 0.0001, g_loss: 0.5065
# Elapsed time: 5135.9086 seconds, Epoch [24/200], Step [100/853], d_loss: 0.0018, g_loss: 0.2923
# Elapsed time: 5161.8876 seconds, Epoch [24/200], Step [200/853], d_loss: 0.0003, g_loss: 0.5945
# Elapsed time: 5187.8771 seconds, Epoch [24/200], Step [300/853], d_loss: 0.0003, g_loss: 0.4070
# Elapsed time: 5213.9906 seconds, Epoch [24/200], Step [400/853], d_loss: 0.0014, g_loss: 0.4379
# Elapsed time: 5239.8763 seconds, Epoch [24/200], Step [500/853], d_loss: 0.0005, g_loss: 0.3471
# Elapsed time: 5266.1890 seconds, Epoch [24/200], Step [600/853], d_loss: 0.0003, g_loss: 0.3387
# Elapsed time: 5292.1376 seconds, Epoch [24/200], Step [700/853], d_loss: 0.0015, g_loss: 0.3272
# Elapsed time: 5318.1861 seconds, Epoch [24/200], Step [800/853], d_loss: 0.0003, g_loss: 0.3050
# Elapsed time: 5358.0348 seconds, Epoch [25/200], Step [100/853], d_loss: 0.0004, g_loss: 0.4612
# Elapsed time: 5383.9833 seconds, Epoch [25/200], Step [200/853], d_loss: 0.0001, g_loss: 0.2415
# Elapsed time: 5409.8746 seconds, Epoch [25/200], Step [300/853], d_loss: 0.0001, g_loss: 0.2014
# Elapsed time: 5436.1952 seconds, Epoch [25/200], Step [400/853], d_loss: 0.0003, g_loss: 0.2077
# Elapsed time: 5462.1803 seconds, Epoch [25/200], Step [500/853], d_loss: 0.0003, g_loss: 0.2806
# Elapsed time: 5488.2600 seconds, Epoch [25/200], Step [600/853], d_loss: 0.0001, g_loss: 0.3999
# Elapsed time: 5514.3115 seconds, Epoch [25/200], Step [700/853], d_loss: 0.0001, g_loss: 0.3333
# Elapsed time: 5540.3587 seconds, Epoch [25/200], Step [800/853], d_loss: 0.0002, g_loss: 0.3935
# Elapsed time: 5580.3277 seconds, Epoch [26/200], Step [100/853], d_loss: 0.0009, g_loss: 0.3438
# Elapsed time: 5606.3855 seconds, Epoch [26/200], Step [200/853], d_loss: 0.0349, g_loss: 0.3737
# Elapsed time: 5632.4068 seconds, Epoch [26/200], Step [300/853], d_loss: 0.0041, g_loss: 0.3092
# Elapsed time: 5658.5503 seconds, Epoch [26/200], Step [400/853], d_loss: 0.0012, g_loss: 0.5962
# Elapsed time: 5684.5654 seconds, Epoch [26/200], Step [500/853], d_loss: 0.0006, g_loss: 0.3264
# Elapsed time: 5710.4230 seconds, Epoch [26/200], Step [600/853], d_loss: 0.0012, g_loss: 0.3153
# Elapsed time: 5736.4897 seconds, Epoch [26/200], Step [700/853], d_loss: 0.0008, g_loss: 0.3990
# Elapsed time: 5762.5403 seconds, Epoch [26/200], Step [800/853], d_loss: 0.0004, g_loss: 0.2946
# Elapsed time: 5802.4963 seconds, Epoch [27/200], Step [100/853], d_loss: 0.0005, g_loss: 0.4521
# Elapsed time: 5828.5009 seconds, Epoch [27/200], Step [200/853], d_loss: 0.0003, g_loss: 0.2714
# Elapsed time: 5854.5786 seconds, Epoch [27/200], Step [300/853], d_loss: 0.0006, g_loss: 0.4807
# Elapsed time: 5880.6015 seconds, Epoch [27/200], Step [400/853], d_loss: 0.0023, g_loss: 0.3233
# Elapsed time: 5906.7049 seconds, Epoch [27/200], Step [500/853], d_loss: 0.0003, g_loss: 0.4286
# Elapsed time: 5932.7916 seconds, Epoch [27/200], Step [600/853], d_loss: 0.0003, g_loss: 0.5490
# Elapsed time: 5958.9152 seconds, Epoch [27/200], Step [700/853], d_loss: 0.0003, g_loss: 0.3258
# Elapsed time: 5985.0025 seconds, Epoch [27/200], Step [800/853], d_loss: 0.0013, g_loss: 0.3169
# Elapsed time: 6024.8942 seconds, Epoch [28/200], Step [100/853], d_loss: 0.0006, g_loss: 0.3735
# Elapsed time: 6050.9292 seconds, Epoch [28/200], Step [200/853], d_loss: 0.0004, g_loss: 0.2879
# Elapsed time: 6076.8769 seconds, Epoch [28/200], Step [300/853], d_loss: 0.0012, g_loss: 0.5336
# Elapsed time: 6102.8852 seconds, Epoch [28/200], Step [400/853], d_loss: 0.0011, g_loss: 0.6802
# Elapsed time: 6128.9996 seconds, Epoch [28/200], Step [500/853], d_loss: 0.0002, g_loss: 0.3100
# Elapsed time: 6155.0082 seconds, Epoch [28/200], Step [600/853], d_loss: 0.0006, g_loss: 0.3616
# Elapsed time: 6181.3097 seconds, Epoch [28/200], Step [700/853], d_loss: 0.0007, g_loss: 0.2597
# Elapsed time: 6207.4699 seconds, Epoch [28/200], Step [800/853], d_loss: 0.0012, g_loss: 0.4893
# Elapsed time: 6247.3803 seconds, Epoch [29/200], Step [100/853], d_loss: 0.0002, g_loss: 0.3513
# Elapsed time: 6273.3718 seconds, Epoch [29/200], Step [200/853], d_loss: 0.0003, g_loss: 0.3542
# Elapsed time: 6299.4262 seconds, Epoch [29/200], Step [300/853], d_loss: 0.0013, g_loss: 0.3244
# Elapsed time: 6325.6815 seconds, Epoch [29/200], Step [400/853], d_loss: 0.0005, g_loss: 0.3371
# Elapsed time: 6351.6893 seconds, Epoch [29/200], Step [500/853], d_loss: 0.0003, g_loss: 0.3377
# Elapsed time: 6377.7363 seconds, Epoch [29/200], Step [600/853], d_loss: 0.0004, g_loss: 0.5103
# Elapsed time: 6403.7968 seconds, Epoch [29/200], Step [700/853], d_loss: 0.0008, g_loss: 0.4517
# Elapsed time: 6429.8692 seconds, Epoch [29/200], Step [800/853], d_loss: 0.0002, g_loss: 0.4002
# Elapsed time: 6469.7255 seconds, Epoch [30/200], Step [100/853], d_loss: 0.0006, g_loss: 0.2753
# Elapsed time: 6495.6022 seconds, Epoch [30/200], Step [200/853], d_loss: 0.0003, g_loss: 0.4838
# Elapsed time: 6521.6513 seconds, Epoch [30/200], Step [300/853], d_loss: 0.0003, g_loss: 0.2259
# Elapsed time: 6547.5014 seconds, Epoch [30/200], Step [400/853], d_loss: 0.0009, g_loss: 0.4247
# Elapsed time: 6573.8998 seconds, Epoch [30/200], Step [500/853], d_loss: 0.0005, g_loss: 0.4213
# Elapsed time: 6599.8678 seconds, Epoch [30/200], Step [600/853], d_loss: 0.0021, g_loss: 0.3187
# Elapsed time: 6626.1426 seconds, Epoch [30/200], Step [700/853], d_loss: 0.0002, g_loss: 0.4055
# Elapsed time: 6652.1464 seconds, Epoch [30/200], Step [800/853], d_loss: 0.0002, g_loss: 0.2830
# Elapsed time: 6691.6563 seconds, Epoch [31/200], Step [100/853], d_loss: 0.0003, g_loss: 0.5925
# Elapsed time: 6717.7554 seconds, Epoch [31/200], Step [200/853], d_loss: 0.0019, g_loss: 0.3569
# Elapsed time: 6743.7845 seconds, Epoch [31/200], Step [300/853], d_loss: 0.0003, g_loss: 0.3174
# Elapsed time: 6769.7761 seconds, Epoch [31/200], Step [400/853], d_loss: 0.0002, g_loss: 0.3641
# Elapsed time: 6795.8094 seconds, Epoch [31/200], Step [500/853], d_loss: 0.0001, g_loss: 0.3754
# Elapsed time: 6821.8416 seconds, Epoch [31/200], Step [600/853], d_loss: 0.0001, g_loss: 0.2380
# Elapsed time: 6847.8895 seconds, Epoch [31/200], Step [700/853], d_loss: 0.0005, g_loss: 0.4215
# Elapsed time: 6873.8319 seconds, Epoch [31/200], Step [800/853], d_loss: 0.0001, g_loss: 0.3056
# Elapsed time: 6913.4332 seconds, Epoch [32/200], Step [100/853], d_loss: 0.0002, g_loss: 0.3899
# Elapsed time: 6939.6791 seconds, Epoch [32/200], Step [200/853], d_loss: 0.0004, g_loss: 0.4379
# Elapsed time: 6965.4157 seconds, Epoch [32/200], Step [300/853], d_loss: 0.0004, g_loss: 0.5629
# Elapsed time: 6991.3771 seconds, Epoch [32/200], Step [400/853], d_loss: 0.0013, g_loss: 0.4092
# Elapsed time: 7017.4102 seconds, Epoch [32/200], Step [500/853], d_loss: 0.0005, g_loss: 0.5642
# Elapsed time: 7043.2984 seconds, Epoch [32/200], Step [600/853], d_loss: 0.0002, g_loss: 0.6014
# Elapsed time: 7069.2043 seconds, Epoch [32/200], Step [700/853], d_loss: 0.0074, g_loss: 0.3487
# Elapsed time: 7095.1433 seconds, Epoch [32/200], Step [800/853], d_loss: 0.0022, g_loss: 0.5376
# Elapsed time: 7134.7970 seconds, Epoch [33/200], Step [100/853], d_loss: 0.0002, g_loss: 0.3902
# Elapsed time: 7160.8712 seconds, Epoch [33/200], Step [200/853], d_loss: 0.0004, g_loss: 0.5390
# Elapsed time: 7186.8455 seconds, Epoch [33/200], Step [300/853], d_loss: 0.0008, g_loss: 0.3638
# Elapsed time: 7212.7668 seconds, Epoch [33/200], Step [400/853], d_loss: 0.0003, g_loss: 0.3299
# Elapsed time: 7238.6978 seconds, Epoch [33/200], Step [500/853], d_loss: 0.0003, g_loss: 0.3823
# Elapsed time: 7264.7832 seconds, Epoch [33/200], Step [600/853], d_loss: 0.0003, g_loss: 0.2980
# Elapsed time: 7290.7604 seconds, Epoch [33/200], Step [700/853], d_loss: 0.0003, g_loss: 0.3617
# Elapsed time: 7316.7113 seconds, Epoch [33/200], Step [800/853], d_loss: 0.0014, g_loss: 0.2596
# Elapsed time: 7356.2657 seconds, Epoch [34/200], Step [100/853], d_loss: 0.0014, g_loss: 0.3802
# Elapsed time: 7382.2523 seconds, Epoch [34/200], Step [200/853], d_loss: 0.0002, g_loss: 0.3920
# Elapsed time: 7408.2591 seconds, Epoch [34/200], Step [300/853], d_loss: 0.0001, g_loss: 0.3507
# Elapsed time: 7434.1556 seconds, Epoch [34/200], Step [400/853], d_loss: 0.0015, g_loss: 0.2932
# Elapsed time: 7460.2663 seconds, Epoch [34/200], Step [500/853], d_loss: 0.0001, g_loss: 0.4017
# Elapsed time: 7486.2238 seconds, Epoch [34/200], Step [600/853], d_loss: 0.0001, g_loss: 0.3213
# Elapsed time: 7512.2470 seconds, Epoch [34/200], Step [700/853], d_loss: 0.0044, g_loss: 0.3300
# Elapsed time: 7538.1565 seconds, Epoch [34/200], Step [800/853], d_loss: 0.0023, g_loss: 0.3020
# Elapsed time: 7577.9183 seconds, Epoch [35/200], Step [100/853], d_loss: 0.0002, g_loss: 0.2412
# Elapsed time: 7603.9635 seconds, Epoch [35/200], Step [200/853], d_loss: 0.0001, g_loss: 0.3532
# Elapsed time: 7629.9585 seconds, Epoch [35/200], Step [300/853], d_loss: 0.0002, g_loss: 0.3591
# Elapsed time: 7655.9560 seconds, Epoch [35/200], Step [400/853], d_loss: 0.0002, g_loss: 0.3241
# Elapsed time: 7682.0554 seconds, Epoch [35/200], Step [500/853], d_loss: 0.0001, g_loss: 0.5008
# Elapsed time: 7708.1712 seconds, Epoch [35/200], Step [600/853], d_loss: 0.0008, g_loss: 0.4727
# Elapsed time: 7734.3020 seconds, Epoch [35/200], Step [700/853], d_loss: 0.0002, g_loss: 0.3618
# Elapsed time: 7760.2250 seconds, Epoch [35/200], Step [800/853], d_loss: 0.0004, g_loss: 0.3226
# Elapsed time: 7799.8843 seconds, Epoch [36/200], Step [100/853], d_loss: 0.0001, g_loss: 0.3672
# Elapsed time: 7826.1759 seconds, Epoch [36/200], Step [200/853], d_loss: 0.0004, g_loss: 0.3974
# Elapsed time: 7852.0954 seconds, Epoch [36/200], Step [300/853], d_loss: 0.0001, g_loss: 0.3987
# Elapsed time: 7878.0437 seconds, Epoch [36/200], Step [400/853], d_loss: 0.0034, g_loss: 0.3841
# Elapsed time: 7904.0093 seconds, Epoch [36/200], Step [500/853], d_loss: 0.0003, g_loss: 0.3745
# Elapsed time: 7929.8864 seconds, Epoch [36/200], Step [600/853], d_loss: 0.0001, g_loss: 0.5082
# Elapsed time: 7955.9896 seconds, Epoch [36/200], Step [700/853], d_loss: 0.0002, g_loss: 0.4127
# Elapsed time: 7981.8820 seconds, Epoch [36/200], Step [800/853], d_loss: 0.0011, g_loss: 0.3240
# Elapsed time: 8021.5744 seconds, Epoch [37/200], Step [100/853], d_loss: 0.0005, g_loss: 0.4688
# Elapsed time: 8048.0063 seconds, Epoch [37/200], Step [200/853], d_loss: 0.0003, g_loss: 0.2486
# Elapsed time: 8074.2049 seconds, Epoch [37/200], Step [300/853], d_loss: 0.0001, g_loss: 0.3524
# Elapsed time: 8100.1248 seconds, Epoch [37/200], Step [400/853], d_loss: 0.0004, g_loss: 0.3123
# Elapsed time: 8126.0649 seconds, Epoch [37/200], Step [500/853], d_loss: 0.0003, g_loss: 0.3803
# Elapsed time: 8152.1964 seconds, Epoch [37/200], Step [600/853], d_loss: 0.0001, g_loss: 0.5753
# Elapsed time: 8178.1364 seconds, Epoch [37/200], Step [700/853], d_loss: 0.0001, g_loss: 0.3488
# Elapsed time: 8204.0944 seconds, Epoch [37/200], Step [800/853], d_loss: 0.0003, g_loss: 0.2797
# Elapsed time: 8243.8880 seconds, Epoch [38/200], Step [100/853], d_loss: 0.0007, g_loss: 0.2641
# Elapsed time: 8269.8707 seconds, Epoch [38/200], Step [200/853], d_loss: 0.0005, g_loss: 0.3592
# Elapsed time: 8295.8669 seconds, Epoch [38/200], Step [300/853], d_loss: 0.0004, g_loss: 0.3712
# Elapsed time: 8321.8622 seconds, Epoch [38/200], Step [400/853], d_loss: 0.0003, g_loss: 0.2480
# Elapsed time: 8347.8142 seconds, Epoch [38/200], Step [500/853], d_loss: 0.0001, g_loss: 0.4656
# Elapsed time: 8373.8399 seconds, Epoch [38/200], Step [600/853], d_loss: 0.0001, g_loss: 0.3403
# Elapsed time: 8400.1789 seconds, Epoch [38/200], Step [700/853], d_loss: 0.0009, g_loss: 0.2713
# Elapsed time: 8426.4007 seconds, Epoch [38/200], Step [800/853], d_loss: 0.0007, g_loss: 0.2432
# Elapsed time: 8466.2762 seconds, Epoch [39/200], Step [100/853], d_loss: 0.0006, g_loss: 0.4596
# Elapsed time: 8492.2567 seconds, Epoch [39/200], Step [200/853], d_loss: 0.0000, g_loss: 0.2607
# Elapsed time: 8518.6531 seconds, Epoch [39/200], Step [300/853], d_loss: 0.0001, g_loss: 0.5720
# Elapsed time: 8544.6984 seconds, Epoch [39/200], Step [400/853], d_loss: 0.0001, g_loss: 0.2032
# Elapsed time: 8570.5450 seconds, Epoch [39/200], Step [500/853], d_loss: 0.0002, g_loss: 0.4035
# Elapsed time: 8596.5935 seconds, Epoch [39/200], Step [600/853], d_loss: 0.0002, g_loss: 0.3354
# Elapsed time: 8622.5608 seconds, Epoch [39/200], Step [700/853], d_loss: 0.0006, g_loss: 0.3646
# Elapsed time: 8648.8241 seconds, Epoch [39/200], Step [800/853], d_loss: 0.0001, g_loss: 0.4268
# Elapsed time: 8688.7538 seconds, Epoch [40/200], Step [100/853], d_loss: 0.0000, g_loss: 0.2971
# Elapsed time: 8714.8104 seconds, Epoch [40/200], Step [200/853], d_loss: 0.0006, g_loss: 0.3801
# Elapsed time: 8740.7091 seconds, Epoch [40/200], Step [300/853], d_loss: 0.0000, g_loss: 0.2501
# Elapsed time: 8766.6841 seconds, Epoch [40/200], Step [400/853], d_loss: 0.0015, g_loss: 0.3411
# Elapsed time: 8792.5818 seconds, Epoch [40/200], Step [500/853], d_loss: 0.0006, g_loss: 0.4951
# Elapsed time: 8818.6641 seconds, Epoch [40/200], Step [600/853], d_loss: 0.0001, g_loss: 0.2783
# Elapsed time: 8844.8643 seconds, Epoch [40/200], Step [700/853], d_loss: 0.0001, g_loss: 0.3247
# Elapsed time: 8870.9389 seconds, Epoch [40/200], Step [800/853], d_loss: 0.0001, g_loss: 0.3460
# Elapsed time: 8910.7506 seconds, Epoch [41/200], Step [100/853], d_loss: 0.0001, g_loss: 0.5703
# Elapsed time: 8937.0636 seconds, Epoch [41/200], Step [200/853], d_loss: 0.0001, g_loss: 0.5374
# Elapsed time: 8963.1710 seconds, Epoch [41/200], Step [300/853], d_loss: 0.0002, g_loss: 0.5745
# Elapsed time: 8989.2367 seconds, Epoch [41/200], Step [400/853], d_loss: 0.0001, g_loss: 0.4941
# Elapsed time: 9015.2155 seconds, Epoch [41/200], Step [500/853], d_loss: 0.0001, g_loss: 0.5888
# Elapsed time: 9041.1380 seconds, Epoch [41/200], Step [600/853], d_loss: 0.0005, g_loss: 0.4844
# Elapsed time: 9067.2433 seconds, Epoch [41/200], Step [700/853], d_loss: 0.0007, g_loss: 0.3104
# Elapsed time: 9093.2724 seconds, Epoch [41/200], Step [800/853], d_loss: 0.0003, g_loss: 0.3427
# Elapsed time: 9133.1969 seconds, Epoch [42/200], Step [100/853], d_loss: 0.0001, g_loss: 0.3971
# Elapsed time: 9159.3180 seconds, Epoch [42/200], Step [200/853], d_loss: 0.0000, g_loss: 0.4567
# Elapsed time: 9185.3453 seconds, Epoch [42/200], Step [300/853], d_loss: 0.0001, g_loss: 0.3005
# Elapsed time: 9211.1924 seconds, Epoch [42/200], Step [400/853], d_loss: 0.0001, g_loss: 0.3336
# Elapsed time: 9237.1940 seconds, Epoch [42/200], Step [500/853], d_loss: 0.0012, g_loss: 0.4812
# Elapsed time: 9263.2543 seconds, Epoch [42/200], Step [600/853], d_loss: 0.0000, g_loss: 0.3705
# Elapsed time: 9289.2638 seconds, Epoch [42/200], Step [700/853], d_loss: 0.0001, g_loss: 0.4279
# Elapsed time: 9315.3255 seconds, Epoch [42/200], Step [800/853], d_loss: 0.0003, g_loss: 0.3868
# Elapsed time: 9355.4225 seconds, Epoch [43/200], Step [100/853], d_loss: 0.0001, g_loss: 0.3512
# Elapsed time: 9381.6438 seconds, Epoch [43/200], Step [200/853], d_loss: 0.0002, g_loss: 0.3464
# Elapsed time: 9407.5755 seconds, Epoch [43/200], Step [300/853], d_loss: 0.0001, g_loss: 0.2446
# Elapsed time: 9433.4205 seconds, Epoch [43/200], Step [400/853], d_loss: 0.0001, g_loss: 0.2828
# Elapsed time: 9459.3256 seconds, Epoch [43/200], Step [500/853], d_loss: 0.0002, g_loss: 0.3950
# Elapsed time: 9485.4699 seconds, Epoch [43/200], Step [600/853], d_loss: 0.0001, g_loss: 0.3551
# Elapsed time: 9511.6533 seconds, Epoch [43/200], Step [700/853], d_loss: 0.0000, g_loss: 0.4682
# Elapsed time: 9537.6002 seconds, Epoch [43/200], Step [800/853], d_loss: 0.0004, g_loss: 0.3872
# Elapsed time: 9577.4058 seconds, Epoch [44/200], Step [100/853], d_loss: 0.0001, g_loss: 0.3491
# Elapsed time: 9603.4825 seconds, Epoch [44/200], Step [200/853], d_loss: 0.0004, g_loss: 0.4588
# Elapsed time: 9629.3318 seconds, Epoch [44/200], Step [300/853], d_loss: 0.0002, g_loss: 0.3952
# Elapsed time: 9655.2689 seconds, Epoch [44/200], Step [400/853], d_loss: 0.0001, g_loss: 0.2958
# Elapsed time: 9681.2487 seconds, Epoch [44/200], Step [500/853], d_loss: 0.0001, g_loss: 0.2887
# Elapsed time: 9707.3337 seconds, Epoch [44/200], Step [600/853], d_loss: 0.0001, g_loss: 0.2387
# Elapsed time: 9733.3386 seconds, Epoch [44/200], Step [700/853], d_loss: 0.0001, g_loss: 0.2891
# Elapsed time: 9759.2434 seconds, Epoch [44/200], Step [800/853], d_loss: 0.0002, g_loss: 0.4161
# Elapsed time: 9799.3500 seconds, Epoch [45/200], Step [100/853], d_loss: 0.0001, g_loss: 0.3382
# Elapsed time: 9825.3318 seconds, Epoch [45/200], Step [200/853], d_loss: 0.0005, g_loss: 0.3901
# Elapsed time: 9851.2722 seconds, Epoch [45/200], Step [300/853], d_loss: 0.0008, g_loss: 0.4619
# Elapsed time: 9877.2111 seconds, Epoch [45/200], Step [400/853], d_loss: 0.0001, g_loss: 0.3934
# Elapsed time: 9903.2350 seconds, Epoch [45/200], Step [500/853], d_loss: 0.0017, g_loss: 0.3157
# Elapsed time: 9929.1905 seconds, Epoch [45/200], Step [600/853], d_loss: 0.0001, g_loss: 0.3252
# Elapsed time: 9955.1818 seconds, Epoch [45/200], Step [700/853], d_loss: 0.0020, g_loss: 0.4845
# Elapsed time: 9981.2091 seconds, Epoch [45/200], Step [800/853], d_loss: 0.0000, g_loss: 0.5207
# Elapsed time: 10020.5518 seconds, Epoch [46/200], Step [100/853], d_loss: 0.0005, g_loss: 0.2014
# Elapsed time: 10046.3288 seconds, Epoch [46/200], Step [200/853], d_loss: 0.0001, g_loss: 0.6241
# Elapsed time: 10072.3094 seconds, Epoch [46/200], Step [300/853], d_loss: 0.0002, g_loss: 0.3007
# Elapsed time: 10098.3048 seconds, Epoch [46/200], Step [400/853], d_loss: 0.0001, g_loss: 0.1767
# Elapsed time: 10124.2768 seconds, Epoch [46/200], Step [500/853], d_loss: 0.0002, g_loss: 0.5935
# Elapsed time: 10150.2775 seconds, Epoch [46/200], Step [600/853], d_loss: 0.0000, g_loss: 0.3442
# Elapsed time: 10176.5376 seconds, Epoch [46/200], Step [700/853], d_loss: 0.0013, g_loss: 0.4050
# Elapsed time: 10202.7636 seconds, Epoch [46/200], Step [800/853], d_loss: 0.0007, g_loss: 0.3647
# Elapsed time: 10242.5427 seconds, Epoch [47/200], Step [100/853], d_loss: 0.0004, g_loss: 0.6818
# Elapsed time: 10268.3972 seconds, Epoch [47/200], Step [200/853], d_loss: 0.0001, g_loss: 0.4634
# Elapsed time: 10294.1767 seconds, Epoch [47/200], Step [300/853], d_loss: 0.0002, g_loss: 0.2165
# Elapsed time: 10320.2339 seconds, Epoch [47/200], Step [400/853], d_loss: 0.0004, g_loss: 0.3924
# Elapsed time: 10346.2123 seconds, Epoch [47/200], Step [500/853], d_loss: 0.0002, g_loss: 0.4735
# Elapsed time: 10372.2069 seconds, Epoch [47/200], Step [600/853], d_loss: 0.0002, g_loss: 0.4279
# Elapsed time: 10398.0933 seconds, Epoch [47/200], Step [700/853], d_loss: 0.0001, g_loss: 0.3452
# Elapsed time: 10424.1566 seconds, Epoch [47/200], Step [800/853], d_loss: 0.0001, g_loss: 0.5841
# Elapsed time: 10464.0094 seconds, Epoch [48/200], Step [100/853], d_loss: 0.0001, g_loss: 0.2165
# Elapsed time: 10489.9762 seconds, Epoch [48/200], Step [200/853], d_loss: 0.0001, g_loss: 0.3051
# Elapsed time: 10516.0984 seconds, Epoch [48/200], Step [300/853], d_loss: 0.0000, g_loss: 0.2589
# Elapsed time: 10542.1935 seconds, Epoch [48/200], Step [400/853], d_loss: 0.0002, g_loss: 0.2877
# Elapsed time: 10568.1721 seconds, Epoch [48/200], Step [500/853], d_loss: 0.0002, g_loss: 0.3268
# Elapsed time: 10594.2503 seconds, Epoch [48/200], Step [600/853], d_loss: 0.0002, g_loss: 0.3696
# Elapsed time: 10620.3014 seconds, Epoch [48/200], Step [700/853], d_loss: 0.0004, g_loss: 0.3747
# Elapsed time: 10646.1901 seconds, Epoch [48/200], Step [800/853], d_loss: 0.0003, g_loss: 0.4161
# Elapsed time: 10685.9229 seconds, Epoch [49/200], Step [100/853], d_loss: 0.0001, g_loss: 0.3043
# Elapsed time: 10711.8128 seconds, Epoch [49/200], Step [200/853], d_loss: 0.0003, g_loss: 0.1953
# Elapsed time: 10737.8704 seconds, Epoch [49/200], Step [300/853], d_loss: 0.0002, g_loss: 0.5695
# Elapsed time: 10763.8387 seconds, Epoch [49/200], Step [400/853], d_loss: 0.0001, g_loss: 0.4936
# Elapsed time: 10790.1051 seconds, Epoch [49/200], Step [500/853], d_loss: 0.0000, g_loss: 0.2828
# Elapsed time: 10816.0709 seconds, Epoch [49/200], Step [600/853], d_loss: 0.0005, g_loss: 0.4131
# Elapsed time: 10841.9305 seconds, Epoch [49/200], Step [700/853], d_loss: 0.0002, g_loss: 0.4399
# Elapsed time: 10867.9079 seconds, Epoch [49/200], Step [800/853], d_loss: 0.0002, g_loss: 0.3054
# Elapsed time: 10907.4872 seconds, Epoch [50/200], Step [100/853], d_loss: 0.0006, g_loss: 0.3867
# Elapsed time: 10933.4928 seconds, Epoch [50/200], Step [200/853], d_loss: 0.0005, g_loss: 0.4458
# Elapsed time: 10959.4410 seconds, Epoch [50/200], Step [300/853], d_loss: 0.0005, g_loss: 0.4202
# Elapsed time: 10985.3377 seconds, Epoch [50/200], Step [400/853], d_loss: 0.0002, g_loss: 0.2728
# Elapsed time: 11011.3259 seconds, Epoch [50/200], Step [500/853], d_loss: 0.0004, g_loss: 0.4256
# Elapsed time: 11037.1558 seconds, Epoch [50/200], Step [600/853], d_loss: 0.0002, g_loss: 0.3110
# Elapsed time: 11063.2251 seconds, Epoch [50/200], Step [700/853], d_loss: 0.0002, g_loss: 0.2169
# Elapsed time: 11089.2106 seconds, Epoch [50/200], Step [800/853], d_loss: 0.0000, g_loss: 0.5242
# Elapsed time: 11128.9631 seconds, Epoch [51/200], Step [100/853], d_loss: 0.0006, g_loss: 0.3731
# Elapsed time: 11154.9539 seconds, Epoch [51/200], Step [200/853], d_loss: 0.0002, g_loss: 0.3376
# Elapsed time: 11181.2094 seconds, Epoch [51/200], Step [300/853], d_loss: 0.0001, g_loss: 0.5463
# Elapsed time: 11207.1359 seconds, Epoch [51/200], Step [400/853], d_loss: 0.0001, g_loss: 0.1844
# Elapsed time: 11233.2935 seconds, Epoch [51/200], Step [500/853], d_loss: 0.0001, g_loss: 0.2679
# Elapsed time: 11259.2718 seconds, Epoch [51/200], Step [600/853], d_loss: 0.0006, g_loss: 0.2844
# Elapsed time: 11285.1410 seconds, Epoch [51/200], Step [700/853], d_loss: 0.0001, g_loss: 0.2228
# Elapsed time: 11311.0492 seconds, Epoch [51/200], Step [800/853], d_loss: 0.0001, g_loss: 0.3053
# Elapsed time: 11350.9093 seconds, Epoch [52/200], Step [100/853], d_loss: 0.0007, g_loss: 0.3074
# Elapsed time: 11376.9176 seconds, Epoch [52/200], Step [200/853], d_loss: 0.0005, g_loss: 0.3679
# Elapsed time: 11402.9307 seconds, Epoch [52/200], Step [300/853], d_loss: 0.0001, g_loss: 0.3582
# Elapsed time: 11428.9133 seconds, Epoch [52/200], Step [400/853], d_loss: 0.0000, g_loss: 0.3136
# Elapsed time: 11454.9916 seconds, Epoch [52/200], Step [500/853], d_loss: 0.0001, g_loss: 0.4693
# Elapsed time: 11480.8668 seconds, Epoch [52/200], Step [600/853], d_loss: 0.0001, g_loss: 0.2277
# Elapsed time: 11506.7639 seconds, Epoch [52/200], Step [700/853], d_loss: 0.0001, g_loss: 0.3870
# Elapsed time: 11532.5588 seconds, Epoch [52/200], Step [800/853], d_loss: 0.0007, g_loss: 0.5193
# Elapsed time: 11572.3362 seconds, Epoch [53/200], Step [100/853], d_loss: 0.0000, g_loss: 0.1880
# Elapsed time: 11598.3391 seconds, Epoch [53/200], Step [200/853], d_loss: 0.0003, g_loss: 0.4318
# Elapsed time: 11624.4365 seconds, Epoch [53/200], Step [300/853], d_loss: 0.0001, g_loss: 0.2240
# Elapsed time: 11650.5699 seconds, Epoch [53/200], Step [400/853], d_loss: 0.0001, g_loss: 0.5913
# Elapsed time: 11676.6421 seconds, Epoch [53/200], Step [500/853], d_loss: 0.0000, g_loss: 0.2552
# Elapsed time: 11702.7182 seconds, Epoch [53/200], Step [600/853], d_loss: 0.0003, g_loss: 0.4589
# Elapsed time: 11728.7166 seconds, Epoch [53/200], Step [700/853], d_loss: 0.0000, g_loss: 0.2992
# Elapsed time: 11754.8495 seconds, Epoch [53/200], Step [800/853], d_loss: 0.0001, g_loss: 0.4122
# Elapsed time: 11794.7211 seconds, Epoch [54/200], Step [100/853], d_loss: 0.0000, g_loss: 0.4087
# Elapsed time: 11820.8136 seconds, Epoch [54/200], Step [200/853], d_loss: 0.0002, g_loss: 0.2838
# Elapsed time: 11847.0696 seconds, Epoch [54/200], Step [300/853], d_loss: 0.0001, g_loss: 0.3102
# Elapsed time: 11873.1039 seconds, Epoch [54/200], Step [400/853], d_loss: 0.0001, g_loss: 0.3301
# Elapsed time: 11899.0468 seconds, Epoch [54/200], Step [500/853], d_loss: 0.0002, g_loss: 0.4463
# Elapsed time: 11925.0368 seconds, Epoch [54/200], Step [600/853], d_loss: 0.0001, g_loss: 0.3393
# Elapsed time: 11951.0488 seconds, Epoch [54/200], Step [700/853], d_loss: 0.0003, g_loss: 0.3297
# Elapsed time: 11977.0501 seconds, Epoch [54/200], Step [800/853], d_loss: 0.0002, g_loss: 0.2760
# Elapsed time: 12017.2450 seconds, Epoch [55/200], Step [100/853], d_loss: 0.0000, g_loss: 0.2655
# Elapsed time: 12043.5680 seconds, Epoch [55/200], Step [200/853], d_loss: 0.0001, g_loss: 0.2721
# Elapsed time: 12069.5866 seconds, Epoch [55/200], Step [300/853], d_loss: 0.0001, g_loss: 0.3948
# Elapsed time: 12095.7238 seconds, Epoch [55/200], Step [400/853], d_loss: 0.0001, g_loss: 0.3217
# Elapsed time: 12121.5974 seconds, Epoch [55/200], Step [500/853], d_loss: 0.0000, g_loss: 0.2958
# Elapsed time: 12147.8233 seconds, Epoch [55/200], Step [600/853], d_loss: 0.0002, g_loss: 0.4052
# Elapsed time: 12173.8593 seconds, Epoch [55/200], Step [700/853], d_loss: 0.0001, g_loss: 0.3289
# Elapsed time: 12200.1588 seconds, Epoch [55/200], Step [800/853], d_loss: 0.0000, g_loss: 0.3498
# Elapsed time: 12239.9907 seconds, Epoch [56/200], Step [100/853], d_loss: 0.0005, g_loss: 0.2208
# Elapsed time: 12266.0178 seconds, Epoch [56/200], Step [200/853], d_loss: 0.0001, g_loss: 0.3153
# Elapsed time: 12292.1505 seconds, Epoch [56/200], Step [300/853], d_loss: 0.0007, g_loss: 0.2805
# Elapsed time: 12318.1566 seconds, Epoch [56/200], Step [400/853], d_loss: 0.0001, g_loss: 0.3705
# Elapsed time: 12344.0851 seconds, Epoch [56/200], Step [500/853], d_loss: 0.0000, g_loss: 0.3545
# Elapsed time: 12370.0693 seconds, Epoch [56/200], Step [600/853], d_loss: 0.0000, g_loss: 0.2566
# Elapsed time: 12396.1618 seconds, Epoch [56/200], Step [700/853], d_loss: 0.0000, g_loss: 0.3691
# Elapsed time: 12422.2424 seconds, Epoch [56/200], Step [800/853], d_loss: 0.0001, g_loss: 0.5173
# Elapsed time: 12462.0999 seconds, Epoch [57/200], Step [100/853], d_loss: 0.0000, g_loss: 0.3087
# Elapsed time: 12488.3887 seconds, Epoch [57/200], Step [200/853], d_loss: 0.0000, g_loss: 0.4933
# Elapsed time: 12514.5598 seconds, Epoch [57/200], Step [300/853], d_loss: 0.0000, g_loss: 0.2445
# Elapsed time: 12540.4213 seconds, Epoch [57/200], Step [400/853], d_loss: 0.0000, g_loss: 0.3755
# Elapsed time: 12566.4424 seconds, Epoch [57/200], Step [500/853], d_loss: 0.0012, g_loss: 0.4287
# Elapsed time: 12592.6400 seconds, Epoch [57/200], Step [600/853], d_loss: 0.0001, g_loss: 0.4532
# Elapsed time: 12618.7335 seconds, Epoch [57/200], Step [700/853], d_loss: 0.0001, g_loss: 0.4874
# Elapsed time: 12644.7828 seconds, Epoch [57/200], Step [800/853], d_loss: 0.0000, g_loss: 0.3320
# Elapsed time: 12684.5089 seconds, Epoch [58/200], Step [100/853], d_loss: 0.0003, g_loss: 0.4905
# Elapsed time: 12710.5188 seconds, Epoch [58/200], Step [200/853], d_loss: 0.0000, g_loss: 0.3433
# Elapsed time: 12736.3529 seconds, Epoch [58/200], Step [300/853], d_loss: 0.0001, g_loss: 0.3469
# Elapsed time: 12762.2757 seconds, Epoch [58/200], Step [400/853], d_loss: 0.0000, g_loss: 0.2603
# Elapsed time: 12788.1348 seconds, Epoch [58/200], Step [500/853], d_loss: 0.0001, g_loss: 0.5015
# Elapsed time: 12814.2419 seconds, Epoch [58/200], Step [600/853], d_loss: 0.0002, g_loss: 0.3436
# Elapsed time: 12840.3559 seconds, Epoch [58/200], Step [700/853], d_loss: 0.0000, g_loss: 0.3342
# Elapsed time: 12866.3922 seconds, Epoch [58/200], Step [800/853], d_loss: 0.0001, g_loss: 0.3273
# Elapsed time: 12906.0041 seconds, Epoch [59/200], Step [100/853], d_loss: 0.0001, g_loss: 0.3709
# Elapsed time: 12932.1622 seconds, Epoch [59/200], Step [200/853], d_loss: 0.0001, g_loss: 0.5071
# Elapsed time: 12958.2359 seconds, Epoch [59/200], Step [300/853], d_loss: 0.0002, g_loss: 0.3202
# Elapsed time: 12984.2724 seconds, Epoch [59/200], Step [400/853], d_loss: 0.0000, g_loss: 0.3159
# Elapsed time: 13010.4355 seconds, Epoch [59/200], Step [500/853], d_loss: 0.0005, g_loss: 0.3294
# Elapsed time: 13036.5566 seconds, Epoch [59/200], Step [600/853], d_loss: 0.0010, g_loss: 0.3168
# Elapsed time: 13062.7998 seconds, Epoch [59/200], Step [700/853], d_loss: 0.0000, g_loss: 0.3892
# Elapsed time: 13088.8185 seconds, Epoch [59/200], Step [800/853], d_loss: 0.0002, g_loss: 0.4412
# Elapsed time: 13128.6987 seconds, Epoch [60/200], Step [100/853], d_loss: 0.0003, g_loss: 0.3665
# Elapsed time: 13154.6579 seconds, Epoch [60/200], Step [200/853], d_loss: 0.0001, g_loss: 0.3650
# Elapsed time: 13180.6067 seconds, Epoch [60/200], Step [300/853], d_loss: 0.0000, g_loss: 0.3004
# Elapsed time: 13206.5695 seconds, Epoch [60/200], Step [400/853], d_loss: 0.0002, g_loss: 0.4620
# Elapsed time: 13232.8705 seconds, Epoch [60/200], Step [500/853], d_loss: 0.0001, g_loss: 0.4431
# Elapsed time: 13258.8125 seconds, Epoch [60/200], Step [600/853], d_loss: 0.0003, g_loss: 0.3086
# Elapsed time: 13284.9515 seconds, Epoch [60/200], Step [700/853], d_loss: 0.0001, g_loss: 0.4596
# Elapsed time: 13310.9611 seconds, Epoch [60/200], Step [800/853], d_loss: 0.0003, g_loss: 0.3542
# Elapsed time: 13350.4212 seconds, Epoch [61/200], Step [100/853], d_loss: 0.0000, g_loss: 0.3430
# Elapsed time: 13376.4119 seconds, Epoch [61/200], Step [200/853], d_loss: 0.0004, g_loss: 0.3369
# Elapsed time: 13402.2612 seconds, Epoch [61/200], Step [300/853], d_loss: 0.0001, g_loss: 0.2284
# Elapsed time: 13428.2605 seconds, Epoch [61/200], Step [400/853], d_loss: 0.0002, g_loss: 0.2610
# Elapsed time: 13454.2698 seconds, Epoch [61/200], Step [500/853], d_loss: 0.0001, g_loss: 0.3485
# Elapsed time: 13480.3669 seconds, Epoch [61/200], Step [600/853], d_loss: 0.0001, g_loss: 0.3792
# Elapsed time: 13506.3751 seconds, Epoch [61/200], Step [700/853], d_loss: 0.0000, g_loss: 0.4369
# Elapsed time: 13532.3969 seconds, Epoch [61/200], Step [800/853], d_loss: 0.0001, g_loss: 0.4513
# Elapsed time: 13571.9964 seconds, Epoch [62/200], Step [100/853], d_loss: 0.0014, g_loss: 0.3540
# Elapsed time: 13597.9272 seconds, Epoch [62/200], Step [200/853], d_loss: 0.0001, g_loss: 0.3862
# Elapsed time: 13623.8068 seconds, Epoch [62/200], Step [300/853], d_loss: 0.0000, g_loss: 0.4393
# Elapsed time: 13649.7904 seconds, Epoch [62/200], Step [400/853], d_loss: 0.0001, g_loss: 0.6120
# Elapsed time: 13675.8702 seconds, Epoch [62/200], Step [500/853], d_loss: 0.0000, g_loss: 0.3004
# Elapsed time: 13701.7840 seconds, Epoch [62/200], Step [600/853], d_loss: 0.0000, g_loss: 0.3628
# Elapsed time: 13727.8321 seconds, Epoch [62/200], Step [700/853], d_loss: 0.0000, g_loss: 0.3016
# Elapsed time: 13753.9148 seconds, Epoch [62/200], Step [800/853], d_loss: 0.0000, g_loss: 0.2830
# Elapsed time: 13793.5059 seconds, Epoch [63/200], Step [100/853], d_loss: 0.0000, g_loss: 0.3406
# Elapsed time: 13819.4180 seconds, Epoch [63/200], Step [200/853], d_loss: 0.0000, g_loss: 0.2870
# Elapsed time: 13845.4551 seconds, Epoch [63/200], Step [300/853], d_loss: 0.0006, g_loss: 0.4421
# ...
# Elapsed time: 40094.3161 seconds, Epoch [180/200], Step [600/853], d_loss: 0.0000, g_loss: 0.2122
# Elapsed time: 40120.3212 seconds, Epoch [180/200], Step [700/853], d_loss: 0.0000, g_loss: 0.3889
# Elapsed time: 40146.4155 seconds, Epoch [180/200], Step [800/853], d_loss: 0.0000, g_loss: 0.3485
# Elapsed time: 40186.2098 seconds, Epoch [181/200], Step [100/853], d_loss: 0.0000, g_loss: 0.3611
# Elapsed time: 40212.2029 seconds, Epoch [181/200], Step [200/853], d_loss: 0.0000, g_loss: 0.4623
# Elapsed time: 40238.1883 seconds, Epoch [181/200], Step [300/853], d_loss: 0.0000, g_loss: 0.5680
# Elapsed time: 40264.0787 seconds, Epoch [181/200], Step [400/853], d_loss: 0.0000, g_loss: 0.2961
# Elapsed time: 40289.9557 seconds, Epoch [181/200], Step [500/853], d_loss: 0.0000, g_loss: 0.3724
# Elapsed time: 40315.7921 seconds, Epoch [181/200], Step [600/853], d_loss: 0.0000, g_loss: 0.3553
# Elapsed time: 40341.7882 seconds, Epoch [181/200], Step [700/853], d_loss: 0.0001, g_loss: 0.3109
# Elapsed time: 40367.8241 seconds, Epoch [181/200], Step [800/853], d_loss: 0.0000, g_loss: 0.2751
# Elapsed time: 40407.5714 seconds, Epoch [182/200], Step [100/853], d_loss: 0.0000, g_loss: 0.4202
# Elapsed time: 40433.5111 seconds, Epoch [182/200], Step [200/853], d_loss: 0.0001, g_loss: 0.2785
# Elapsed time: 40459.4817 seconds, Epoch [182/200], Step [300/853], d_loss: 0.0000, g_loss: 0.2897
# Elapsed time: 40485.4305 seconds, Epoch [182/200], Step [400/853], d_loss: 0.0000, g_loss: 0.3530
# Elapsed time: 40511.6460 seconds, Epoch [182/200], Step [500/853], d_loss: 0.0000, g_loss: 0.2716
# Elapsed time: 40537.6531 seconds, Epoch [182/200], Step [600/853], d_loss: 0.0000, g_loss: 0.2830
# Elapsed time: 40563.5906 seconds, Epoch [182/200], Step [700/853], d_loss: 0.0000, g_loss: 0.4318
# Elapsed time: 40589.5453 seconds, Epoch [182/200], Step [800/853], d_loss: 0.0000, g_loss: 0.2368
# Elapsed time: 40629.2349 seconds, Epoch [183/200], Step [100/853], d_loss: 0.0000, g_loss: 0.5475
# Elapsed time: 40655.1925 seconds, Epoch [183/200], Step [200/853], d_loss: 0.0000, g_loss: 0.2600
# Elapsed time: 40681.2673 seconds, Epoch [183/200], Step [300/853], d_loss: 0.0000, g_loss: 0.4450
# Elapsed time: 40707.2344 seconds, Epoch [183/200], Step [400/853], d_loss: 0.0000, g_loss: 0.2433
# Elapsed time: 40733.3761 seconds, Epoch [183/200], Step [500/853], d_loss: 0.0000, g_loss: 0.3696
# Elapsed time: 40759.5007 seconds, Epoch [183/200], Step [600/853], d_loss: 0.0000, g_loss: 0.2205
# Elapsed time: 40785.3587 seconds, Epoch [183/200], Step [700/853], d_loss: 0.0000, g_loss: 0.3112
# Elapsed time: 40811.3395 seconds, Epoch [183/200], Step [800/853], d_loss: 0.0001, g_loss: 0.2538
# Elapsed time: 40850.8711 seconds, Epoch [184/200], Step [100/853], d_loss: 0.0000, g_loss: 0.3428
# Elapsed time: 40876.5227 seconds, Epoch [184/200], Step [200/853], d_loss: 0.0000, g_loss: 0.6558
# Elapsed time: 40902.4723 seconds, Epoch [184/200], Step [300/853], d_loss: 0.0000, g_loss: 0.2853
# Elapsed time: 40928.4102 seconds, Epoch [184/200], Step [400/853], d_loss: 0.0000, g_loss: 0.3976
# Elapsed time: 40954.4532 seconds, Epoch [184/200], Step [500/853], d_loss: 0.0000, g_loss: 0.2300
# Elapsed time: 40980.4354 seconds, Epoch [184/200], Step [600/853], d_loss: 0.0000, g_loss: 0.4257
# Elapsed time: 41006.3960 seconds, Epoch [184/200], Step [700/853], d_loss: 0.0000, g_loss: 0.3549
# Elapsed time: 41032.3337 seconds, Epoch [184/200], Step [800/853], d_loss: 0.0000, g_loss: 0.4398
# Elapsed time: 41072.0652 seconds, Epoch [185/200], Step [100/853], d_loss: 0.0000, g_loss: 0.2630
# Elapsed time: 41097.9772 seconds, Epoch [185/200], Step [200/853], d_loss: 0.0000, g_loss: 0.3661
# Elapsed time: 41123.7842 seconds, Epoch [185/200], Step [300/853], d_loss: 0.0000, g_loss: 0.4258
# Elapsed time: 41149.7646 seconds, Epoch [185/200], Step [400/853], d_loss: 0.0000, g_loss: 0.2903
# Elapsed time: 41175.6584 seconds, Epoch [185/200], Step [500/853], d_loss: 0.0000, g_loss: 0.3638
# Elapsed time: 41201.7772 seconds, Epoch [185/200], Step [600/853], d_loss: 0.0000, g_loss: 0.3880
# Elapsed time: 41227.6560 seconds, Epoch [185/200], Step [700/853], d_loss: 0.0000, g_loss: 0.2188
# Elapsed time: 41253.4841 seconds, Epoch [185/200], Step [800/853], d_loss: 0.0000, g_loss: 0.3438
# Elapsed time: 41293.1889 seconds, Epoch [186/200], Step [100/853], d_loss: 0.0000, g_loss: 0.2732
# Elapsed time: 41319.3463 seconds, Epoch [186/200], Step [200/853], d_loss: 0.0000, g_loss: 0.3617
# Elapsed time: 41345.4420 seconds, Epoch [186/200], Step [300/853], d_loss: 0.0000, g_loss: 0.2143
# Elapsed time: 41371.4616 seconds, Epoch [186/200], Step [400/853], d_loss: 0.0000, g_loss: 0.3863
# Elapsed time: 41397.6061 seconds, Epoch [186/200], Step [500/853], d_loss: 0.0000, g_loss: 0.2922
# Elapsed time: 41423.5795 seconds, Epoch [186/200], Step [600/853], d_loss: 0.0000, g_loss: 0.3077
# Elapsed time: 41449.4347 seconds, Epoch [186/200], Step [700/853], d_loss: 0.0000, g_loss: 0.2623
# Elapsed time: 41475.3441 seconds, Epoch [186/200], Step [800/853], d_loss: 0.0000, g_loss: 0.2627
# Elapsed time: 41514.8023 seconds, Epoch [187/200], Step [100/853], d_loss: 0.0000, g_loss: 0.3266
# Elapsed time: 41540.8159 seconds, Epoch [187/200], Step [200/853], d_loss: 0.0000, g_loss: 0.2682
# Elapsed time: 41566.8162 seconds, Epoch [187/200], Step [300/853], d_loss: 0.0000, g_loss: 0.5476
# Elapsed time: 41592.9394 seconds, Epoch [187/200], Step [400/853], d_loss: 0.0000, g_loss: 0.3910
# Elapsed time: 41618.9782 seconds, Epoch [187/200], Step [500/853], d_loss: 0.0001, g_loss: 0.2347
# Elapsed time: 41644.8218 seconds, Epoch [187/200], Step [600/853], d_loss: 0.0000, g_loss: 0.3710
# Elapsed time: 41670.7792 seconds, Epoch [187/200], Step [700/853], d_loss: 0.0000, g_loss: 0.4419
# Elapsed time: 41696.5733 seconds, Epoch [187/200], Step [800/853], d_loss: 0.0000, g_loss: 0.2599
# Elapsed time: 41736.1127 seconds, Epoch [188/200], Step [100/853], d_loss: 0.0000, g_loss: 0.3159
# Elapsed time: 41762.1315 seconds, Epoch [188/200], Step [200/853], d_loss: 0.0000, g_loss: 0.3033
# Elapsed time: 41788.3464 seconds, Epoch [188/200], Step [300/853], d_loss: 0.0000, g_loss: 0.3208
# Elapsed time: 41814.2574 seconds, Epoch [188/200], Step [400/853], d_loss: 0.0000, g_loss: 0.4079
# Elapsed time: 41840.3019 seconds, Epoch [188/200], Step [500/853], d_loss: 0.0000, g_loss: 0.2260
# Elapsed time: 41866.4078 seconds, Epoch [188/200], Step [600/853], d_loss: 0.0000, g_loss: 0.2713
# Elapsed time: 41892.7200 seconds, Epoch [188/200], Step [700/853], d_loss: 0.0000, g_loss: 0.4739
# Elapsed time: 41918.7143 seconds, Epoch [188/200], Step [800/853], d_loss: 0.0001, g_loss: 0.3510
# Elapsed time: 41958.2397 seconds, Epoch [189/200], Step [100/853], d_loss: 0.0000, g_loss: 0.2388
# Elapsed time: 41984.2262 seconds, Epoch [189/200], Step [200/853], d_loss: 0.0000, g_loss: 0.4868
# Elapsed time: 42010.1818 seconds, Epoch [189/200], Step [300/853], d_loss: 0.0000, g_loss: 0.2854
# Elapsed time: 42036.1719 seconds, Epoch [189/200], Step [400/853], d_loss: 0.0000, g_loss: 0.2334
# Elapsed time: 42062.1488 seconds, Epoch [189/200], Step [500/853], d_loss: 0.0000, g_loss: 0.2294
# Elapsed time: 42088.0299 seconds, Epoch [189/200], Step [600/853], d_loss: 0.0000, g_loss: 0.3860
# Elapsed time: 42114.0075 seconds, Epoch [189/200], Step [700/853], d_loss: 0.0000, g_loss: 0.3772
# Elapsed time: 42139.8912 seconds, Epoch [189/200], Step [800/853], d_loss: 0.0000, g_loss: 0.3437
# Elapsed time: 42179.9070 seconds, Epoch [190/200], Step [100/853], d_loss: 0.0000, g_loss: 0.2313
# Elapsed time: 42205.9469 seconds, Epoch [190/200], Step [200/853], d_loss: 0.0000, g_loss: 0.2010
# Elapsed time: 42231.9339 seconds, Epoch [190/200], Step [300/853], d_loss: 0.0000, g_loss: 0.3305
# Elapsed time: 42258.0270 seconds, Epoch [190/200], Step [400/853], d_loss: 0.0000, g_loss: 0.2970
# Elapsed time: 42284.0830 seconds, Epoch [190/200], Step [500/853], d_loss: 0.0000, g_loss: 0.2726
# Elapsed time: 42310.0299 seconds, Epoch [190/200], Step [600/853], d_loss: 0.0000, g_loss: 0.4324
# Elapsed time: 42335.9412 seconds, Epoch [190/200], Step [700/853], d_loss: 0.0000, g_loss: 0.3135
# Elapsed time: 42362.0520 seconds, Epoch [190/200], Step [800/853], d_loss: 0.0000, g_loss: 0.3740
# Elapsed time: 42401.7501 seconds, Epoch [191/200], Step [100/853], d_loss: 0.0000, g_loss: 0.3474
# Elapsed time: 42427.7652 seconds, Epoch [191/200], Step [200/853], d_loss: 0.0000, g_loss: 0.3816
# Elapsed time: 42453.9459 seconds, Epoch [191/200], Step [300/853], d_loss: 0.0000, g_loss: 0.3124
# Elapsed time: 42479.9347 seconds, Epoch [191/200], Step [400/853], d_loss: 0.0000, g_loss: 0.3371
# Elapsed time: 42506.1431 seconds, Epoch [191/200], Step [500/853], d_loss: 0.0000, g_loss: 0.3218
# Elapsed time: 42532.1198 seconds, Epoch [191/200], Step [600/853], d_loss: 0.0000, g_loss: 0.3850
# Elapsed time: 42558.1180 seconds, Epoch [191/200], Step [700/853], d_loss: 0.0000, g_loss: 0.3146
# Elapsed time: 42584.2668 seconds, Epoch [191/200], Step [800/853], d_loss: 0.0000, g_loss: 0.2737
# Elapsed time: 42624.1037 seconds, Epoch [192/200], Step [100/853], d_loss: 0.0000, g_loss: 0.2896
# Elapsed time: 42650.2859 seconds, Epoch [192/200], Step [200/853], d_loss: 0.0000, g_loss: 0.2769
# Elapsed time: 42676.3808 seconds, Epoch [192/200], Step [300/853], d_loss: 0.0000, g_loss: 0.3541
# Elapsed time: 42702.3583 seconds, Epoch [192/200], Step [400/853], d_loss: 0.0000, g_loss: 0.2924
# Elapsed time: 42728.5735 seconds, Epoch [192/200], Step [500/853], d_loss: 0.0000, g_loss: 0.2705
# Elapsed time: 42754.4181 seconds, Epoch [192/200], Step [600/853], d_loss: 0.0000, g_loss: 0.2829
# Elapsed time: 42780.2501 seconds, Epoch [192/200], Step [700/853], d_loss: 0.0000, g_loss: 0.3353
# Elapsed time: 42806.2039 seconds, Epoch [192/200], Step [800/853], d_loss: 0.0000, g_loss: 0.3043
# Elapsed time: 42845.9684 seconds, Epoch [193/200], Step [100/853], d_loss: 0.0000, g_loss: 0.3793
# Elapsed time: 42871.9412 seconds, Epoch [193/200], Step [200/853], d_loss: 0.0000, g_loss: 0.5583
# Elapsed time: 42898.1473 seconds, Epoch [193/200], Step [300/853], d_loss: 0.0000, g_loss: 0.2489
# Elapsed time: 42924.4501 seconds, Epoch [193/200], Step [400/853], d_loss: 0.0000, g_loss: 0.4351
# Elapsed time: 42950.2981 seconds, Epoch [193/200], Step [500/853], d_loss: 0.0000, g_loss: 0.2623
# Elapsed time: 42976.2832 seconds, Epoch [193/200], Step [600/853], d_loss: 0.0000, g_loss: 0.3008
# Elapsed time: 43002.1630 seconds, Epoch [193/200], Step [700/853], d_loss: 0.0000, g_loss: 0.2674
# Elapsed time: 43028.1522 seconds, Epoch [193/200], Step [800/853], d_loss: 0.0000, g_loss: 0.3942
# Elapsed time: 43067.9364 seconds, Epoch [194/200], Step [100/853], d_loss: 0.0000, g_loss: 0.3188
# Elapsed time: 43093.8899 seconds, Epoch [194/200], Step [200/853], d_loss: 0.0000, g_loss: 0.4128
# Elapsed time: 43119.7806 seconds, Epoch [194/200], Step [300/853], d_loss: 0.0000, g_loss: 0.2512
# Elapsed time: 43145.7608 seconds, Epoch [194/200], Step [400/853], d_loss: 0.0000, g_loss: 0.2337
# Elapsed time: 43171.7226 seconds, Epoch [194/200], Step [500/853], d_loss: 0.0000, g_loss: 0.3536
# Elapsed time: 43197.8100 seconds, Epoch [194/200], Step [600/853], d_loss: 0.0000, g_loss: 0.3500
# Elapsed time: 43223.8919 seconds, Epoch [194/200], Step [700/853], d_loss: 0.0000, g_loss: 0.2841
# Elapsed time: 43250.2936 seconds, Epoch [194/200], Step [800/853], d_loss: 0.0000, g_loss: 0.4645
# Elapsed time: 43290.0369 seconds, Epoch [195/200], Step [100/853], d_loss: 0.0000, g_loss: 0.4289
# Elapsed time: 43315.9264 seconds, Epoch [195/200], Step [200/853], d_loss: 0.0000, g_loss: 0.3642
# Elapsed time: 43341.8147 seconds, Epoch [195/200], Step [300/853], d_loss: 0.0000, g_loss: 0.2498
# Elapsed time: 43367.8608 seconds, Epoch [195/200], Step [400/853], d_loss: 0.0000, g_loss: 0.4771
# Elapsed time: 43393.8205 seconds, Epoch [195/200], Step [500/853], d_loss: 0.0000, g_loss: 0.2790
# Elapsed time: 43419.8442 seconds, Epoch [195/200], Step [600/853], d_loss: 0.0000, g_loss: 0.3653
# Elapsed time: 43445.7797 seconds, Epoch [195/200], Step [700/853], d_loss: 0.0000, g_loss: 0.3730
# Elapsed time: 43471.7556 seconds, Epoch [195/200], Step [800/853], d_loss: 0.0000, g_loss: 0.2616
# Elapsed time: 43511.6995 seconds, Epoch [196/200], Step [100/853], d_loss: 0.0000, g_loss: 0.2728
# Elapsed time: 43537.6832 seconds, Epoch [196/200], Step [200/853], d_loss: 0.0000, g_loss: 0.2513
# Elapsed time: 43563.5547 seconds, Epoch [196/200], Step [300/853], d_loss: 0.0000, g_loss: 0.5591
# Elapsed time: 43589.3234 seconds, Epoch [196/200], Step [400/853], d_loss: 0.0000, g_loss: 0.4498
# Elapsed time: 43615.2313 seconds, Epoch [196/200], Step [500/853], d_loss: 0.0000, g_loss: 0.3810
# Elapsed time: 43641.1017 seconds, Epoch [196/200], Step [600/853], d_loss: 0.0000, g_loss: 0.4196
# Elapsed time: 43667.1360 seconds, Epoch [196/200], Step [700/853], d_loss: 0.0000, g_loss: 0.3899
# Elapsed time: 43693.0475 seconds, Epoch [196/200], Step [800/853], d_loss: 0.0000, g_loss: 0.3592
# Elapsed time: 43732.6410 seconds, Epoch [197/200], Step [100/853], d_loss: 0.0000, g_loss: 0.3075
# Elapsed time: 43758.5284 seconds, Epoch [197/200], Step [200/853], d_loss: 0.0000, g_loss: 0.2470
# Elapsed time: 43784.3174 seconds, Epoch [197/200], Step [300/853], d_loss: 0.0000, g_loss: 0.3713
# Elapsed time: 43810.2421 seconds, Epoch [197/200], Step [400/853], d_loss: 0.0000, g_loss: 0.3288
# Elapsed time: 43836.1255 seconds, Epoch [197/200], Step [500/853], d_loss: 0.0000, g_loss: 0.2441
# Elapsed time: 43862.1661 seconds, Epoch [197/200], Step [600/853], d_loss: 0.0000, g_loss: 0.2807
# Elapsed time: 43888.0599 seconds, Epoch [197/200], Step [700/853], d_loss: 0.0000, g_loss: 0.4061
# Elapsed time: 43914.0635 seconds, Epoch [197/200], Step [800/853], d_loss: 0.0000, g_loss: 0.2508
# Elapsed time: 43953.6887 seconds, Epoch [198/200], Step [100/853], d_loss: 0.0000, g_loss: 0.4021
# Elapsed time: 43979.6823 seconds, Epoch [198/200], Step [200/853], d_loss: 0.0000, g_loss: 0.3398
# Elapsed time: 44005.6615 seconds, Epoch [198/200], Step [300/853], d_loss: 0.0000, g_loss: 0.2758
# Elapsed time: 44031.4336 seconds, Epoch [198/200], Step [400/853], d_loss: 0.0000, g_loss: 0.4193
# Elapsed time: 44057.3061 seconds, Epoch [198/200], Step [500/853], d_loss: 0.0000, g_loss: 0.2558
# Elapsed time: 44083.1818 seconds, Epoch [198/200], Step [600/853], d_loss: 0.0000, g_loss: 0.4034
# Elapsed time: 44109.2386 seconds, Epoch [198/200], Step [700/853], d_loss: 0.0000, g_loss: 0.3757
# Elapsed time: 44135.4363 seconds, Epoch [198/200], Step [800/853], d_loss: 0.0000, g_loss: 0.2537
# Elapsed time: 44175.0039 seconds, Epoch [199/200], Step [100/853], d_loss: 0.0000, g_loss: 0.2924
# Elapsed time: 44200.8742 seconds, Epoch [199/200], Step [200/853], d_loss: 0.0000, g_loss: 0.3452
# Elapsed time: 44226.9325 seconds, Epoch [199/200], Step [300/853], d_loss: 0.0000, g_loss: 0.3913
# Elapsed time: 44252.9758 seconds, Epoch [199/200], Step [400/853], d_loss: 0.0000, g_loss: 0.2979
# Elapsed time: 44279.0485 seconds, Epoch [199/200], Step [500/853], d_loss: 0.0000, g_loss: 0.2658
# Elapsed time: 44305.0881 seconds, Epoch [199/200], Step [600/853], d_loss: 0.0000, g_loss: 0.3096
# Elapsed time: 44331.0823 seconds, Epoch [199/200], Step [700/853], d_loss: 0.0000, g_loss: 0.2595
# Elapsed time: 44357.0221 seconds, Epoch [199/200], Step [800/853], d_loss: 0.0000, g_loss: 0.2245
# Elapsed time: 44396.6535 seconds, Epoch [200/200], Step [100/853], d_loss: 0.0000, g_loss: 0.4286
# Elapsed time: 44422.4942 seconds, Epoch [200/200], Step [200/853], d_loss: 0.0000, g_loss: 0.2583
# Elapsed time: 44448.3868 seconds, Epoch [200/200], Step [300/853], d_loss: 0.0000, g_loss: 0.2015
# Elapsed time: 44474.1685 seconds, Epoch [200/200], Step [400/853], d_loss: 0.0000, g_loss: 0.2889
# Elapsed time: 44500.1380 seconds, Epoch [200/200], Step [500/853], d_loss: 0.0000, g_loss: 0.3902
# Elapsed time: 44525.9911 seconds, Epoch [200/200], Step [600/853], d_loss: 0.0000, g_loss: 0.3725
# Elapsed time: 44552.1316 seconds, Epoch [200/200], Step [700/853], d_loss: 0.0000, g_loss: 0.3459
# Elapsed time: 44578.0949 seconds, Epoch [200/200], Step [800/853], d_loss: 0.0000, g_loss: 0.3117

# %% [markdown]
# ## 保存模型

# %%
# 保存生成器模型
torch.save(generator.state_dict(), './demo1/generator.pth')

# 保存判别器模型
torch.save(discriminator.state_dict(), './demo1/discriminator.pth')

# %% [markdown]
# ## 测试模型

# %%
from PIL import Image
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

# 加载低分辨率图像
image = Image.open('/home/cxmd/文档/data_for_AI_train/Particles/hr/L2_ffe7b1e4a0dbed455356a5a62d04894a.jpg')

# 将图像转换为Tensor，并添加一个批次维度
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean, std),
])
image = transform(image).unsqueeze(0).to(device)

# 使用生成器生成高分辨率图像
with torch.no_grad():
    output = generator(image)

# 将输出转换回图像
output = output.squeeze(0).cpu().detach()
output = output * std.view() + mean.view()  # 反归一化
output = output.clamp(0, 1)  # 将像素值限制在[0, 1]范围内
output = transforms.ToPILImage()(output)

# 显示图像
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
# ax[0].imshow(image.squeeze(0).cpu().detach())
ax[1].imshow(output)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/cxmd/Nutstore_Files/test_files/neural_network/SRGAN/srgan_demo1.ipynb 单元格 23 line 2
#      <a href='vscode-notebook-cell:/home/cxmd/Nutstore_Files/test_files/neural_network/SRGAN/srgan_demo1.ipynb#X31sZmlsZQ%3D%3D?line=18'>19</a> # 将输出转换回图像
#      <a href='vscode-notebook-cell:/home/cxmd/Nutstore_Files/test_files/neural_network/SRGAN/srgan_demo1.ipynb#X31sZmlsZQ%3D%3D?line=19'>20</a> output = output.squeeze(0).cpu().detach()
# ---> <a href='vscode-notebook-cell:/home/cxmd/Nutstore_Files/test_files/neural_network/SRGAN/srgan_demo1.ipynb#X31sZmlsZQ%3D%3D?line=20'>21</a> output = output * std.view() + mean.view()  # 反归一化
#      <a href='vscode-notebook-cell:/home/cxmd/Nutstore_Files/test_files/neural_network/SRGAN/srgan_demo1.ipynb#X31sZmlsZQ%3D%3D?line=21'>22</a> output = output.clamp(0, 1)  # 将像素值限制在[0, 1]范围内
#      <a href='vscode-notebook-cell:/home/cxmd/Nutstore_Files/test_files/neural_network/SRGAN/srgan_demo1.ipynb#X31sZmlsZQ%3D%3D?line=22'>23</a> output = transforms.ToPILImage()(output)
#
# ValueError: operands could not be broadcast together with shapes (3,3072,4096) (3,)

# %%
mean.view()
# Out:
# array([0.485, 0.456, 0.406])
