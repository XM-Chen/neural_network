# %% [markdown]
# # GAN
# 与demo2不同的是数据集是Particles_100SEM数据集

# %%
import os
import sys
import time

import matplotlib.pyplot as plt
import numpy as np
import torch.nn as nn
import torch.optim as optim
import torch.utils.data
from torch.autograd import Variable
import torchvision.datasets as dset
import torchvision.transforms as transforms
import torchvision.utils as vutils
# PyTorch TensorBoard support
from torch.utils.tensorboard import SummaryWriter
from torchvision.utils import save_image

# %%
# %% 超参数
if sys.platform.startswith('win'):
    datapath = 'D:\\datasets\\mnist_data'
else:
    datapath = '/home/cxmd/文档/data_for_AI_train/Particles_100SEM/'

workers = 8             # 加载数据集时所使用的线程数
n_epochs = 200          # 训练次数
batch_size = 32        # 批大小
lr = 0.00005            # 学习率
b1 = 0.5 
b2 = 0.999
n_cpu = 8               # cpu数量
latent_dim = 100        # 隐变量维度
img_size = 32           # 图片大小
channels = 1            # 图像通道数
n_critic = 5            # 每次迭代判别器训练的次数
clip_value = 0.01       # 
sample_interval = 400   # 每400次迭代保存一次生成的图片

ngpu = 1            # 使用的GPU数量，使用0表示cpu模式

img_shape = (channels, img_size, img_size)

# %%
# 选择我们运行在上面的设备
device = torch.device("cuda" if (torch.cuda.is_available()) else "cpu")
print(device)
# Out:
# cuda

# %%
os.makedirs(r"/home/cxmd/文档/git_files/neural_network/GAN/run3", exist_ok=True)
os.makedirs(r"/home/cxmd/文档/git_files/neural_network/GAN/images3", exist_ok=True)

# %%
# transform配置
transform = transforms.Compose(
    [
        transforms.Resize(img_size),
        transforms.CenterCrop(img_size),
        transforms.Grayscale(),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.5],std=[0.5]),
    ]
)

dataset = dset.ImageFolder(
    root=datapath,
    transform=transform
)

data_loader = torch.utils.data.DataLoader(
    dataset=dataset,
    batch_size=batch_size,
    shuffle=True,
    num_workers=workers
)

# %%
# 绘制部分我们的输入图像
real_batch = next(iter(data_loader))
fig, ax = plt.subplots(figsize=(8, 8))
ax.axis("off")
ax.set_title("Training Images")
ax.imshow(
    vutils.make_grid(
        real_batch[0].to(device)[:64], padding=2, normalize=True
    ).permute(1, 2, 0).cpu()
)
plt.show()

# %%
# 标准GAN生成器
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        
        def block(in_features, out_features, normalize=True):
            layers = [nn.Linear(in_features, out_features)]
            if normalize:
                layers.append(nn.BatchNorm1d(out_features, 0.8))
            layers.append(nn.LeakyReLU(0.2, inplace=True))
            return layers
        
        self.model = nn.Sequential(
            *block(latent_dim, 128, normalize=False),
            *block(128, 256),
            *block(256, 512),
            *block(512, 1024),
            nn.Linear(1024, int(np.prod(img_shape))),
            nn.Tanh()
        )
        
    def forward(self, z):
        img = self.model(z)     # 输入形状为(batch_size, latent_dim)
        img = img.reshape(img.shape[0], *img_shape)  # 输出形状为(batch_size, channels, img_size, img_size)
        return img

# %%
netG = Generator().to(device)
print(netG)

# 写入tensorboard
if sys.platform.startswith('win'):
    writerGpath = r'D:\git_files\neural_network\GAN\run3\Generator'
else:
    writerGpath = r'/home/cxmd/文档/git_files/neural_network/GAN/run3/Generator'

writerG = SummaryWriter(writerGpath)

input_to_netG = torch.randn(batch_size, latent_dim, device=device)
writerG.add_graph(netG, input_to_model=input_to_netG)
writerG.close()
# Out:
# Generator(
#   (model): Sequential(
#     (0): Linear(in_features=100, out_features=128, bias=True)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Linear(in_features=128, out_features=256, bias=True)
#     (3): BatchNorm1d(256, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): Linear(in_features=256, out_features=512, bias=True)
#     (6): BatchNorm1d(512, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.2, inplace=True)
#     (8): Linear(in_features=512, out_features=1024, bias=True)
#     (9): BatchNorm1d(1024, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (10): LeakyReLU(negative_slope=0.2, inplace=True)
#     (11): Linear(in_features=1024, out_features=1024, bias=True)
#     (12): Tanh()
#   )
# )

# %%
# 判别器
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(int(np.prod(img_shape)), 512),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(512, 256),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(256, 1),
            nn.Sigmoid(),
        )
    
    def forward(self, img):
        img_flat = img.reshape(img.shape[0], -1)    # 输入形状为(batch_size, channels, img_size, img_size)
        validity = self.model(img_flat)            # 输出形状为(batch_size, 1)
        return validity

# %%
netD = Discriminator().to(device)
print(netD)

if sys.platform.startswith("win"):
    writerDpath = r'D:\git_files\neural_network\GAN\run3\Discriminator'
else:
    writerDpath = r'/home/cxmd/文档/git_files/neural_network/GAN/run3/Discriminator'

writerD = SummaryWriter(writerDpath)
input_to_netD = torch.randn(batch_size, int(np.prod(img_shape)), device=device)
writerD.add_graph(netD, input_to_netD)
writerD.close()
# Out:
# Discriminator(
#   (model): Sequential(
#     (0): Linear(in_features=1024, out_features=512, bias=True)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Linear(in_features=512, out_features=256, bias=True)
#     (3): LeakyReLU(negative_slope=0.2, inplace=True)
#     (4): Linear(in_features=256, out_features=1, bias=True)
#     (5): Sigmoid()
#   )
# )

# %%
# 设置损失函数和优化器
adversarial_loss = nn.BCELoss()  # 二值交叉熵 Binary cross entropy loss
optimizer_G = torch.optim.Adam(netG.parameters(), lr=lr, betas=(b1, b2))
optimizer_D = torch.optim.Adam(netD.parameters(), lr=lr, betas=(b1, b2))

# %%
# 记录开始训练的时间
start_time = time.time()

batches_done = 0
if sys.platform.startswith('win'):
    writerpath = r'D:\git_files\neural_network\GAN\run3'
else:
    writerpath = r'/home/cxmd/文档/git_files/neural_network/GAN/run3'
writer = SummaryWriter(writerpath)


for epoch in range(n_epochs):
    for i, (imgs, _) in enumerate(data_loader):
        # 如果这个批次的样本数量小于批次大小，跳过这个批次
        if imgs.shape[0] != batch_size:
            continue
        
        # 创建真实图像和生成图像的标签
        valid = torch.ones([imgs.size(0), 1]).to(device)
        fake = torch.zeros([imgs.size(0), 1]).to(device)
        
        # 真实输入训练集
        real_imgs = imgs.to(device)
        # real_imgs = Variable(imgs.type(Tensor)).to(device)
        
        # -----------------
        #  训练生成器
        # -----------------
        
        optimizer_G.zero_grad()
        
        # 生成正态分布噪声以作为生成器的输入
        z = torch.randn(imgs.shape[0], latent_dim, device=device)
        
        # 生成器生成的图像
        gen_imgs = netG(z).to(device)
        
        # 生成器损失函数来衡量生成器欺骗判别器的能力
        g_loss = adversarial_loss(netD(gen_imgs), valid).to(device)
        
        g_loss.backward()
        optimizer_G.step()
        
        # ---------------------
        #  训练判别器
        # ---------------------
        
        optimizer_D.zero_grad()
        
        # 判别器损失函数来衡量分辨出真实图片和生成器生成图片的能力
        real_loss = adversarial_loss(netD(real_imgs), valid)
        fake_loss = adversarial_loss(netD(gen_imgs.detach()), fake)
        
        d_loss = (real_loss + fake_loss) / 2
        
        real_score = netD(real_imgs)
        fake_score = netD(gen_imgs.detach())
        
        d_loss.backward()
        optimizer_D.step()
        
        # tensorboard跟踪数据
        writer.add_scalar('loss_g', g_loss.item(), epoch*len(data_loader)+i)
        writer.add_scalar('loss_d', d_loss.item(), epoch*len(data_loader)+i)
        writer.add_scalar('D(x)', real_score.mean().item(), epoch*len(data_loader)+i)
        writer.add_scalar('D(G(z))', fake_score.mean().item(), epoch*len(data_loader)+i)
        
        if (i + 1) % 10 == 0:      # 每一百批次输入一次训练程度
            # 计算过去的时间
            elapsed_time = time.time() - start_time
            print('Elapsed time: {:.4f} seconds, Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss: {:.4f}, D(x): {:.2f}, D(G(z)): {:.2f}'.format(elapsed_time, epoch + 1, n_epochs, i + 1, len(data_loader), d_loss.item(), g_loss.item(), real_score.mean().item(), fake_score.mean().item()))

        if batches_done % sample_interval == 0:
            # writer image to tensorboard
            imgs_to_tensorboard = gen_imgs.data[:25]
            imgs_to_tensorboard = vutils.make_grid(imgs_to_tensorboard, nrow=5, normalize=True).cpu()
            writer.add_image("fake_imgs", imgs_to_tensorboard, epoch*len(data_loader)+i)
            
            save_image(gen_imgs.data[:25], r"/home/cxmd/文档/git_files/neural_network/GAN/images3/%d.png" % batches_done, nrow=5, normalize=True)

        batches_done += 1
writer.close()
# Out:
# Elapsed time: 2.6055 seconds, Epoch [1/200], Step [10/123], d_loss: 0.5916, g_loss: 0.6634, D(x): 0.64, D(G(z)): 0.52
# Elapsed time: 4.2344 seconds, Epoch [1/200], Step [20/123], d_loss: 0.5310, g_loss: 0.6508, D(x): 0.73, D(G(z)): 0.52
# Elapsed time: 5.5388 seconds, Epoch [1/200], Step [30/123], d_loss: 0.4938, g_loss: 0.6260, D(x): 0.82, D(G(z)): 0.53
# Elapsed time: 6.3884 seconds, Epoch [1/200], Step [40/123], d_loss: 0.5036, g_loss: 0.5907, D(x): 0.83, D(G(z)): 0.55
# Elapsed time: 8.2235 seconds, Epoch [1/200], Step [50/123], d_loss: 0.4970, g_loss: 0.5737, D(x): 0.86, D(G(z)): 0.56
# Elapsed time: 9.8149 seconds, Epoch [1/200], Step [60/123], d_loss: 0.5008, g_loss: 0.5800, D(x): 0.84, D(G(z)): 0.56
# Elapsed time: 11.1164 seconds, Epoch [1/200], Step [70/123], d_loss: 0.4901, g_loss: 0.5885, D(x): 0.85, D(G(z)): 0.56
# Elapsed time: 12.5685 seconds, Epoch [1/200], Step [80/123], d_loss: 0.5018, g_loss: 0.5948, D(x): 0.82, D(G(z)): 0.55
# Elapsed time: 13.9117 seconds, Epoch [1/200], Step [90/123], d_loss: 0.5053, g_loss: 0.5835, D(x): 0.83, D(G(z)): 0.56
# Elapsed time: 15.6448 seconds, Epoch [1/200], Step [100/123], d_loss: 0.5100, g_loss: 0.5782, D(x): 0.83, D(G(z)): 0.56
# Elapsed time: 16.8948 seconds, Epoch [1/200], Step [110/123], d_loss: 0.5411, g_loss: 0.5829, D(x): 0.78, D(G(z)): 0.56
# Elapsed time: 17.8364 seconds, Epoch [1/200], Step [120/123], d_loss: 0.5648, g_loss: 0.5890, D(x): 0.74, D(G(z)): 0.56
# Elapsed time: 20.5693 seconds, Epoch [2/200], Step [10/123], d_loss: 0.5295, g_loss: 0.5937, D(x): 0.78, D(G(z)): 0.55
# Elapsed time: 21.7189 seconds, Epoch [2/200], Step [20/123], d_loss: 0.5707, g_loss: 0.5687, D(x): 0.74, D(G(z)): 0.57
# Elapsed time: 22.9039 seconds, Epoch [2/200], Step [30/123], d_loss: 0.5372, g_loss: 0.6315, D(x): 0.74, D(G(z)): 0.53
# Elapsed time: 24.1676 seconds, Epoch [2/200], Step [40/123], d_loss: 0.5383, g_loss: 0.6257, D(x): 0.74, D(G(z)): 0.54
# Elapsed time: 26.4346 seconds, Epoch [2/200], Step [50/123], d_loss: 0.5268, g_loss: 0.6221, D(x): 0.76, D(G(z)): 0.54
# Elapsed time: 27.9997 seconds, Epoch [2/200], Step [60/123], d_loss: 0.5457, g_loss: 0.7042, D(x): 0.68, D(G(z)): 0.50
# Elapsed time: 28.7982 seconds, Epoch [2/200], Step [70/123], d_loss: 0.5351, g_loss: 0.7067, D(x): 0.69, D(G(z)): 0.49
# Elapsed time: 29.5906 seconds, Epoch [2/200], Step [80/123], d_loss: 0.5790, g_loss: 0.6260, D(x): 0.70, D(G(z)): 0.54
# Elapsed time: 31.7520 seconds, Epoch [2/200], Step [90/123], d_loss: 0.5909, g_loss: 0.6541, D(x): 0.67, D(G(z)): 0.52
# Elapsed time: 32.7529 seconds, Epoch [2/200], Step [100/123], d_loss: 0.6778, g_loss: 0.5189, D(x): 0.71, D(G(z)): 0.61
# Elapsed time: 34.2521 seconds, Epoch [2/200], Step [110/123], d_loss: 0.6331, g_loss: 0.6107, D(x): 0.67, D(G(z)): 0.55
# Elapsed time: 35.1652 seconds, Epoch [2/200], Step [120/123], d_loss: 0.6240, g_loss: 0.6432, D(x): 0.64, D(G(z)): 0.53
# Elapsed time: 38.2279 seconds, Epoch [3/200], Step [10/123], d_loss: 0.5589, g_loss: 0.6684, D(x): 0.68, D(G(z)): 0.51
# Elapsed time: 39.1893 seconds, Epoch [3/200], Step [20/123], d_loss: 0.5986, g_loss: 0.7630, D(x): 0.59, D(G(z)): 0.47
# Elapsed time: 41.0932 seconds, Epoch [3/200], Step [30/123], d_loss: 0.5885, g_loss: 0.6483, D(x): 0.66, D(G(z)): 0.53
# Elapsed time: 42.0634 seconds, Epoch [3/200], Step [40/123], d_loss: 0.5969, g_loss: 0.7318, D(x): 0.63, D(G(z)): 0.48
# Elapsed time: 43.9634 seconds, Epoch [3/200], Step [50/123], d_loss: 0.5558, g_loss: 0.7738, D(x): 0.63, D(G(z)): 0.46
# Elapsed time: 45.1605 seconds, Epoch [3/200], Step [60/123], d_loss: 0.5767, g_loss: 0.8182, D(x): 0.58, D(G(z)): 0.44
# Elapsed time: 46.0751 seconds, Epoch [3/200], Step [70/123], d_loss: 0.5862, g_loss: 0.8040, D(x): 0.59, D(G(z)): 0.45
# Elapsed time: 47.4170 seconds, Epoch [3/200], Step [80/123], d_loss: 0.5919, g_loss: 0.7125, D(x): 0.63, D(G(z)): 0.50
# Elapsed time: 49.4422 seconds, Epoch [3/200], Step [90/123], d_loss: 0.5209, g_loss: 0.8111, D(x): 0.65, D(G(z)): 0.45
# Elapsed time: 50.7701 seconds, Epoch [3/200], Step [100/123], d_loss: 0.5020, g_loss: 0.8747, D(x): 0.65, D(G(z)): 0.42
# Elapsed time: 51.9525 seconds, Epoch [3/200], Step [110/123], d_loss: 0.5008, g_loss: 1.0076, D(x): 0.61, D(G(z)): 0.37
# Elapsed time: 52.8657 seconds, Epoch [3/200], Step [120/123], d_loss: 0.4521, g_loss: 0.9081, D(x): 0.70, D(G(z)): 0.40
# Elapsed time: 56.0443 seconds, Epoch [4/200], Step [10/123], d_loss: 0.5388, g_loss: 0.9430, D(x): 0.58, D(G(z)): 0.39
# Elapsed time: 57.9303 seconds, Epoch [4/200], Step [20/123], d_loss: 0.4449, g_loss: 0.8960, D(x): 0.72, D(G(z)): 0.41
# Elapsed time: 59.2244 seconds, Epoch [4/200], Step [30/123], d_loss: 0.4650, g_loss: 0.9630, D(x): 0.67, D(G(z)): 0.38
# Elapsed time: 60.7917 seconds, Epoch [4/200], Step [40/123], d_loss: 0.5312, g_loss: 0.7311, D(x): 0.70, D(G(z)): 0.48
# Elapsed time: 62.0563 seconds, Epoch [4/200], Step [50/123], d_loss: 0.4970, g_loss: 1.0008, D(x): 0.63, D(G(z)): 0.38
# Elapsed time: 63.1854 seconds, Epoch [4/200], Step [60/123], d_loss: 0.5244, g_loss: 0.8409, D(x): 0.65, D(G(z)): 0.44
# Elapsed time: 64.2922 seconds, Epoch [4/200], Step [70/123], d_loss: 0.5210, g_loss: 0.7657, D(x): 0.70, D(G(z)): 0.48
# Elapsed time: 66.5991 seconds, Epoch [4/200], Step [80/123], d_loss: 0.5751, g_loss: 0.8142, D(x): 0.63, D(G(z)): 0.46
# Elapsed time: 67.5187 seconds, Epoch [4/200], Step [90/123], d_loss: 0.6061, g_loss: 0.6425, D(x): 0.66, D(G(z)): 0.53
# Elapsed time: 69.1781 seconds, Epoch [4/200], Step [100/123], d_loss: 0.5892, g_loss: 0.7107, D(x): 0.63, D(G(z)): 0.50
# Elapsed time: 70.3954 seconds, Epoch [4/200], Step [110/123], d_loss: 0.5608, g_loss: 0.7686, D(x): 0.64, D(G(z)): 0.47
# Elapsed time: 71.6986 seconds, Epoch [4/200], Step [120/123], d_loss: 0.5399, g_loss: 0.7019, D(x): 0.71, D(G(z)): 0.51
# Elapsed time: 74.8022 seconds, Epoch [5/200], Step [10/123], d_loss: 0.5473, g_loss: 0.7655, D(x): 0.68, D(G(z)): 0.48
# Elapsed time: 76.0712 seconds, Epoch [5/200], Step [20/123], d_loss: 0.5005, g_loss: 0.8908, D(x): 0.67, D(G(z)): 0.42
# Elapsed time: 77.9383 seconds, Epoch [5/200], Step [30/123], d_loss: 0.5850, g_loss: 0.5857, D(x): 0.73, D(G(z)): 0.56
# Elapsed time: 78.9402 seconds, Epoch [5/200], Step [40/123], d_loss: 0.5479, g_loss: 0.7069, D(x): 0.68, D(G(z)): 0.50
# Elapsed time: 80.3611 seconds, Epoch [5/200], Step [50/123], d_loss: 0.5103, g_loss: 0.8010, D(x): 0.68, D(G(z)): 0.46
# Elapsed time: 81.9275 seconds, Epoch [5/200], Step [60/123], d_loss: 0.5964, g_loss: 0.8238, D(x): 0.56, D(G(z)): 0.45
# Elapsed time: 83.4190 seconds, Epoch [5/200], Step [70/123], d_loss: 0.5731, g_loss: 0.8087, D(x): 0.58, D(G(z)): 0.45
# Elapsed time: 84.3009 seconds, Epoch [5/200], Step [80/123], d_loss: 0.5625, g_loss: 0.8918, D(x): 0.57, D(G(z)): 0.42
# Elapsed time: 86.5084 seconds, Epoch [5/200], Step [90/123], d_loss: 0.5249, g_loss: 0.8526, D(x): 0.63, D(G(z)): 0.43
# Elapsed time: 88.0052 seconds, Epoch [5/200], Step [100/123], d_loss: 0.6036, g_loss: 0.9003, D(x): 0.52, D(G(z)): 0.41
# Elapsed time: 89.6212 seconds, Epoch [5/200], Step [110/123], d_loss: 0.6040, g_loss: 1.1045, D(x): 0.47, D(G(z)): 0.34
# Elapsed time: 90.3369 seconds, Epoch [5/200], Step [120/123], d_loss: 0.5968, g_loss: 0.6488, D(x): 0.68, D(G(z)): 0.53
# Elapsed time: 94.1698 seconds, Epoch [6/200], Step [10/123], d_loss: 0.5765, g_loss: 0.8100, D(x): 0.59, D(G(z)): 0.45
# Elapsed time: 96.0968 seconds, Epoch [6/200], Step [20/123], d_loss: 0.6107, g_loss: 0.8034, D(x): 0.56, D(G(z)): 0.45
# Elapsed time: 97.1682 seconds, Epoch [6/200], Step [30/123], d_loss: 0.5641, g_loss: 0.8172, D(x): 0.60, D(G(z)): 0.44
# Elapsed time: 98.2722 seconds, Epoch [6/200], Step [40/123], d_loss: 0.6014, g_loss: 0.7854, D(x): 0.57, D(G(z)): 0.46
# Elapsed time: 100.5490 seconds, Epoch [6/200], Step [50/123], d_loss: 0.6031, g_loss: 0.7381, D(x): 0.59, D(G(z)): 0.48
# Elapsed time: 101.5334 seconds, Epoch [6/200], Step [60/123], d_loss: 0.5849, g_loss: 0.8862, D(x): 0.56, D(G(z)): 0.42
# Elapsed time: 102.4930 seconds, Epoch [6/200], Step [70/123], d_loss: 0.6193, g_loss: 0.8176, D(x): 0.54, D(G(z)): 0.45
# Elapsed time: 103.4494 seconds, Epoch [6/200], Step [80/123], d_loss: 0.5501, g_loss: 0.9368, D(x): 0.56, D(G(z)): 0.40
# Elapsed time: 105.5845 seconds, Epoch [6/200], Step [90/123], d_loss: 0.5631, g_loss: 0.9570, D(x): 0.55, D(G(z)): 0.39
# Elapsed time: 106.6512 seconds, Epoch [6/200], Step [100/123], d_loss: 0.5584, g_loss: 0.9122, D(x): 0.57, D(G(z)): 0.41
# Elapsed time: 107.9592 seconds, Epoch [6/200], Step [110/123], d_loss: 0.5600, g_loss: 0.8087, D(x): 0.61, D(G(z)): 0.45
# Elapsed time: 109.5605 seconds, Epoch [6/200], Step [120/123], d_loss: 0.5456, g_loss: 0.8256, D(x): 0.62, D(G(z)): 0.44
# Elapsed time: 112.4542 seconds, Epoch [7/200], Step [10/123], d_loss: 0.5434, g_loss: 0.8484, D(x): 0.62, D(G(z)): 0.43
# Elapsed time: 113.1913 seconds, Epoch [7/200], Step [20/123], d_loss: 0.5725, g_loss: 0.8123, D(x): 0.60, D(G(z)): 0.45
# Elapsed time: 114.9306 seconds, Epoch [7/200], Step [30/123], d_loss: 0.5960, g_loss: 0.7760, D(x): 0.59, D(G(z)): 0.46
# Elapsed time: 116.4486 seconds, Epoch [7/200], Step [40/123], d_loss: 0.6169, g_loss: 0.9044, D(x): 0.51, D(G(z)): 0.41
# Elapsed time: 117.7878 seconds, Epoch [7/200], Step [50/123], d_loss: 0.6032, g_loss: 0.8161, D(x): 0.56, D(G(z)): 0.44
# Elapsed time: 119.2099 seconds, Epoch [7/200], Step [60/123], d_loss: 0.5277, g_loss: 0.8935, D(x): 0.62, D(G(z)): 0.41
# Elapsed time: 121.1034 seconds, Epoch [7/200], Step [70/123], d_loss: 0.5997, g_loss: 0.8089, D(x): 0.56, D(G(z)): 0.45
# Elapsed time: 122.1843 seconds, Epoch [7/200], Step [80/123], d_loss: 0.5586, g_loss: 0.8802, D(x): 0.58, D(G(z)): 0.42
# Elapsed time: 123.3597 seconds, Epoch [7/200], Step [90/123], d_loss: 0.5678, g_loss: 0.7278, D(x): 0.63, D(G(z)): 0.49
# Elapsed time: 125.4297 seconds, Epoch [7/200], Step [100/123], d_loss: 0.5120, g_loss: 0.8943, D(x): 0.63, D(G(z)): 0.41
# Elapsed time: 126.9447 seconds, Epoch [7/200], Step [110/123], d_loss: 0.6209, g_loss: 0.9515, D(x): 0.50, D(G(z)): 0.40
# Elapsed time: 127.8640 seconds, Epoch [7/200], Step [120/123], d_loss: 0.6144, g_loss: 0.8660, D(x): 0.52, D(G(z)): 0.43
# Elapsed time: 130.3553 seconds, Epoch [8/200], Step [10/123], d_loss: 0.6426, g_loss: 0.8079, D(x): 0.51, D(G(z)): 0.45
# Elapsed time: 132.3527 seconds, Epoch [8/200], Step [20/123], d_loss: 0.6255, g_loss: 0.7816, D(x): 0.54, D(G(z)): 0.46
# Elapsed time: 133.3332 seconds, Epoch [8/200], Step [30/123], d_loss: 0.5849, g_loss: 0.8092, D(x): 0.57, D(G(z)): 0.45
# Elapsed time: 134.9417 seconds, Epoch [8/200], Step [40/123], d_loss: 0.5567, g_loss: 0.8489, D(x): 0.60, D(G(z)): 0.43
# Elapsed time: 135.9655 seconds, Epoch [8/200], Step [50/123], d_loss: 0.5598, g_loss: 0.8279, D(x): 0.59, D(G(z)): 0.44
# Elapsed time: 137.4980 seconds, Epoch [8/200], Step [60/123], d_loss: 0.6680, g_loss: 0.9794, D(x): 0.45, D(G(z)): 0.39
# Elapsed time: 138.6857 seconds, Epoch [8/200], Step [70/123], d_loss: 0.5820, g_loss: 0.8785, D(x): 0.56, D(G(z)): 0.42
# Elapsed time: 140.8236 seconds, Epoch [8/200], Step [80/123], d_loss: 0.5593, g_loss: 0.8935, D(x): 0.57, D(G(z)): 0.41
# Elapsed time: 141.7029 seconds, Epoch [8/200], Step [90/123], d_loss: 0.5900, g_loss: 0.8946, D(x): 0.54, D(G(z)): 0.41
# Elapsed time: 142.7983 seconds, Epoch [8/200], Step [100/123], d_loss: 0.6150, g_loss: 0.9371, D(x): 0.49, D(G(z)): 0.39
# Elapsed time: 143.9030 seconds, Epoch [8/200], Step [110/123], d_loss: 0.6221, g_loss: 0.6769, D(x): 0.62, D(G(z)): 0.52
# Elapsed time: 145.8228 seconds, Epoch [8/200], Step [120/123], d_loss: 0.6503, g_loss: 0.8988, D(x): 0.47, D(G(z)): 0.41
# Elapsed time: 148.8033 seconds, Epoch [9/200], Step [10/123], d_loss: 0.6158, g_loss: 0.9316, D(x): 0.51, D(G(z)): 0.40
# Elapsed time: 150.3991 seconds, Epoch [9/200], Step [20/123], d_loss: 0.5714, g_loss: 0.8820, D(x): 0.58, D(G(z)): 0.42
# Elapsed time: 151.6370 seconds, Epoch [9/200], Step [30/123], d_loss: 0.5911, g_loss: 0.7672, D(x): 0.60, D(G(z)): 0.47
# Elapsed time: 152.9000 seconds, Epoch [9/200], Step [40/123], d_loss: 0.6403, g_loss: 0.8855, D(x): 0.50, D(G(z)): 0.42
# Elapsed time: 155.0403 seconds, Epoch [9/200], Step [50/123], d_loss: 0.6394, g_loss: 0.7574, D(x): 0.54, D(G(z)): 0.47
# Elapsed time: 156.2057 seconds, Epoch [9/200], Step [60/123], d_loss: 0.6261, g_loss: 0.9914, D(x): 0.47, D(G(z)): 0.38
# Elapsed time: 157.7264 seconds, Epoch [9/200], Step [70/123], d_loss: 0.6185, g_loss: 1.0261, D(x): 0.47, D(G(z)): 0.36
# Elapsed time: 158.9551 seconds, Epoch [9/200], Step [80/123], d_loss: 0.6167, g_loss: 0.8778, D(x): 0.51, D(G(z)): 0.42
# Elapsed time: 160.9815 seconds, Epoch [9/200], Step [90/123], d_loss: 0.6077, g_loss: 0.9863, D(x): 0.51, D(G(z)): 0.38
# Elapsed time: 162.0494 seconds, Epoch [9/200], Step [100/123], d_loss: 0.6443, g_loss: 0.9461, D(x): 0.47, D(G(z)): 0.39
# Elapsed time: 163.1168 seconds, Epoch [9/200], Step [110/123], d_loss: 0.5996, g_loss: 0.9817, D(x): 0.50, D(G(z)): 0.38
# Elapsed time: 164.0184 seconds, Epoch [9/200], Step [120/123], d_loss: 0.5962, g_loss: 0.7915, D(x): 0.57, D(G(z)): 0.46
# Elapsed time: 166.7757 seconds, Epoch [10/200], Step [10/123], d_loss: 0.6164, g_loss: 0.9751, D(x): 0.49, D(G(z)): 0.38
# Elapsed time: 168.1516 seconds, Epoch [10/200], Step [20/123], d_loss: 0.6501, g_loss: 0.5503, D(x): 0.72, D(G(z)): 0.59
# Elapsed time: 169.8122 seconds, Epoch [10/200], Step [30/123], d_loss: 0.6110, g_loss: 0.8946, D(x): 0.51, D(G(z)): 0.41
# Elapsed time: 171.1882 seconds, Epoch [10/200], Step [40/123], d_loss: 0.5749, g_loss: 0.7767, D(x): 0.61, D(G(z)): 0.46
# Elapsed time: 172.6428 seconds, Epoch [10/200], Step [50/123], d_loss: 0.6459, g_loss: 0.7991, D(x): 0.51, D(G(z)): 0.45
# Elapsed time: 174.4370 seconds, Epoch [10/200], Step [60/123], d_loss: 0.5913, g_loss: 0.8664, D(x): 0.55, D(G(z)): 0.42
# Elapsed time: 175.7247 seconds, Epoch [10/200], Step [70/123], d_loss: 0.5638, g_loss: 0.7705, D(x): 0.62, D(G(z)): 0.47
# Elapsed time: 176.8482 seconds, Epoch [10/200], Step [80/123], d_loss: 0.5755, g_loss: 0.8414, D(x): 0.58, D(G(z)): 0.43
# Elapsed time: 178.7230 seconds, Epoch [10/200], Step [90/123], d_loss: 0.6242, g_loss: 0.6926, D(x): 0.60, D(G(z)): 0.50
# Elapsed time: 179.7779 seconds, Epoch [10/200], Step [100/123], d_loss: 0.5290, g_loss: 1.0685, D(x): 0.58, D(G(z)): 0.35
# Elapsed time: 180.8142 seconds, Epoch [10/200], Step [110/123], d_loss: 0.5975, g_loss: 0.8452, D(x): 0.55, D(G(z)): 0.43
# Elapsed time: 182.1047 seconds, Epoch [10/200], Step [120/123], d_loss: 0.5921, g_loss: 0.8881, D(x): 0.53, D(G(z)): 0.41
# Elapsed time: 185.9475 seconds, Epoch [11/200], Step [10/123], d_loss: 0.5663, g_loss: 0.8835, D(x): 0.57, D(G(z)): 0.42
# Elapsed time: 187.3770 seconds, Epoch [11/200], Step [20/123], d_loss: 0.5768, g_loss: 0.8219, D(x): 0.58, D(G(z)): 0.44
# Elapsed time: 188.7719 seconds, Epoch [11/200], Step [30/123], d_loss: 0.5854, g_loss: 0.7804, D(x): 0.59, D(G(z)): 0.46
# Elapsed time: 189.7343 seconds, Epoch [11/200], Step [40/123], d_loss: 0.6217, g_loss: 0.7974, D(x): 0.54, D(G(z)): 0.45
# Elapsed time: 191.7518 seconds, Epoch [11/200], Step [50/123], d_loss: 0.6232, g_loss: 0.7439, D(x): 0.57, D(G(z)): 0.48
# Elapsed time: 192.9413 seconds, Epoch [11/200], Step [60/123], d_loss: 0.6978, g_loss: 0.6097, D(x): 0.58, D(G(z)): 0.55
# Elapsed time: 194.2747 seconds, Epoch [11/200], Step [70/123], d_loss: 0.5928, g_loss: 0.8724, D(x): 0.55, D(G(z)): 0.42
# Elapsed time: 195.2194 seconds, Epoch [11/200], Step [80/123], d_loss: 0.6164, g_loss: 0.7114, D(x): 0.58, D(G(z)): 0.49
# Elapsed time: 196.9771 seconds, Epoch [11/200], Step [90/123], d_loss: 0.5990, g_loss: 1.0435, D(x): 0.50, D(G(z)): 0.36
# Elapsed time: 198.7134 seconds, Epoch [11/200], Step [100/123], d_loss: 0.5834, g_loss: 0.7549, D(x): 0.61, D(G(z)): 0.47
# Elapsed time: 200.0126 seconds, Epoch [11/200], Step [110/123], d_loss: 0.5946, g_loss: 0.7772, D(x): 0.58, D(G(z)): 0.46
# Elapsed time: 200.7843 seconds, Epoch [11/200], Step [120/123], d_loss: 0.5879, g_loss: 0.8716, D(x): 0.54, D(G(z)): 0.42
# Elapsed time: 204.5526 seconds, Epoch [12/200], Step [10/123], d_loss: 0.6109, g_loss: 0.9591, D(x): 0.51, D(G(z)): 0.39
# Elapsed time: 206.1306 seconds, Epoch [12/200], Step [20/123], d_loss: 0.5932, g_loss: 0.8361, D(x): 0.56, D(G(z)): 0.43
# Elapsed time: 207.3121 seconds, Epoch [12/200], Step [30/123], d_loss: 0.6377, g_loss: 0.7890, D(x): 0.53, D(G(z)): 0.46
# Elapsed time: 208.2475 seconds, Epoch [12/200], Step [40/123], d_loss: 0.6180, g_loss: 0.8426, D(x): 0.53, D(G(z)): 0.43
# Elapsed time: 209.7740 seconds, Epoch [12/200], Step [50/123], d_loss: 0.5472, g_loss: 0.9606, D(x): 0.57, D(G(z)): 0.39
# Elapsed time: 211.5002 seconds, Epoch [12/200], Step [60/123], d_loss: 0.5345, g_loss: 1.0187, D(x): 0.57, D(G(z)): 0.37
# Elapsed time: 212.6150 seconds, Epoch [12/200], Step [70/123], d_loss: 0.6010, g_loss: 1.0026, D(x): 0.51, D(G(z)): 0.37
# Elapsed time: 213.9586 seconds, Epoch [12/200], Step [80/123], d_loss: 0.5551, g_loss: 0.9212, D(x): 0.57, D(G(z)): 0.40
# Elapsed time: 215.4822 seconds, Epoch [12/200], Step [90/123], d_loss: 0.6120, g_loss: 0.8653, D(x): 0.52, D(G(z)): 0.42
# Elapsed time: 217.3121 seconds, Epoch [12/200], Step [100/123], d_loss: 0.6280, g_loss: 0.7235, D(x): 0.58, D(G(z)): 0.49
# Elapsed time: 218.5880 seconds, Epoch [12/200], Step [110/123], d_loss: 0.5760, g_loss: 0.8053, D(x): 0.59, D(G(z)): 0.45
# Elapsed time: 219.2968 seconds, Epoch [12/200], Step [120/123], d_loss: 0.5343, g_loss: 0.9345, D(x): 0.59, D(G(z)): 0.40
# Elapsed time: 221.9326 seconds, Epoch [13/200], Step [10/123], d_loss: 0.5952, g_loss: 0.8980, D(x): 0.53, D(G(z)): 0.41
# Elapsed time: 223.4755 seconds, Epoch [13/200], Step [20/123], d_loss: 0.5674, g_loss: 0.9071, D(x): 0.55, D(G(z)): 0.41
# Elapsed time: 225.1856 seconds, Epoch [13/200], Step [30/123], d_loss: 0.5657, g_loss: 0.9014, D(x): 0.58, D(G(z)): 0.41
# Elapsed time: 226.1344 seconds, Epoch [13/200], Step [40/123], d_loss: 0.6016, g_loss: 1.1036, D(x): 0.50, D(G(z)): 0.34
# Elapsed time: 228.0621 seconds, Epoch [13/200], Step [50/123], d_loss: 0.6090, g_loss: 0.8516, D(x): 0.54, D(G(z)): 0.43
# Elapsed time: 229.1437 seconds, Epoch [13/200], Step [60/123], d_loss: 0.6394, g_loss: 0.8646, D(x): 0.51, D(G(z)): 0.43
# Elapsed time: 230.7307 seconds, Epoch [13/200], Step [70/123], d_loss: 0.5938, g_loss: 0.8845, D(x): 0.53, D(G(z)): 0.42
# Elapsed time: 232.0517 seconds, Epoch [13/200], Step [80/123], d_loss: 0.5813, g_loss: 0.9068, D(x): 0.55, D(G(z)): 0.41
# Elapsed time: 233.7386 seconds, Epoch [13/200], Step [90/123], d_loss: 0.5407, g_loss: 0.8661, D(x): 0.60, D(G(z)): 0.42
# Elapsed time: 235.2962 seconds, Epoch [13/200], Step [100/123], d_loss: 0.6288, g_loss: 0.7930, D(x): 0.54, D(G(z)): 0.45
# Elapsed time: 236.4364 seconds, Epoch [13/200], Step [110/123], d_loss: 0.5869, g_loss: 0.9584, D(x): 0.52, D(G(z)): 0.39
# Elapsed time: 237.2628 seconds, Epoch [13/200], Step [120/123], d_loss: 0.6055, g_loss: 0.8490, D(x): 0.54, D(G(z)): 0.43
# Elapsed time: 240.4038 seconds, Epoch [14/200], Step [10/123], d_loss: 0.6088, g_loss: 0.7125, D(x): 0.61, D(G(z)): 0.49
# Elapsed time: 241.4827 seconds, Epoch [14/200], Step [20/123], d_loss: 0.6189, g_loss: 0.6755, D(x): 0.60, D(G(z)): 0.51
# Elapsed time: 243.8051 seconds, Epoch [14/200], Step [30/123], d_loss: 0.6022, g_loss: 0.9322, D(x): 0.53, D(G(z)): 0.40
# Elapsed time: 244.9685 seconds, Epoch [14/200], Step [40/123], d_loss: 0.5774, g_loss: 0.8200, D(x): 0.58, D(G(z)): 0.44
# Elapsed time: 245.7608 seconds, Epoch [14/200], Step [50/123], d_loss: 0.5998, g_loss: 0.7848, D(x): 0.56, D(G(z)): 0.46
# Elapsed time: 246.9323 seconds, Epoch [14/200], Step [60/123], d_loss: 0.5830, g_loss: 0.8738, D(x): 0.55, D(G(z)): 0.42
# Elapsed time: 248.8245 seconds, Epoch [14/200], Step [70/123], d_loss: 0.6383, g_loss: 0.7352, D(x): 0.55, D(G(z)): 0.48
# Elapsed time: 250.1690 seconds, Epoch [14/200], Step [80/123], d_loss: 0.6433, g_loss: 0.7181, D(x): 0.56, D(G(z)): 0.49
# Elapsed time: 251.0478 seconds, Epoch [14/200], Step [90/123], d_loss: 0.6051, g_loss: 0.6895, D(x): 0.63, D(G(z)): 0.50
# Elapsed time: 253.2173 seconds, Epoch [14/200], Step [100/123], d_loss: 0.5846, g_loss: 0.8948, D(x): 0.56, D(G(z)): 0.41
# Elapsed time: 254.5134 seconds, Epoch [14/200], Step [110/123], d_loss: 0.6074, g_loss: 0.7075, D(x): 0.61, D(G(z)): 0.50
# Elapsed time: 255.2632 seconds, Epoch [14/200], Step [120/123], d_loss: 0.5464, g_loss: 1.0112, D(x): 0.57, D(G(z)): 0.37
# Elapsed time: 258.0232 seconds, Epoch [15/200], Step [10/123], d_loss: 0.5716, g_loss: 0.7040, D(x): 0.65, D(G(z)): 0.50
# Elapsed time: 259.3215 seconds, Epoch [15/200], Step [20/123], d_loss: 0.6094, g_loss: 0.8786, D(x): 0.53, D(G(z)): 0.42
# Elapsed time: 261.0134 seconds, Epoch [15/200], Step [30/123], d_loss: 0.5771, g_loss: 0.9544, D(x): 0.54, D(G(z)): 0.39
# Elapsed time: 262.3487 seconds, Epoch [15/200], Step [40/123], d_loss: 0.5954, g_loss: 0.6720, D(x): 0.65, D(G(z)): 0.52
# Elapsed time: 263.3809 seconds, Epoch [15/200], Step [50/123], d_loss: 0.6523, g_loss: 0.5585, D(x): 0.68, D(G(z)): 0.58
# Elapsed time: 265.3139 seconds, Epoch [15/200], Step [60/123], d_loss: 0.5431, g_loss: 0.7264, D(x): 0.68, D(G(z)): 0.49
# Elapsed time: 266.3439 seconds, Epoch [15/200], Step [70/123], d_loss: 0.5795, g_loss: 0.9162, D(x): 0.55, D(G(z)): 0.40
# Elapsed time: 267.5639 seconds, Epoch [15/200], Step [80/123], d_loss: 0.5959, g_loss: 0.8306, D(x): 0.57, D(G(z)): 0.44
# Elapsed time: 268.5147 seconds, Epoch [15/200], Step [90/123], d_loss: 0.6265, g_loss: 1.0343, D(x): 0.50, D(G(z)): 0.37
# Elapsed time: 270.6603 seconds, Epoch [15/200], Step [100/123], d_loss: 0.5772, g_loss: 0.9709, D(x): 0.54, D(G(z)): 0.38
# Elapsed time: 271.5948 seconds, Epoch [15/200], Step [110/123], d_loss: 0.6139, g_loss: 0.8731, D(x): 0.51, D(G(z)): 0.42
# Elapsed time: 272.4146 seconds, Epoch [15/200], Step [120/123], d_loss: 0.5852, g_loss: 0.7958, D(x): 0.59, D(G(z)): 0.45
# Elapsed time: 275.3338 seconds, Epoch [16/200], Step [10/123], d_loss: 0.5952, g_loss: 0.8592, D(x): 0.54, D(G(z)): 0.43
# Elapsed time: 276.7026 seconds, Epoch [16/200], Step [20/123], d_loss: 0.5976, g_loss: 0.7562, D(x): 0.59, D(G(z)): 0.47
# Elapsed time: 277.7768 seconds, Epoch [16/200], Step [30/123], d_loss: 0.5765, g_loss: 0.8524, D(x): 0.57, D(G(z)): 0.43
# Elapsed time: 278.9455 seconds, Epoch [16/200], Step [40/123], d_loss: 0.5825, g_loss: 0.7504, D(x): 0.60, D(G(z)): 0.47
# Elapsed time: 280.6904 seconds, Epoch [16/200], Step [50/123], d_loss: 0.6021, g_loss: 0.6855, D(x): 0.62, D(G(z)): 0.51
# Elapsed time: 281.7632 seconds, Epoch [16/200], Step [60/123], d_loss: 0.6587, g_loss: 0.7394, D(x): 0.53, D(G(z)): 0.48
# Elapsed time: 282.8282 seconds, Epoch [16/200], Step [70/123], d_loss: 0.6351, g_loss: 0.7344, D(x): 0.55, D(G(z)): 0.48
# Elapsed time: 284.7896 seconds, Epoch [16/200], Step [80/123], d_loss: 0.6169, g_loss: 0.8026, D(x): 0.54, D(G(z)): 0.45
# Elapsed time: 285.9341 seconds, Epoch [16/200], Step [90/123], d_loss: 0.6583, g_loss: 0.9385, D(x): 0.46, D(G(z)): 0.40
# Elapsed time: 287.6444 seconds, Epoch [16/200], Step [100/123], d_loss: 0.6738, g_loss: 0.7711, D(x): 0.52, D(G(z)): 0.47
# Elapsed time: 288.4135 seconds, Epoch [16/200], Step [110/123], d_loss: 0.6026, g_loss: 0.8998, D(x): 0.52, D(G(z)): 0.41
# Elapsed time: 290.0252 seconds, Epoch [16/200], Step [120/123], d_loss: 0.6168, g_loss: 0.8880, D(x): 0.52, D(G(z)): 0.42
# Elapsed time: 292.3105 seconds, Epoch [17/200], Step [10/123], d_loss: 0.7080, g_loss: 1.0239, D(x): 0.41, D(G(z)): 0.37
# Elapsed time: 293.9341 seconds, Epoch [17/200], Step [20/123], d_loss: 0.6505, g_loss: 0.6249, D(x): 0.63, D(G(z)): 0.55
# Elapsed time: 295.2237 seconds, Epoch [17/200], Step [30/123], d_loss: 0.5973, g_loss: 0.7409, D(x): 0.60, D(G(z)): 0.48
# Elapsed time: 296.7449 seconds, Epoch [17/200], Step [40/123], d_loss: 0.6262, g_loss: 0.7327, D(x): 0.57, D(G(z)): 0.48
# Elapsed time: 298.4374 seconds, Epoch [17/200], Step [50/123], d_loss: 0.6547, g_loss: 0.8400, D(x): 0.49, D(G(z)): 0.44
# Elapsed time: 299.7587 seconds, Epoch [17/200], Step [60/123], d_loss: 0.6165, g_loss: 0.7353, D(x): 0.58, D(G(z)): 0.48
# Elapsed time: 301.1104 seconds, Epoch [17/200], Step [70/123], d_loss: 0.5448, g_loss: 1.0394, D(x): 0.57, D(G(z)): 0.36
# Elapsed time: 302.6393 seconds, Epoch [17/200], Step [80/123], d_loss: 0.5886, g_loss: 0.9769, D(x): 0.53, D(G(z)): 0.38
# Elapsed time: 304.0665 seconds, Epoch [17/200], Step [90/123], d_loss: 0.6400, g_loss: 0.6331, D(x): 0.63, D(G(z)): 0.54
# Elapsed time: 305.6498 seconds, Epoch [17/200], Step [100/123], d_loss: 0.5869, g_loss: 0.8631, D(x): 0.57, D(G(z)): 0.43
# Elapsed time: 306.7525 seconds, Epoch [17/200], Step [110/123], d_loss: 0.6555, g_loss: 0.6588, D(x): 0.60, D(G(z)): 0.53
# Elapsed time: 307.8606 seconds, Epoch [17/200], Step [120/123], d_loss: 0.5808, g_loss: 0.9119, D(x): 0.56, D(G(z)): 0.41
# Elapsed time: 310.4113 seconds, Epoch [18/200], Step [10/123], d_loss: 0.6019, g_loss: 0.7484, D(x): 0.60, D(G(z)): 0.48
# Elapsed time: 312.0714 seconds, Epoch [18/200], Step [20/123], d_loss: 0.6054, g_loss: 0.7520, D(x): 0.59, D(G(z)): 0.48
# Elapsed time: 313.2774 seconds, Epoch [18/200], Step [30/123], d_loss: 0.6247, g_loss: 0.8257, D(x): 0.54, D(G(z)): 0.44
# Elapsed time: 314.0695 seconds, Epoch [18/200], Step [40/123], d_loss: 0.6095, g_loss: 0.8983, D(x): 0.52, D(G(z)): 0.41
# Elapsed time: 316.5298 seconds, Epoch [18/200], Step [50/123], d_loss: 0.6035, g_loss: 1.0585, D(x): 0.47, D(G(z)): 0.35
# Elapsed time: 317.8109 seconds, Epoch [18/200], Step [60/123], d_loss: 0.6291, g_loss: 0.7930, D(x): 0.54, D(G(z)): 0.46
# Elapsed time: 318.7301 seconds, Epoch [18/200], Step [70/123], d_loss: 0.6291, g_loss: 0.7447, D(x): 0.57, D(G(z)): 0.48
# Elapsed time: 319.8388 seconds, Epoch [18/200], Step [80/123], d_loss: 0.6704, g_loss: 0.7156, D(x): 0.54, D(G(z)): 0.49
# Elapsed time: 322.1895 seconds, Epoch [18/200], Step [90/123], d_loss: 0.6419, g_loss: 0.7743, D(x): 0.54, D(G(z)): 0.47
# Elapsed time: 323.2278 seconds, Epoch [18/200], Step [100/123], d_loss: 0.6271, g_loss: 0.7030, D(x): 0.59, D(G(z)): 0.50
# Elapsed time: 324.3134 seconds, Epoch [18/200], Step [110/123], d_loss: 0.6519, g_loss: 0.7218, D(x): 0.55, D(G(z)): 0.49
# Elapsed time: 325.0181 seconds, Epoch [18/200], Step [120/123], d_loss: 0.6304, g_loss: 0.7116, D(x): 0.58, D(G(z)): 0.49
# Elapsed time: 328.2420 seconds, Epoch [19/200], Step [10/123], d_loss: 0.6040, g_loss: 0.7745, D(x): 0.58, D(G(z)): 0.46
# Elapsed time: 329.3703 seconds, Epoch [19/200], Step [20/123], d_loss: 0.6359, g_loss: 0.7678, D(x): 0.54, D(G(z)): 0.47
# Elapsed time: 330.7559 seconds, Epoch [19/200], Step [30/123], d_loss: 0.6822, g_loss: 0.6451, D(x): 0.56, D(G(z)): 0.53
# Elapsed time: 331.8336 seconds, Epoch [19/200], Step [40/123], d_loss: 0.6547, g_loss: 0.6464, D(x): 0.58, D(G(z)): 0.53
# Elapsed time: 334.1123 seconds, Epoch [19/200], Step [50/123], d_loss: 0.5989, g_loss: 0.8173, D(x): 0.56, D(G(z)): 0.45
# Elapsed time: 335.0219 seconds, Epoch [19/200], Step [60/123], d_loss: 0.5985, g_loss: 0.8907, D(x): 0.54, D(G(z)): 0.41
# Elapsed time: 335.8399 seconds, Epoch [19/200], Step [70/123], d_loss: 0.6091, g_loss: 0.8407, D(x): 0.55, D(G(z)): 0.43
# Elapsed time: 336.9101 seconds, Epoch [19/200], Step [80/123], d_loss: 0.6645, g_loss: 0.7658, D(x): 0.51, D(G(z)): 0.47
# Elapsed time: 338.8659 seconds, Epoch [19/200], Step [90/123], d_loss: 0.6313, g_loss: 0.7476, D(x): 0.56, D(G(z)): 0.48
# Elapsed time: 340.2437 seconds, Epoch [19/200], Step [100/123], d_loss: 0.5777, g_loss: 0.8336, D(x): 0.58, D(G(z)): 0.44
# Elapsed time: 341.8266 seconds, Epoch [19/200], Step [110/123], d_loss: 0.6572, g_loss: 0.6085, D(x): 0.63, D(G(z)): 0.55
# Elapsed time: 342.9377 seconds, Epoch [19/200], Step [120/123], d_loss: 0.6415, g_loss: 0.8388, D(x): 0.51, D(G(z)): 0.44
# Elapsed time: 345.9914 seconds, Epoch [20/200], Step [10/123], d_loss: 0.6014, g_loss: 0.7339, D(x): 0.61, D(G(z)): 0.49
# Elapsed time: 347.0732 seconds, Epoch [20/200], Step [20/123], d_loss: 0.6444, g_loss: 0.9004, D(x): 0.50, D(G(z)): 0.41
# Elapsed time: 348.7070 seconds, Epoch [20/200], Step [30/123], d_loss: 0.5511, g_loss: 0.8783, D(x): 0.60, D(G(z)): 0.42
# Elapsed time: 349.6161 seconds, Epoch [20/200], Step [40/123], d_loss: 0.6458, g_loss: 0.7812, D(x): 0.53, D(G(z)): 0.46
# Elapsed time: 351.4316 seconds, Epoch [20/200], Step [50/123], d_loss: 0.6877, g_loss: 0.6049, D(x): 0.61, D(G(z)): 0.56
# Elapsed time: 352.2095 seconds, Epoch [20/200], Step [60/123], d_loss: 0.6220, g_loss: 0.8695, D(x): 0.54, D(G(z)): 0.43
# Elapsed time: 354.1392 seconds, Epoch [20/200], Step [70/123], d_loss: 0.6037, g_loss: 0.7746, D(x): 0.59, D(G(z)): 0.46
# Elapsed time: 355.0130 seconds, Epoch [20/200], Step [80/123], d_loss: 0.7313, g_loss: 0.9952, D(x): 0.41, D(G(z)): 0.38
# Elapsed time: 357.3116 seconds, Epoch [20/200], Step [90/123], d_loss: 0.5971, g_loss: 0.8536, D(x): 0.55, D(G(z)): 0.43
# Elapsed time: 358.4931 seconds, Epoch [20/200], Step [100/123], d_loss: 0.6109, g_loss: 0.9379, D(x): 0.53, D(G(z)): 0.40
# Elapsed time: 359.8482 seconds, Epoch [20/200], Step [110/123], d_loss: 0.6095, g_loss: 0.8701, D(x): 0.54, D(G(z)): 0.43
# Elapsed time: 361.0439 seconds, Epoch [20/200], Step [120/123], d_loss: 0.6537, g_loss: 0.7241, D(x): 0.55, D(G(z)): 0.49
# Elapsed time: 363.9632 seconds, Epoch [21/200], Step [10/123], d_loss: 0.5590, g_loss: 0.8233, D(x): 0.61, D(G(z)): 0.45
# Elapsed time: 365.6758 seconds, Epoch [21/200], Step [20/123], d_loss: 0.6757, g_loss: 0.5780, D(x): 0.65, D(G(z)): 0.58
# Elapsed time: 367.7834 seconds, Epoch [21/200], Step [30/123], d_loss: 0.6001, g_loss: 0.8616, D(x): 0.54, D(G(z)): 0.43
# Elapsed time: 368.6236 seconds, Epoch [21/200], Step [40/123], d_loss: 0.6537, g_loss: 0.8913, D(x): 0.50, D(G(z)): 0.42
# Elapsed time: 369.6033 seconds, Epoch [21/200], Step [50/123], d_loss: 0.6346, g_loss: 0.8520, D(x): 0.52, D(G(z)): 0.43
# Elapsed time: 371.6152 seconds, Epoch [21/200], Step [60/123], d_loss: 0.6489, g_loss: 0.9032, D(x): 0.49, D(G(z)): 0.41
# Elapsed time: 372.9226 seconds, Epoch [21/200], Step [70/123], d_loss: 0.6297, g_loss: 0.7851, D(x): 0.55, D(G(z)): 0.46
# Elapsed time: 374.5001 seconds, Epoch [21/200], Step [80/123], d_loss: 0.6634, g_loss: 0.8642, D(x): 0.49, D(G(z)): 0.43
# Elapsed time: 375.6899 seconds, Epoch [21/200], Step [90/123], d_loss: 0.6410, g_loss: 0.7429, D(x): 0.55, D(G(z)): 0.48
# Elapsed time: 377.3177 seconds, Epoch [21/200], Step [100/123], d_loss: 0.6458, g_loss: 1.0233, D(x): 0.45, D(G(z)): 0.36
# Elapsed time: 378.2736 seconds, Epoch [21/200], Step [110/123], d_loss: 0.7043, g_loss: 0.6574, D(x): 0.56, D(G(z)): 0.53
# Elapsed time: 379.4101 seconds, Epoch [21/200], Step [120/123], d_loss: 0.6501, g_loss: 0.6614, D(x): 0.61, D(G(z)): 0.53
# Elapsed time: 382.0816 seconds, Epoch [22/200], Step [10/123], d_loss: 0.6165, g_loss: 0.7738, D(x): 0.59, D(G(z)): 0.47
# Elapsed time: 383.4997 seconds, Epoch [22/200], Step [20/123], d_loss: 0.6040, g_loss: 0.8416, D(x): 0.55, D(G(z)): 0.44
# Elapsed time: 384.8093 seconds, Epoch [22/200], Step [30/123], d_loss: 0.6169, g_loss: 0.8993, D(x): 0.52, D(G(z)): 0.41
# Elapsed time: 385.8600 seconds, Epoch [22/200], Step [40/123], d_loss: 0.5987, g_loss: 1.0180, D(x): 0.50, D(G(z)): 0.37
# Elapsed time: 387.5126 seconds, Epoch [22/200], Step [50/123], d_loss: 0.6431, g_loss: 0.8533, D(x): 0.50, D(G(z)): 0.43
# Elapsed time: 388.6047 seconds, Epoch [22/200], Step [60/123], d_loss: 0.6304, g_loss: 0.8285, D(x): 0.54, D(G(z)): 0.44
# Elapsed time: 390.1537 seconds, Epoch [22/200], Step [70/123], d_loss: 0.6558, g_loss: 0.6251, D(x): 0.60, D(G(z)): 0.54
# Elapsed time: 391.4638 seconds, Epoch [22/200], Step [80/123], d_loss: 0.5696, g_loss: 0.8809, D(x): 0.58, D(G(z)): 0.42
# Elapsed time: 393.7528 seconds, Epoch [22/200], Step [90/123], d_loss: 0.6204, g_loss: 0.8457, D(x): 0.53, D(G(z)): 0.44
# Elapsed time: 394.7007 seconds, Epoch [22/200], Step [100/123], d_loss: 0.6238, g_loss: 0.7222, D(x): 0.59, D(G(z)): 0.49
# Elapsed time: 396.6875 seconds, Epoch [22/200], Step [110/123], d_loss: 0.5798, g_loss: 0.9746, D(x): 0.53, D(G(z)): 0.38
# Elapsed time: 397.4139 seconds, Epoch [22/200], Step [120/123], d_loss: 0.5568, g_loss: 1.1817, D(x): 0.51, D(G(z)): 0.32
# Elapsed time: 400.1624 seconds, Epoch [23/200], Step [10/123], d_loss: 0.5336, g_loss: 0.9119, D(x): 0.62, D(G(z)): 0.41
# Elapsed time: 401.0524 seconds, Epoch [23/200], Step [20/123], d_loss: 0.6165, g_loss: 0.7704, D(x): 0.57, D(G(z)): 0.47
# Elapsed time: 402.3547 seconds, Epoch [23/200], Step [30/123], d_loss: 0.6104, g_loss: 0.8490, D(x): 0.54, D(G(z)): 0.43
# Elapsed time: 403.5040 seconds, Epoch [23/200], Step [40/123], d_loss: 0.6403, g_loss: 0.7698, D(x): 0.55, D(G(z)): 0.47
# Elapsed time: 405.3258 seconds, Epoch [23/200], Step [50/123], d_loss: 0.6434, g_loss: 1.0365, D(x): 0.46, D(G(z)): 0.36
# Elapsed time: 406.7130 seconds, Epoch [23/200], Step [60/123], d_loss: 0.5914, g_loss: 0.8534, D(x): 0.57, D(G(z)): 0.43
# Elapsed time: 408.7026 seconds, Epoch [23/200], Step [70/123], d_loss: 0.6105, g_loss: 0.8180, D(x): 0.56, D(G(z)): 0.45
# Elapsed time: 409.5654 seconds, Epoch [23/200], Step [80/123], d_loss: 0.6088, g_loss: 0.9231, D(x): 0.52, D(G(z)): 0.40
# Elapsed time: 410.6407 seconds, Epoch [23/200], Step [90/123], d_loss: 0.5973, g_loss: 0.6914, D(x): 0.64, D(G(z)): 0.51
# Elapsed time: 411.8236 seconds, Epoch [23/200], Step [100/123], d_loss: 0.6560, g_loss: 0.6637, D(x): 0.58, D(G(z)): 0.52
# Elapsed time: 413.8493 seconds, Epoch [23/200], Step [110/123], d_loss: 0.6079, g_loss: 0.8163, D(x): 0.57, D(G(z)): 0.45
# Elapsed time: 414.6967 seconds, Epoch [23/200], Step [120/123], d_loss: 0.6447, g_loss: 0.7644, D(x): 0.53, D(G(z)): 0.47
# Elapsed time: 417.6222 seconds, Epoch [24/200], Step [10/123], d_loss: 0.5660, g_loss: 0.8814, D(x): 0.59, D(G(z)): 0.42
# Elapsed time: 418.9450 seconds, Epoch [24/200], Step [20/123], d_loss: 0.5677, g_loss: 0.8505, D(x): 0.60, D(G(z)): 0.43
# Elapsed time: 419.9830 seconds, Epoch [24/200], Step [30/123], d_loss: 0.5852, g_loss: 0.8055, D(x): 0.58, D(G(z)): 0.45
# Elapsed time: 421.2453 seconds, Epoch [24/200], Step [40/123], d_loss: 0.6591, g_loss: 0.9566, D(x): 0.47, D(G(z)): 0.40
# Elapsed time: 423.2233 seconds, Epoch [24/200], Step [50/123], d_loss: 0.6679, g_loss: 0.6930, D(x): 0.57, D(G(z)): 0.51
# Elapsed time: 424.2588 seconds, Epoch [24/200], Step [60/123], d_loss: 0.6384, g_loss: 0.7768, D(x): 0.55, D(G(z)): 0.46
# Elapsed time: 425.3258 seconds, Epoch [24/200], Step [70/123], d_loss: 0.6529, g_loss: 0.7260, D(x): 0.54, D(G(z)): 0.49
# Elapsed time: 427.0400 seconds, Epoch [24/200], Step [80/123], d_loss: 0.6075, g_loss: 0.6897, D(x): 0.62, D(G(z)): 0.51
# Elapsed time: 428.3547 seconds, Epoch [24/200], Step [90/123], d_loss: 0.6279, g_loss: 0.8163, D(x): 0.54, D(G(z)): 0.45
# Elapsed time: 429.5508 seconds, Epoch [24/200], Step [100/123], d_loss: 0.5977, g_loss: 0.8106, D(x): 0.57, D(G(z)): 0.45
# Elapsed time: 430.9057 seconds, Epoch [24/200], Step [110/123], d_loss: 0.5999, g_loss: 0.9521, D(x): 0.53, D(G(z)): 0.40
# Elapsed time: 432.1457 seconds, Epoch [24/200], Step [120/123], d_loss: 0.6360, g_loss: 0.8127, D(x): 0.53, D(G(z)): 0.45
# Elapsed time: 434.5416 seconds, Epoch [25/200], Step [10/123], d_loss: 0.6335, g_loss: 0.9705, D(x): 0.48, D(G(z)): 0.39
# Elapsed time: 436.0603 seconds, Epoch [25/200], Step [20/123], d_loss: 0.6333, g_loss: 0.9229, D(x): 0.49, D(G(z)): 0.41
# Elapsed time: 437.4295 seconds, Epoch [25/200], Step [30/123], d_loss: 0.6066, g_loss: 0.7859, D(x): 0.57, D(G(z)): 0.46
# Elapsed time: 438.5153 seconds, Epoch [25/200], Step [40/123], d_loss: 0.6043, g_loss: 0.7513, D(x): 0.58, D(G(z)): 0.47
# Elapsed time: 440.1005 seconds, Epoch [25/200], Step [50/123], d_loss: 0.5734, g_loss: 0.8345, D(x): 0.58, D(G(z)): 0.44
# Elapsed time: 441.0483 seconds, Epoch [25/200], Step [60/123], d_loss: 0.5969, g_loss: 0.8159, D(x): 0.56, D(G(z)): 0.45
# Elapsed time: 442.9826 seconds, Epoch [25/200], Step [70/123], d_loss: 0.6053, g_loss: 0.7315, D(x): 0.61, D(G(z)): 0.49
# Elapsed time: 444.4181 seconds, Epoch [25/200], Step [80/123], d_loss: 0.6332, g_loss: 0.6731, D(x): 0.60, D(G(z)): 0.51
# Elapsed time: 445.4681 seconds, Epoch [25/200], Step [90/123], d_loss: 0.6123, g_loss: 0.7152, D(x): 0.60, D(G(z)): 0.49
# Elapsed time: 446.9499 seconds, Epoch [25/200], Step [100/123], d_loss: 0.5996, g_loss: 0.7817, D(x): 0.57, D(G(z)): 0.46
# Elapsed time: 448.2912 seconds, Epoch [25/200], Step [110/123], d_loss: 0.6559, g_loss: 0.8338, D(x): 0.50, D(G(z)): 0.44
# Elapsed time: 449.4888 seconds, Epoch [25/200], Step [120/123], d_loss: 0.6548, g_loss: 0.7808, D(x): 0.52, D(G(z)): 0.46
# Elapsed time: 452.6120 seconds, Epoch [26/200], Step [10/123], d_loss: 0.6573, g_loss: 0.7391, D(x): 0.54, D(G(z)): 0.48
# Elapsed time: 453.6702 seconds, Epoch [26/200], Step [20/123], d_loss: 0.6541, g_loss: 0.6786, D(x): 0.59, D(G(z)): 0.52
# Elapsed time: 454.7161 seconds, Epoch [26/200], Step [30/123], d_loss: 0.6820, g_loss: 0.8478, D(x): 0.47, D(G(z)): 0.43
# Elapsed time: 456.6057 seconds, Epoch [26/200], Step [40/123], d_loss: 0.5938, g_loss: 0.9183, D(x): 0.54, D(G(z)): 0.41
# Elapsed time: 457.9705 seconds, Epoch [26/200], Step [50/123], d_loss: 0.6137, g_loss: 0.8175, D(x): 0.57, D(G(z)): 0.45
# Elapsed time: 459.2592 seconds, Epoch [26/200], Step [60/123], d_loss: 0.5758, g_loss: 0.8312, D(x): 0.60, D(G(z)): 0.45
# Elapsed time: 460.3728 seconds, Epoch [26/200], Step [70/123], d_loss: 0.5690, g_loss: 0.8022, D(x): 0.62, D(G(z)): 0.46
# Elapsed time: 461.9727 seconds, Epoch [26/200], Step [80/123], d_loss: 0.6516, g_loss: 0.8759, D(x): 0.50, D(G(z)): 0.43
# Elapsed time: 463.3734 seconds, Epoch [26/200], Step [90/123], d_loss: 0.6201, g_loss: 0.7071, D(x): 0.59, D(G(z)): 0.50
# Elapsed time: 465.1792 seconds, Epoch [26/200], Step [100/123], d_loss: 0.6211, g_loss: 0.7435, D(x): 0.57, D(G(z)): 0.48
# Elapsed time: 465.9522 seconds, Epoch [26/200], Step [110/123], d_loss: 0.7609, g_loss: 0.6173, D(x): 0.54, D(G(z)): 0.55
# Elapsed time: 467.0750 seconds, Epoch [26/200], Step [120/123], d_loss: 0.6081, g_loss: 0.7500, D(x): 0.59, D(G(z)): 0.48
# Elapsed time: 470.0665 seconds, Epoch [27/200], Step [10/123], d_loss: 0.6535, g_loss: 0.8211, D(x): 0.50, D(G(z)): 0.45
# Elapsed time: 471.4663 seconds, Epoch [27/200], Step [20/123], d_loss: 0.7114, g_loss: 0.7026, D(x): 0.52, D(G(z)): 0.50
# Elapsed time: 472.5836 seconds, Epoch [27/200], Step [30/123], d_loss: 0.6556, g_loss: 0.8256, D(x): 0.51, D(G(z)): 0.45
# Elapsed time: 474.0525 seconds, Epoch [27/200], Step [40/123], d_loss: 0.6311, g_loss: 0.7416, D(x): 0.56, D(G(z)): 0.48
# Elapsed time: 475.3432 seconds, Epoch [27/200], Step [50/123], d_loss: 0.6145, g_loss: 0.9360, D(x): 0.50, D(G(z)): 0.40
# Elapsed time: 476.9916 seconds, Epoch [27/200], Step [60/123], d_loss: 0.6370, g_loss: 0.7527, D(x): 0.55, D(G(z)): 0.48
# Elapsed time: 479.1916 seconds, Epoch [27/200], Step [70/123], d_loss: 0.6298, g_loss: 0.7001, D(x): 0.60, D(G(z)): 0.51
# Elapsed time: 480.0843 seconds, Epoch [27/200], Step [80/123], d_loss: 0.6862, g_loss: 0.7656, D(x): 0.49, D(G(z)): 0.47
# Elapsed time: 481.2660 seconds, Epoch [27/200], Step [90/123], d_loss: 0.6793, g_loss: 0.6529, D(x): 0.56, D(G(z)): 0.53
# Elapsed time: 482.1880 seconds, Epoch [27/200], Step [100/123], d_loss: 0.6738, g_loss: 0.6839, D(x): 0.57, D(G(z)): 0.52
# Elapsed time: 484.1640 seconds, Epoch [27/200], Step [110/123], d_loss: 0.7234, g_loss: 0.6837, D(x): 0.52, D(G(z)): 0.51
# Elapsed time: 484.8756 seconds, Epoch [27/200], Step [120/123], d_loss: 0.6443, g_loss: 0.9004, D(x): 0.50, D(G(z)): 0.42
# Elapsed time: 486.9576 seconds, Epoch [28/200], Step [10/123], d_loss: 0.6896, g_loss: 1.0574, D(x): 0.43, D(G(z)): 0.37
# Elapsed time: 488.3081 seconds, Epoch [28/200], Step [20/123], d_loss: 0.6555, g_loss: 0.9742, D(x): 0.46, D(G(z)): 0.39
# Elapsed time: 490.1874 seconds, Epoch [28/200], Step [30/123], d_loss: 0.6332, g_loss: 0.8376, D(x): 0.52, D(G(z)): 0.44
# Elapsed time: 491.9672 seconds, Epoch [28/200], Step [40/123], d_loss: 0.6165, g_loss: 0.7592, D(x): 0.56, D(G(z)): 0.47
# Elapsed time: 493.4513 seconds, Epoch [28/200], Step [50/123], d_loss: 0.6244, g_loss: 0.8092, D(x): 0.54, D(G(z)): 0.45
# Elapsed time: 494.7346 seconds, Epoch [28/200], Step [60/123], d_loss: 0.6231, g_loss: 0.7485, D(x): 0.58, D(G(z)): 0.48
# Elapsed time: 495.9089 seconds, Epoch [28/200], Step [70/123], d_loss: 0.6748, g_loss: 0.9490, D(x): 0.46, D(G(z)): 0.40
# Elapsed time: 497.6128 seconds, Epoch [28/200], Step [80/123], d_loss: 0.6309, g_loss: 0.8281, D(x): 0.51, D(G(z)): 0.44
# Elapsed time: 498.5567 seconds, Epoch [28/200], Step [90/123], d_loss: 0.6342, g_loss: 0.9023, D(x): 0.49, D(G(z)): 0.41
# Elapsed time: 500.1370 seconds, Epoch [28/200], Step [100/123], d_loss: 0.6194, g_loss: 0.8555, D(x): 0.54, D(G(z)): 0.43
# Elapsed time: 501.4996 seconds, Epoch [28/200], Step [110/123], d_loss: 0.6309, g_loss: 0.8811, D(x): 0.51, D(G(z)): 0.42
# Elapsed time: 503.2218 seconds, Epoch [28/200], Step [120/123], d_loss: 0.6093, g_loss: 0.7690, D(x): 0.58, D(G(z)): 0.47
# Elapsed time: 505.4017 seconds, Epoch [29/200], Step [10/123], d_loss: 0.6239, g_loss: 0.7315, D(x): 0.57, D(G(z)): 0.49
# Elapsed time: 507.4946 seconds, Epoch [29/200], Step [20/123], d_loss: 0.6253, g_loss: 0.7707, D(x): 0.56, D(G(z)): 0.47
# Elapsed time: 508.9119 seconds, Epoch [29/200], Step [30/123], d_loss: 0.6452, g_loss: 0.8426, D(x): 0.50, D(G(z)): 0.43
# Elapsed time: 509.9874 seconds, Epoch [29/200], Step [40/123], d_loss: 0.5970, g_loss: 0.7700, D(x): 0.59, D(G(z)): 0.46
# Elapsed time: 511.3863 seconds, Epoch [29/200], Step [50/123], d_loss: 0.6359, g_loss: 0.6887, D(x): 0.58, D(G(z)): 0.51
# Elapsed time: 512.8115 seconds, Epoch [29/200], Step [60/123], d_loss: 0.6539, g_loss: 0.6170, D(x): 0.63, D(G(z)): 0.55
# Elapsed time: 514.0385 seconds, Epoch [29/200], Step [70/123], d_loss: 0.7022, g_loss: 0.8521, D(x): 0.45, D(G(z)): 0.43
# Elapsed time: 515.2367 seconds, Epoch [29/200], Step [80/123], d_loss: 0.6478, g_loss: 0.8399, D(x): 0.51, D(G(z)): 0.44
# Elapsed time: 517.2066 seconds, Epoch [29/200], Step [90/123], d_loss: 0.6350, g_loss: 0.7861, D(x): 0.53, D(G(z)): 0.46
# Elapsed time: 518.6228 seconds, Epoch [29/200], Step [100/123], d_loss: 0.6342, g_loss: 0.7270, D(x): 0.58, D(G(z)): 0.49
# Elapsed time: 519.5458 seconds, Epoch [29/200], Step [110/123], d_loss: 0.5672, g_loss: 0.8036, D(x): 0.62, D(G(z)): 0.45
# Elapsed time: 520.5298 seconds, Epoch [29/200], Step [120/123], d_loss: 0.6507, g_loss: 0.8247, D(x): 0.51, D(G(z)): 0.44
# Elapsed time: 524.2323 seconds, Epoch [30/200], Step [10/123], d_loss: 0.6212, g_loss: 0.7997, D(x): 0.55, D(G(z)): 0.45
# Elapsed time: 525.5205 seconds, Epoch [30/200], Step [20/123], d_loss: 0.5969, g_loss: 0.9844, D(x): 0.53, D(G(z)): 0.39
# Elapsed time: 526.7965 seconds, Epoch [30/200], Step [30/123], d_loss: 0.6070, g_loss: 0.7719, D(x): 0.58, D(G(z)): 0.47
# Elapsed time: 528.2360 seconds, Epoch [30/200], Step [40/123], d_loss: 0.5819, g_loss: 0.7304, D(x): 0.64, D(G(z)): 0.49
# Elapsed time: 530.0978 seconds, Epoch [30/200], Step [50/123], d_loss: 0.5354, g_loss: 0.8387, D(x): 0.64, D(G(z)): 0.44
# Elapsed time: 531.2080 seconds, Epoch [30/200], Step [60/123], d_loss: 0.6589, g_loss: 1.0575, D(x): 0.45, D(G(z)): 0.36
# Elapsed time: 532.7372 seconds, Epoch [30/200], Step [70/123], d_loss: 0.6308, g_loss: 0.8525, D(x): 0.51, D(G(z)): 0.43
# Elapsed time: 533.7332 seconds, Epoch [30/200], Step [80/123], d_loss: 0.6063, g_loss: 0.7877, D(x): 0.58, D(G(z)): 0.46
# Elapsed time: 535.5884 seconds, Epoch [30/200], Step [90/123], d_loss: 0.6658, g_loss: 0.7165, D(x): 0.53, D(G(z)): 0.49
# Elapsed time: 537.0412 seconds, Epoch [30/200], Step [100/123], d_loss: 0.6467, g_loss: 0.8991, D(x): 0.49, D(G(z)): 0.41
# Elapsed time: 538.2350 seconds, Epoch [30/200], Step [110/123], d_loss: 0.6185, g_loss: 0.9075, D(x): 0.51, D(G(z)): 0.41
# Elapsed time: 539.3020 seconds, Epoch [30/200], Step [120/123], d_loss: 0.6277, g_loss: 1.2292, D(x): 0.44, D(G(z)): 0.31
# Elapsed time: 542.2159 seconds, Epoch [31/200], Step [10/123], d_loss: 0.6358, g_loss: 0.8357, D(x): 0.53, D(G(z)): 0.44
# Elapsed time: 543.7050 seconds, Epoch [31/200], Step [20/123], d_loss: 0.6269, g_loss: 0.7330, D(x): 0.57, D(G(z)): 0.49
# Elapsed time: 544.5691 seconds, Epoch [31/200], Step [30/123], d_loss: 0.6000, g_loss: 0.7463, D(x): 0.59, D(G(z)): 0.48
# Elapsed time: 545.7119 seconds, Epoch [31/200], Step [40/123], d_loss: 0.6460, g_loss: 0.7724, D(x): 0.53, D(G(z)): 0.47
# Elapsed time: 547.8361 seconds, Epoch [31/200], Step [50/123], d_loss: 0.6625, g_loss: 0.6067, D(x): 0.63, D(G(z)): 0.55
# Elapsed time: 549.0812 seconds, Epoch [31/200], Step [60/123], d_loss: 0.6257, g_loss: 0.7899, D(x): 0.56, D(G(z)): 0.46
# Elapsed time: 550.1325 seconds, Epoch [31/200], Step [70/123], d_loss: 0.6543, g_loss: 0.6865, D(x): 0.58, D(G(z)): 0.51
# Elapsed time: 551.4275 seconds, Epoch [31/200], Step [80/123], d_loss: 0.6736, g_loss: 0.6486, D(x): 0.58, D(G(z)): 0.53
# Elapsed time: 552.9786 seconds, Epoch [31/200], Step [90/123], d_loss: 0.5797, g_loss: 0.8287, D(x): 0.59, D(G(z)): 0.44
# Elapsed time: 555.0582 seconds, Epoch [31/200], Step [100/123], d_loss: 0.6547, g_loss: 0.7229, D(x): 0.54, D(G(z)): 0.49
# Elapsed time: 556.4312 seconds, Epoch [31/200], Step [110/123], d_loss: 0.6276, g_loss: 0.8976, D(x): 0.51, D(G(z)): 0.42
# Elapsed time: 557.2169 seconds, Epoch [31/200], Step [120/123], d_loss: 0.6640, g_loss: 0.8192, D(x): 0.49, D(G(z)): 0.45
# Elapsed time: 560.0892 seconds, Epoch [32/200], Step [10/123], d_loss: 0.5671, g_loss: 0.9237, D(x): 0.59, D(G(z)): 0.41
# Elapsed time: 561.1141 seconds, Epoch [32/200], Step [20/123], d_loss: 0.6648, g_loss: 0.7212, D(x): 0.52, D(G(z)): 0.49
# Elapsed time: 562.3919 seconds, Epoch [32/200], Step [30/123], d_loss: 0.6706, g_loss: 0.8733, D(x): 0.47, D(G(z)): 0.42
# Elapsed time: 563.6187 seconds, Epoch [32/200], Step [40/123], d_loss: 0.6593, g_loss: 0.7594, D(x): 0.52, D(G(z)): 0.47
# Elapsed time: 565.7830 seconds, Epoch [32/200], Step [50/123], d_loss: 0.6784, g_loss: 0.9085, D(x): 0.47, D(G(z)): 0.41
# Elapsed time: 567.0273 seconds, Epoch [32/200], Step [60/123], d_loss: 0.6748, g_loss: 0.7724, D(x): 0.49, D(G(z)): 0.47
# Elapsed time: 568.1575 seconds, Epoch [32/200], Step [70/123], d_loss: 0.6593, g_loss: 0.8190, D(x): 0.50, D(G(z)): 0.44
# Elapsed time: 569.3808 seconds, Epoch [32/200], Step [80/123], d_loss: 0.6181, g_loss: 0.7040, D(x): 0.61, D(G(z)): 0.50
# Elapsed time: 571.2133 seconds, Epoch [32/200], Step [90/123], d_loss: 0.6399, g_loss: 0.9864, D(x): 0.47, D(G(z)): 0.38
# Elapsed time: 572.1355 seconds, Epoch [32/200], Step [100/123], d_loss: 0.6721, g_loss: 0.8448, D(x): 0.48, D(G(z)): 0.44
# Elapsed time: 573.8111 seconds, Epoch [32/200], Step [110/123], d_loss: 0.7029, g_loss: 0.7945, D(x): 0.47, D(G(z)): 0.46
# Elapsed time: 574.6881 seconds, Epoch [32/200], Step [120/123], d_loss: 0.6714, g_loss: 0.6750, D(x): 0.55, D(G(z)): 0.51
# Elapsed time: 577.2611 seconds, Epoch [33/200], Step [10/123], d_loss: 0.6259, g_loss: 0.8687, D(x): 0.51, D(G(z)): 0.42
# Elapsed time: 578.8528 seconds, Epoch [33/200], Step [20/123], d_loss: 0.6498, g_loss: 0.6547, D(x): 0.60, D(G(z)): 0.52
# Elapsed time: 579.8355 seconds, Epoch [33/200], Step [30/123], d_loss: 0.6239, g_loss: 0.7199, D(x): 0.58, D(G(z)): 0.49
# Elapsed time: 581.2176 seconds, Epoch [33/200], Step [40/123], d_loss: 0.6394, g_loss: 0.7639, D(x): 0.55, D(G(z)): 0.47
# Elapsed time: 583.3019 seconds, Epoch [33/200], Step [50/123], d_loss: 0.6345, g_loss: 0.6446, D(x): 0.62, D(G(z)): 0.53
# Elapsed time: 584.5700 seconds, Epoch [33/200], Step [60/123], d_loss: 0.6618, g_loss: 0.9400, D(x): 0.45, D(G(z)): 0.40
# Elapsed time: 585.5668 seconds, Epoch [33/200], Step [70/123], d_loss: 0.7052, g_loss: 0.7380, D(x): 0.52, D(G(z)): 0.48
# Elapsed time: 587.1341 seconds, Epoch [33/200], Step [80/123], d_loss: 0.6752, g_loss: 1.0159, D(x): 0.44, D(G(z)): 0.37
# Elapsed time: 589.4957 seconds, Epoch [33/200], Step [90/123], d_loss: 0.6802, g_loss: 0.8962, D(x): 0.46, D(G(z)): 0.41
# Elapsed time: 590.4768 seconds, Epoch [33/200], Step [100/123], d_loss: 0.6301, g_loss: 0.7962, D(x): 0.54, D(G(z)): 0.46
# Elapsed time: 591.6821 seconds, Epoch [33/200], Step [110/123], d_loss: 0.5609, g_loss: 0.7992, D(x): 0.62, D(G(z)): 0.45
# Elapsed time: 592.5029 seconds, Epoch [33/200], Step [120/123], d_loss: 0.6362, g_loss: 0.6832, D(x): 0.59, D(G(z)): 0.51
# Elapsed time: 595.1668 seconds, Epoch [34/200], Step [10/123], d_loss: 0.6555, g_loss: 0.7401, D(x): 0.55, D(G(z)): 0.49
# ...
# Elapsed time: 3376.0832 seconds, Epoch [190/200], Step [40/123], d_loss: 0.6689, g_loss: 0.7083, D(x): 0.54, D(G(z)): 0.50
# Elapsed time: 3377.4122 seconds, Epoch [190/200], Step [50/123], d_loss: 0.6723, g_loss: 0.7892, D(x): 0.49, D(G(z)): 0.46
# Elapsed time: 3378.9153 seconds, Epoch [190/200], Step [60/123], d_loss: 0.6289, g_loss: 0.7968, D(x): 0.53, D(G(z)): 0.45
# Elapsed time: 3379.8984 seconds, Epoch [190/200], Step [70/123], d_loss: 0.6358, g_loss: 0.7527, D(x): 0.54, D(G(z)): 0.47
# Elapsed time: 3381.0986 seconds, Epoch [190/200], Step [80/123], d_loss: 0.7089, g_loss: 0.6011, D(x): 0.59, D(G(z)): 0.56
# Elapsed time: 3383.3367 seconds, Epoch [190/200], Step [90/123], d_loss: 0.6892, g_loss: 0.7078, D(x): 0.51, D(G(z)): 0.50
# Elapsed time: 3384.9047 seconds, Epoch [190/200], Step [100/123], d_loss: 0.6792, g_loss: 0.7733, D(x): 0.49, D(G(z)): 0.46
# Elapsed time: 3386.1472 seconds, Epoch [190/200], Step [110/123], d_loss: 0.6956, g_loss: 0.6865, D(x): 0.53, D(G(z)): 0.52
# Elapsed time: 3386.8126 seconds, Epoch [190/200], Step [120/123], d_loss: 0.6991, g_loss: 0.8359, D(x): 0.45, D(G(z)): 0.44
# Elapsed time: 3389.7782 seconds, Epoch [191/200], Step [10/123], d_loss: 0.6446, g_loss: 0.6806, D(x): 0.58, D(G(z)): 0.51
# Elapsed time: 3391.4322 seconds, Epoch [191/200], Step [20/123], d_loss: 0.6801, g_loss: 0.7150, D(x): 0.52, D(G(z)): 0.49
# Elapsed time: 3392.2433 seconds, Epoch [191/200], Step [30/123], d_loss: 0.6882, g_loss: 0.6292, D(x): 0.57, D(G(z)): 0.54
# Elapsed time: 3394.2319 seconds, Epoch [191/200], Step [40/123], d_loss: 0.6440, g_loss: 0.7601, D(x): 0.53, D(G(z)): 0.47
# Elapsed time: 3395.2931 seconds, Epoch [191/200], Step [50/123], d_loss: 0.6443, g_loss: 0.8216, D(x): 0.51, D(G(z)): 0.44
# Elapsed time: 3396.7608 seconds, Epoch [191/200], Step [60/123], d_loss: 0.6610, g_loss: 0.8001, D(x): 0.49, D(G(z)): 0.45
# Elapsed time: 3398.3051 seconds, Epoch [191/200], Step [70/123], d_loss: 0.6905, g_loss: 0.7607, D(x): 0.49, D(G(z)): 0.47
# Elapsed time: 3400.9555 seconds, Epoch [191/200], Step [80/123], d_loss: 0.6720, g_loss: 0.7008, D(x): 0.53, D(G(z)): 0.50
# Elapsed time: 3402.1189 seconds, Epoch [191/200], Step [90/123], d_loss: 0.6711, g_loss: 0.7232, D(x): 0.53, D(G(z)): 0.49
# Elapsed time: 3403.1804 seconds, Epoch [191/200], Step [100/123], d_loss: 0.7039, g_loss: 0.6057, D(x): 0.55, D(G(z)): 0.55
# Elapsed time: 3404.2520 seconds, Epoch [191/200], Step [110/123], d_loss: 0.6589, g_loss: 0.7063, D(x): 0.54, D(G(z)): 0.50
# Elapsed time: 3405.7801 seconds, Epoch [191/200], Step [120/123], d_loss: 0.6901, g_loss: 0.6269, D(x): 0.57, D(G(z)): 0.54
# Elapsed time: 3408.6966 seconds, Epoch [192/200], Step [10/123], d_loss: 0.6484, g_loss: 0.7419, D(x): 0.54, D(G(z)): 0.48
# Elapsed time: 3409.7387 seconds, Epoch [192/200], Step [20/123], d_loss: 0.6433, g_loss: 0.8295, D(x): 0.50, D(G(z)): 0.44
# Elapsed time: 3410.7359 seconds, Epoch [192/200], Step [30/123], d_loss: 0.6517, g_loss: 0.8287, D(x): 0.50, D(G(z)): 0.44
# Elapsed time: 3411.9338 seconds, Epoch [192/200], Step [40/123], d_loss: 0.6825, g_loss: 0.8967, D(x): 0.45, D(G(z)): 0.42
# Elapsed time: 3414.3881 seconds, Epoch [192/200], Step [50/123], d_loss: 0.7217, g_loss: 0.6107, D(x): 0.55, D(G(z)): 0.55
# Elapsed time: 3416.0252 seconds, Epoch [192/200], Step [60/123], d_loss: 0.6758, g_loss: 0.7297, D(x): 0.52, D(G(z)): 0.49
# Elapsed time: 3417.3618 seconds, Epoch [192/200], Step [70/123], d_loss: 0.6965, g_loss: 0.6944, D(x): 0.51, D(G(z)): 0.50
# Elapsed time: 3418.5811 seconds, Epoch [192/200], Step [80/123], d_loss: 0.6840, g_loss: 0.8374, D(x): 0.46, D(G(z)): 0.44
# Elapsed time: 3421.1270 seconds, Epoch [192/200], Step [90/123], d_loss: 0.6982, g_loss: 0.8911, D(x): 0.44, D(G(z)): 0.42
# Elapsed time: 3422.2055 seconds, Epoch [192/200], Step [100/123], d_loss: 0.6557, g_loss: 0.9321, D(x): 0.45, D(G(z)): 0.40
# Elapsed time: 3423.4335 seconds, Epoch [192/200], Step [110/123], d_loss: 0.6386, g_loss: 0.7444, D(x): 0.54, D(G(z)): 0.48
# Elapsed time: 3424.1498 seconds, Epoch [192/200], Step [120/123], d_loss: 0.6865, g_loss: 0.7580, D(x): 0.50, D(G(z)): 0.47
# Elapsed time: 3427.2528 seconds, Epoch [193/200], Step [10/123], d_loss: 0.6658, g_loss: 0.7374, D(x): 0.52, D(G(z)): 0.48
# Elapsed time: 3429.2667 seconds, Epoch [193/200], Step [20/123], d_loss: 0.6653, g_loss: 0.8134, D(x): 0.49, D(G(z)): 0.45
# Elapsed time: 3430.3081 seconds, Epoch [193/200], Step [30/123], d_loss: 0.6956, g_loss: 0.7515, D(x): 0.49, D(G(z)): 0.48
# Elapsed time: 3431.6085 seconds, Epoch [193/200], Step [40/123], d_loss: 0.6580, g_loss: 0.8031, D(x): 0.50, D(G(z)): 0.45
# Elapsed time: 3432.9567 seconds, Epoch [193/200], Step [50/123], d_loss: 0.6968, g_loss: 0.6140, D(x): 0.56, D(G(z)): 0.54
# Elapsed time: 3434.9362 seconds, Epoch [193/200], Step [60/123], d_loss: 0.6431, g_loss: 0.7190, D(x): 0.56, D(G(z)): 0.49
# Elapsed time: 3436.2490 seconds, Epoch [193/200], Step [70/123], d_loss: 0.6909, g_loss: 0.7696, D(x): 0.48, D(G(z)): 0.47
# Elapsed time: 3437.2777 seconds, Epoch [193/200], Step [80/123], d_loss: 0.6153, g_loss: 0.8157, D(x): 0.54, D(G(z)): 0.45
# Elapsed time: 3438.2104 seconds, Epoch [193/200], Step [90/123], d_loss: 0.6681, g_loss: 0.8405, D(x): 0.47, D(G(z)): 0.44
# Elapsed time: 3440.6536 seconds, Epoch [193/200], Step [100/123], d_loss: 0.6722, g_loss: 0.6603, D(x): 0.55, D(G(z)): 0.52
# Elapsed time: 3441.4085 seconds, Epoch [193/200], Step [110/123], d_loss: 0.6697, g_loss: 0.8614, D(x): 0.46, D(G(z)): 0.43
# Elapsed time: 3442.0624 seconds, Epoch [193/200], Step [120/123], d_loss: 0.6856, g_loss: 0.7143, D(x): 0.51, D(G(z)): 0.49
# Elapsed time: 3445.1340 seconds, Epoch [194/200], Step [10/123], d_loss: 0.7063, g_loss: 0.5502, D(x): 0.61, D(G(z)): 0.58
# Elapsed time: 3446.5052 seconds, Epoch [194/200], Step [20/123], d_loss: 0.6463, g_loss: 0.8540, D(x): 0.49, D(G(z)): 0.43
# Elapsed time: 3447.3267 seconds, Epoch [194/200], Step [30/123], d_loss: 0.6360, g_loss: 0.9606, D(x): 0.48, D(G(z)): 0.39
# Elapsed time: 3448.7406 seconds, Epoch [194/200], Step [40/123], d_loss: 0.6503, g_loss: 0.8034, D(x): 0.50, D(G(z)): 0.45
# Elapsed time: 3450.8734 seconds, Epoch [194/200], Step [50/123], d_loss: 0.6321, g_loss: 0.7869, D(x): 0.54, D(G(z)): 0.46
# Elapsed time: 3452.0314 seconds, Epoch [194/200], Step [60/123], d_loss: 0.6659, g_loss: 0.7347, D(x): 0.52, D(G(z)): 0.48
# Elapsed time: 3453.2021 seconds, Epoch [194/200], Step [70/123], d_loss: 0.6497, g_loss: 0.8465, D(x): 0.49, D(G(z)): 0.43
# Elapsed time: 3455.1141 seconds, Epoch [194/200], Step [80/123], d_loss: 0.6815, g_loss: 0.8558, D(x): 0.46, D(G(z)): 0.43
# Elapsed time: 3456.2895 seconds, Epoch [194/200], Step [90/123], d_loss: 0.6650, g_loss: 0.7844, D(x): 0.50, D(G(z)): 0.46
# Elapsed time: 3457.5077 seconds, Epoch [194/200], Step [100/123], d_loss: 0.6626, g_loss: 0.7505, D(x): 0.52, D(G(z)): 0.48
# Elapsed time: 3458.6071 seconds, Epoch [194/200], Step [110/123], d_loss: 0.6515, g_loss: 0.8139, D(x): 0.52, D(G(z)): 0.45
# Elapsed time: 3459.9832 seconds, Epoch [194/200], Step [120/123], d_loss: 0.6368, g_loss: 0.7956, D(x): 0.52, D(G(z)): 0.45
# Elapsed time: 3462.8601 seconds, Epoch [195/200], Step [10/123], d_loss: 0.6395, g_loss: 0.7583, D(x): 0.54, D(G(z)): 0.47
# Elapsed time: 3464.5265 seconds, Epoch [195/200], Step [20/123], d_loss: 0.6785, g_loss: 0.9249, D(x): 0.45, D(G(z)): 0.41
# Elapsed time: 3465.5023 seconds, Epoch [195/200], Step [30/123], d_loss: 0.6869, g_loss: 0.6087, D(x): 0.58, D(G(z)): 0.55
# Elapsed time: 3466.8623 seconds, Epoch [195/200], Step [40/123], d_loss: 0.6505, g_loss: 0.7648, D(x): 0.53, D(G(z)): 0.47
# Elapsed time: 3468.7845 seconds, Epoch [195/200], Step [50/123], d_loss: 0.6460, g_loss: 0.7603, D(x): 0.53, D(G(z)): 0.47
# Elapsed time: 3469.6049 seconds, Epoch [195/200], Step [60/123], d_loss: 0.6465, g_loss: 0.6605, D(x): 0.58, D(G(z)): 0.52
# Elapsed time: 3470.9099 seconds, Epoch [195/200], Step [70/123], d_loss: 0.6269, g_loss: 0.6462, D(x): 0.62, D(G(z)): 0.53
# Elapsed time: 3472.3475 seconds, Epoch [195/200], Step [80/123], d_loss: 0.6556, g_loss: 0.8935, D(x): 0.47, D(G(z)): 0.41
# Elapsed time: 3473.8124 seconds, Epoch [195/200], Step [90/123], d_loss: 0.6701, g_loss: 0.7945, D(x): 0.49, D(G(z)): 0.45
# Elapsed time: 3474.9237 seconds, Epoch [195/200], Step [100/123], d_loss: 0.6542, g_loss: 0.6562, D(x): 0.60, D(G(z)): 0.53
# Elapsed time: 3475.9579 seconds, Epoch [195/200], Step [110/123], d_loss: 0.6621, g_loss: 0.8818, D(x): 0.47, D(G(z)): 0.42
# Elapsed time: 3477.9763 seconds, Epoch [195/200], Step [120/123], d_loss: 0.6768, g_loss: 0.7719, D(x): 0.49, D(G(z)): 0.47
# Elapsed time: 3480.4340 seconds, Epoch [196/200], Step [10/123], d_loss: 0.6970, g_loss: 0.6785, D(x): 0.53, D(G(z)): 0.51
# Elapsed time: 3481.7476 seconds, Epoch [196/200], Step [20/123], d_loss: 0.6993, g_loss: 0.8731, D(x): 0.44, D(G(z)): 0.42
# Elapsed time: 3482.6787 seconds, Epoch [196/200], Step [30/123], d_loss: 0.6520, g_loss: 0.7357, D(x): 0.54, D(G(z)): 0.49
# Elapsed time: 3483.9023 seconds, Epoch [196/200], Step [40/123], d_loss: 0.6906, g_loss: 0.7928, D(x): 0.48, D(G(z)): 0.46
# Elapsed time: 3485.5361 seconds, Epoch [196/200], Step [50/123], d_loss: 0.6501, g_loss: 0.7142, D(x): 0.55, D(G(z)): 0.49
# Elapsed time: 3486.8038 seconds, Epoch [196/200], Step [60/123], d_loss: 0.6303, g_loss: 0.8007, D(x): 0.53, D(G(z)): 0.45
# Elapsed time: 3488.1287 seconds, Epoch [196/200], Step [70/123], d_loss: 0.6572, g_loss: 0.7664, D(x): 0.51, D(G(z)): 0.47
# Elapsed time: 3489.3902 seconds, Epoch [196/200], Step [80/123], d_loss: 0.6603, g_loss: 0.7487, D(x): 0.52, D(G(z)): 0.48
# Elapsed time: 3490.8818 seconds, Epoch [196/200], Step [90/123], d_loss: 0.6705, g_loss: 0.9134, D(x): 0.46, D(G(z)): 0.41
# Elapsed time: 3493.1811 seconds, Epoch [196/200], Step [100/123], d_loss: 0.6839, g_loss: 0.7117, D(x): 0.52, D(G(z)): 0.49
# Elapsed time: 3494.1350 seconds, Epoch [196/200], Step [110/123], d_loss: 0.6756, g_loss: 0.7686, D(x): 0.50, D(G(z)): 0.47
# Elapsed time: 3494.8956 seconds, Epoch [196/200], Step [120/123], d_loss: 0.6742, g_loss: 0.7392, D(x): 0.51, D(G(z)): 0.48
# Elapsed time: 3497.6108 seconds, Epoch [197/200], Step [10/123], d_loss: 0.6822, g_loss: 0.8005, D(x): 0.48, D(G(z)): 0.45
# Elapsed time: 3499.1443 seconds, Epoch [197/200], Step [20/123], d_loss: 0.7112, g_loss: 0.7823, D(x): 0.46, D(G(z)): 0.46
# Elapsed time: 3500.1733 seconds, Epoch [197/200], Step [30/123], d_loss: 0.7038, g_loss: 0.6155, D(x): 0.56, D(G(z)): 0.55
# Elapsed time: 3501.2993 seconds, Epoch [197/200], Step [40/123], d_loss: 0.6339, g_loss: 0.7342, D(x): 0.56, D(G(z)): 0.48
# Elapsed time: 3504.0099 seconds, Epoch [197/200], Step [50/123], d_loss: 0.6276, g_loss: 0.7814, D(x): 0.54, D(G(z)): 0.46
# Elapsed time: 3505.0687 seconds, Epoch [197/200], Step [60/123], d_loss: 0.6564, g_loss: 0.7607, D(x): 0.53, D(G(z)): 0.48
# Elapsed time: 3506.2522 seconds, Epoch [197/200], Step [70/123], d_loss: 0.6476, g_loss: 0.7238, D(x): 0.55, D(G(z)): 0.49
# Elapsed time: 3507.3276 seconds, Epoch [197/200], Step [80/123], d_loss: 0.6361, g_loss: 0.7603, D(x): 0.54, D(G(z)): 0.47
# Elapsed time: 3509.8394 seconds, Epoch [197/200], Step [90/123], d_loss: 0.6841, g_loss: 0.8053, D(x): 0.49, D(G(z)): 0.45
# Elapsed time: 3510.7587 seconds, Epoch [197/200], Step [100/123], d_loss: 0.6792, g_loss: 0.6231, D(x): 0.57, D(G(z)): 0.54
# Elapsed time: 3512.1173 seconds, Epoch [197/200], Step [110/123], d_loss: 0.6653, g_loss: 0.8712, D(x): 0.48, D(G(z)): 0.43
# Elapsed time: 3512.9666 seconds, Epoch [197/200], Step [120/123], d_loss: 0.6644, g_loss: 0.7876, D(x): 0.50, D(G(z)): 0.46
# Elapsed time: 3516.1603 seconds, Epoch [198/200], Step [10/123], d_loss: 0.6924, g_loss: 0.6572, D(x): 0.55, D(G(z)): 0.53
# Elapsed time: 3517.5619 seconds, Epoch [198/200], Step [20/123], d_loss: 0.6498, g_loss: 0.7325, D(x): 0.55, D(G(z)): 0.49
# Elapsed time: 3518.8324 seconds, Epoch [198/200], Step [30/123], d_loss: 0.6761, g_loss: 0.8464, D(x): 0.46, D(G(z)): 0.43
# Elapsed time: 3520.0763 seconds, Epoch [198/200], Step [40/123], d_loss: 0.6813, g_loss: 0.7583, D(x): 0.50, D(G(z)): 0.48
# Elapsed time: 3521.6552 seconds, Epoch [198/200], Step [50/123], d_loss: 0.6580, g_loss: 0.7370, D(x): 0.53, D(G(z)): 0.48
# Elapsed time: 3523.4361 seconds, Epoch [198/200], Step [60/123], d_loss: 0.6689, g_loss: 0.7442, D(x): 0.51, D(G(z)): 0.48
# Elapsed time: 3524.4478 seconds, Epoch [198/200], Step [70/123], d_loss: 0.6084, g_loss: 0.9042, D(x): 0.52, D(G(z)): 0.41
# Elapsed time: 3525.3831 seconds, Epoch [198/200], Step [80/123], d_loss: 0.6660, g_loss: 0.7961, D(x): 0.49, D(G(z)): 0.45
# Elapsed time: 3526.8293 seconds, Epoch [198/200], Step [90/123], d_loss: 0.6731, g_loss: 0.7404, D(x): 0.52, D(G(z)): 0.48
# Elapsed time: 3528.5579 seconds, Epoch [198/200], Step [100/123], d_loss: 0.6522, g_loss: 0.7759, D(x): 0.52, D(G(z)): 0.46
# Elapsed time: 3529.6579 seconds, Epoch [198/200], Step [110/123], d_loss: 0.6383, g_loss: 0.7169, D(x): 0.56, D(G(z)): 0.49
# Elapsed time: 3530.6394 seconds, Epoch [198/200], Step [120/123], d_loss: 0.6844, g_loss: 0.8120, D(x): 0.47, D(G(z)): 0.45
# Elapsed time: 3533.9032 seconds, Epoch [199/200], Step [10/123], d_loss: 0.5981, g_loss: 0.8753, D(x): 0.54, D(G(z)): 0.42
# Elapsed time: 3535.1535 seconds, Epoch [199/200], Step [20/123], d_loss: 0.6504, g_loss: 0.7439, D(x): 0.54, D(G(z)): 0.48
# Elapsed time: 3536.2071 seconds, Epoch [199/200], Step [30/123], d_loss: 0.7287, g_loss: 0.6197, D(x): 0.52, D(G(z)): 0.54
# Elapsed time: 3537.6975 seconds, Epoch [199/200], Step [40/123], d_loss: 0.6556, g_loss: 0.7814, D(x): 0.51, D(G(z)): 0.46
# Elapsed time: 3538.9419 seconds, Epoch [199/200], Step [50/123], d_loss: 0.7247, g_loss: 0.6490, D(x): 0.50, D(G(z)): 0.53
# Elapsed time: 3540.7682 seconds, Epoch [199/200], Step [60/123], d_loss: 0.6899, g_loss: 0.8545, D(x): 0.46, D(G(z)): 0.43
# Elapsed time: 3541.7764 seconds, Epoch [199/200], Step [70/123], d_loss: 0.6642, g_loss: 0.9489, D(x): 0.47, D(G(z)): 0.40
# Elapsed time: 3543.3045 seconds, Epoch [199/200], Step [80/123], d_loss: 0.6521, g_loss: 0.7072, D(x): 0.55, D(G(z)): 0.50
# Elapsed time: 3544.5999 seconds, Epoch [199/200], Step [90/123], d_loss: 0.6121, g_loss: 0.6865, D(x): 0.63, D(G(z)): 0.51
# Elapsed time: 3545.9338 seconds, Epoch [199/200], Step [100/123], d_loss: 0.6247, g_loss: 0.8365, D(x): 0.52, D(G(z)): 0.44
# Elapsed time: 3547.2778 seconds, Epoch [199/200], Step [110/123], d_loss: 0.6504, g_loss: 0.7991, D(x): 0.52, D(G(z)): 0.46
# Elapsed time: 3548.4150 seconds, Epoch [199/200], Step [120/123], d_loss: 0.6792, g_loss: 0.7038, D(x): 0.52, D(G(z)): 0.50
# Elapsed time: 3551.6645 seconds, Epoch [200/200], Step [10/123], d_loss: 0.6557, g_loss: 0.7718, D(x): 0.52, D(G(z)): 0.47
# Elapsed time: 3552.5161 seconds, Epoch [200/200], Step [20/123], d_loss: 0.6583, g_loss: 0.8917, D(x): 0.47, D(G(z)): 0.41
# Elapsed time: 3553.7094 seconds, Epoch [200/200], Step [30/123], d_loss: 0.6527, g_loss: 0.7947, D(x): 0.51, D(G(z)): 0.46
# Elapsed time: 3554.8156 seconds, Epoch [200/200], Step [40/123], d_loss: 0.6321, g_loss: 0.7402, D(x): 0.57, D(G(z)): 0.48
# Elapsed time: 3556.6910 seconds, Epoch [200/200], Step [50/123], d_loss: 0.6382, g_loss: 0.7041, D(x): 0.57, D(G(z)): 0.50
# Elapsed time: 3557.9777 seconds, Epoch [200/200], Step [60/123], d_loss: 0.6601, g_loss: 0.7582, D(x): 0.51, D(G(z)): 0.47
# Elapsed time: 3559.0551 seconds, Epoch [200/200], Step [70/123], d_loss: 0.6837, g_loss: 0.7064, D(x): 0.51, D(G(z)): 0.50
# Elapsed time: 3560.0828 seconds, Epoch [200/200], Step [80/123], d_loss: 0.6909, g_loss: 0.5919, D(x): 0.58, D(G(z)): 0.56
# Elapsed time: 3562.4317 seconds, Epoch [200/200], Step [90/123], d_loss: 0.6471, g_loss: 0.7131, D(x): 0.56, D(G(z)): 0.49
# Elapsed time: 3563.8769 seconds, Epoch [200/200], Step [100/123], d_loss: 0.6407, g_loss: 0.7016, D(x): 0.57, D(G(z)): 0.50
# Elapsed time: 3565.0065 seconds, Epoch [200/200], Step [110/123], d_loss: 0.6917, g_loss: 0.6006, D(x): 0.57, D(G(z)): 0.55
# Elapsed time: 3565.8730 seconds, Epoch [200/200], Step [120/123], d_loss: 0.6960, g_loss: 0.6640, D(x): 0.53, D(G(z)): 0.52
